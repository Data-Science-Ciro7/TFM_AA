# %% [markdown]
# #  FEATURE ENGINEERING - `NaN` VALUES IMPUTING - samples for ALTERNATIVE 1-NN METHODOLOGY

# %% [markdown]
# In this Notebook we apply the chosen `NaN` imputing strategy. The imputing operation is carried out on the scaled datasets.
#
# We will use a k-nn algorithm (weighted by distance) to assign values to the `NaN` values present in a few of the features. For each feature to be imputed, we will use all the rest of the non-`NaN` features, even those which do not belong to the same cathegory.
#
# **IMPORTANT:** Notice that, contrary to the scaling operation, in this case we fitted two different k-nn models: one for S4 sample and another one for ML subsample, so as to keep the specific, independent characteristics of both samples (remember the differences between the values distributions for many features).

# %% [markdown]
# ## Modules and configuration

# %% [markdown]
# ### Modules

# %%
import pandas as pd

from sklearn.impute import KNNImputer

import pickle

#import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set_style("white", {'figure.figsize':(15,10)})

# %% [markdown]
# ### Configuration

# %%
CARMENES_IN = "../data/DATASETS_ML/1NN/1NN_CARMENES_01_DS_AfterScaling.csv"
TRAIN_S4B_IN = "../data/DATASETS_ML/1NN/1NN_TRAIN_S4B_01_DS_AfterScaling.csv"
VAL_S4B_IN = "../data/DATASETS_ML/1NN/1NN_VAL_S4B_01_DS_AfterScaling.csv"

CARMENES_IMP_FILE = "../data/ML_MODELS/ML_pipeline_steps/1NN/1NN_CARMENES_imputer.pickle"
# Will store the fitted imputer object
TRAIN_S4B_IMP_FILE = "../data/ML_MODELS/ML_pipeline_steps/1NN/1NN_TRAIN_S4B_imputer.pickle"
# Will store the fitted imputer object
VAL_S4B_IMP_FILE = "../data/ML_MODELS/ML_pipeline_steps/1NN/1NN_VAL_S4B_imputer.pickle"
# Will store the fitted imputer object

IMPUTED_FEATURES_IN = "../data/ML_MODELS/ML_pipeline_steps/1NN/1NN_imputed_features_list.pickle"

CARMENES_OUT = "../data/DATASETS_ML/1NN/1NN_CARMENES_02_DS_AfterImputing.csv"
# The scaled features of the CARMENES subsample.
TRAIN_S4B_OUT = "../data/DATASETS_ML/1NN/1NN_TRAIN_S4B_02_DS_AfterImputing.csv"
# The scaled features of the TRAINING S4 sample
VAL_S4B_OUT = "../data/DATASETS_ML/1NN/1NN_VAL_S4B_02_DS_AfterImputing.csv"
# The scaled features of the VALIDATION S4 sample

ML_ADD_COLUMNS = ['Karmn'] # Only cesium features and this column will be kept.
S4_ADD_COLUMNS = ['ID', 'Pulsating', 'frequency', 'amplitudeRV',
                  'offsetRV', 'refepochRV', 'phase',
                  'CARMENES_source_idx', 'CARMENES_Ref_star'] # Only cesium features and these columns will be kept.

# %% [markdown]
# ### Functions

# %% [markdown]
# ## Load data

# %% [markdown]
# We load the data, which are the time series as previously featurized by _cesium_ and scaled.

# %% [markdown]
# ### Load the list of features to impute

# %%
impute_f_list = pickle.load(open(IMPUTED_FEATURES_IN, "rb"))
impute_f_list
# Out:
# ['all_times_nhist_peak2_bin',
#  'all_times_nhist_peak3_bin',
#  'all_times_nhist_peak4_bin',
#  'all_times_nhist_peak_1_to_2',
#  'all_times_nhist_peak_1_to_3',
#  'all_times_nhist_peak_1_to_4',
#  'all_times_nhist_peak_2_to_3',
#  'all_times_nhist_peak_2_to_4',
#  'all_times_nhist_peak_3_to_4',
#  'fold2P_slope_10percentile',
#  'fold2P_slope_90percentile',
#  'medperc90_2p_p',
#  'freq1_amplitude1',
#  'freq1_amplitude2',
#  'freq1_amplitude3',
#  'freq1_amplitude4',
#  'freq1_rel_phase2',
#  'freq1_rel_phase3',
#  'freq1_rel_phase4',
#  'freq2_amplitude1',
#  'freq2_amplitude2',
#  'freq2_amplitude3',
#  'freq2_amplitude4',
#  'freq2_rel_phase2',
#  'freq2_rel_phase3',
#  'freq2_rel_phase4',
#  'freq3_amplitude1',
#  'freq3_amplitude2',
#  'freq3_amplitude3',
#  'freq3_amplitude4',
#  'freq3_rel_phase2',
#  'freq3_rel_phase3',
#  'freq3_rel_phase4',
#  'freq_amplitude_ratio_21',
#  'freq_amplitude_ratio_31',
#  'freq_model_max_delta_mags',
#  'freq_model_min_delta_mags',
#  'freq_signif_ratio_21',
#  'freq_signif_ratio_31',
#  'freq_varrat',
#  'freq_y_offset',
#  'linear_trend',
#  'scatter_res_raw',
#  'std_double_to_single_step']

# %% [markdown]
# ### Load the TRAINING S4 sample data

# %%
s4_tr = pd.read_csv(TRAIN_S4B_IN, sep=',', decimal='.')
s4_tr
# Out:
#                      ID  Pulsating  frequency  amplitudeRV  offsetRV  \
# 0      ALT-B_Star-00000       True        8.0          0.1       0.0
# 1      ALT-B_Star-00001      False        0.0          0.0       0.0
# 2      ALT-B_Star-00002       True        8.0          0.1       0.0
# 3      ALT-B_Star-00003      False        0.0          0.0       0.0
# 4      ALT-B_Star-00004       True        8.0          0.1       0.0
# ...                 ...        ...        ...          ...       ...
# 37275  ALT-B_Star-37275      False        0.0          0.0       0.0
# 37276  ALT-B_Star-37276       True       64.0          1.6       0.0
# 37277  ALT-B_Star-37277      False        0.0          0.0       0.0
# 37278  ALT-B_Star-37278       True       64.0          1.6       0.0
# 37279  ALT-B_Star-37279      False        0.0          0.0       0.0
#
#        refepochRV  phase  CARMENES_source_idx CARMENES_Ref_star  \
# 0             0.0   0.00                    0        J23505-095
# 1             0.0   0.00                    0        J23505-095
# 2             0.0   0.25                    0        J23505-095
# 3             0.0   0.00                    0        J23505-095
# 4             0.0   0.50                    0        J23505-095
# ...           ...    ...                  ...               ...
# 37275         0.0   0.00                  232        J00051+457
# 37276         0.0   0.50                  232        J00051+457
# 37277         0.0   0.00                  232        J00051+457
# 37278         0.0   0.75                  232        J00051+457
# 37279         0.0   0.00                  232        J00051+457
#
#        all_times_nhist_numpeaks  ...  freq_signif_ratio_31  freq_varrat  \
# 0                      0.205178  ...             -0.908970     0.541171
# 1                      0.205178  ...             -0.725712     0.832929
# 2                      0.205178  ...             -0.411204     0.857062
# 3                      0.205178  ...             -0.022857     1.028396
# 4                      0.205178  ...             -0.272705     0.962090
# ...                         ...  ...                   ...          ...
# 37275                  0.830097  ...             -0.394117     0.405540
# 37276                  0.830097  ...              0.288502     0.461546
# 37277                  0.830097  ...             -0.876158     0.530909
# 37278                  0.830097  ...             -0.487701     0.343003
# 37279                  0.830097  ...             -0.906626     0.539784
#
#        freq_y_offset  linear_trend  medperc90_2p_p  p2p_scatter_2praw  \
# 0          -0.669931     -0.015526       -0.019047          -0.007352
# 1           0.631644     -0.009818       -0.021695           0.552345
# 2           0.541050     -0.005791       -0.035445           0.013431
# 3          -0.061844     -0.002265       -0.031985           0.275371
# 4          -0.223832     -0.008516       -0.043389          -0.593592
# ...              ...           ...             ...                ...
# 37275       1.174777     -0.032514       -0.030659          -0.363602
# 37276       0.193656     -0.023099       -0.028984           0.259205
# 37277       0.215261     -0.027492       -0.033688           0.460585
# 37278      -1.656181     -0.023002       -0.000361           0.384265
# 37279      -0.230445     -0.000470       -0.038807          -0.816153
#
#        p2p_scatter_over_mad  p2p_scatter_pfold_over_mad  \
# 0                 -0.442166                   -0.134743
# 1                 -0.429826                    0.007825
# 2                 -0.327874                   -0.179274
# 3                 -0.217636                    0.168502
# 4                  0.261842                   -0.171281
# ...                     ...                         ...
# 37275             -0.042368                   -0.039153
# 37276             -0.075329                   -0.205573
# 37277             -0.247941                   -0.138908
# 37278             -0.588162                   -0.164535
# 37279             -0.179862                   -0.186934
#
#        p2p_ssqr_diff_over_var  scatter_res_raw
# 0                   -0.219987         0.356795
# 1                   -0.005592         0.720584
# 2                   -0.090747         0.234164
# 3                    0.170924         0.373533
# 4                    0.590502         1.231367
# ...                       ...              ...
# 37275                0.551196         0.088020
# 37276               -0.414141         0.392452
# 37277               -0.166431         0.054261
# 37278               -0.621599         0.013055
# 37279               -0.384288         0.386773
#
# [37280 rows x 121 columns]

# %%
print(list(s4_tr.columns))
# Out:
# ['ID', 'Pulsating', 'frequency', 'amplitudeRV', 'offsetRV', 'refepochRV', 'phase', 'CARMENES_source_idx', 'CARMENES_Ref_star', 'all_times_nhist_numpeaks', 'all_times_nhist_peak1_bin', 'all_times_nhist_peak2_bin', 'all_times_nhist_peak3_bin', 'all_times_nhist_peak4_bin', 'all_times_nhist_peak_1_to_2', 'all_times_nhist_peak_1_to_3', 'all_times_nhist_peak_1_to_4', 'all_times_nhist_peak_2_to_3', 'all_times_nhist_peak_2_to_4', 'all_times_nhist_peak_3_to_4', 'all_times_nhist_peak_val', 'avg_double_to_single_step', 'avg_err', 'avgt', 'cad_probs_1', 'cad_probs_10', 'cad_probs_20', 'cad_probs_30', 'cad_probs_40', 'cad_probs_50', 'cad_probs_100', 'cad_probs_500', 'cad_probs_1000', 'cad_probs_5000', 'cad_probs_10000', 'cad_probs_50000', 'cad_probs_100000', 'cad_probs_500000', 'cad_probs_1000000', 'cad_probs_5000000', 'cad_probs_10000000', 'cads_avg', 'cads_med', 'cads_std', 'mean', 'med_double_to_single_step', 'med_err', 'n_epochs', 'std_double_to_single_step', 'std_err', 'total_time', 'amplitude', 'flux_percentile_ratio_mid20', 'flux_percentile_ratio_mid35', 'flux_percentile_ratio_mid50', 'flux_percentile_ratio_mid65', 'flux_percentile_ratio_mid80', 'max_slope', 'maximum', 'median', 'median_absolute_deviation', 'minimum', 'percent_amplitude', 'percent_beyond_1_std', 'percent_close_to_median', 'percent_difference_flux_percentile', 'period_fast', 'qso_log_chi2_qsonu', 'qso_log_chi2nuNULL_chi2nu', 'skew', 'std', 'stetson_j', 'stetson_k', 'weighted_average', 'fold2P_slope_10percentile', 'fold2P_slope_90percentile', 'freq1_amplitude1', 'freq1_amplitude2', 'freq1_amplitude3', 'freq1_amplitude4', 'freq1_freq', 'freq1_lambda', 'freq1_rel_phase2', 'freq1_rel_phase3', 'freq1_rel_phase4', 'freq1_signif', 'freq2_amplitude1', 'freq2_amplitude2', 'freq2_amplitude3', 'freq2_amplitude4', 'freq2_freq', 'freq2_rel_phase2', 'freq2_rel_phase3', 'freq2_rel_phase4', 'freq3_amplitude1', 'freq3_amplitude2', 'freq3_amplitude3', 'freq3_amplitude4', 'freq3_freq', 'freq3_rel_phase2', 'freq3_rel_phase3', 'freq3_rel_phase4', 'freq_amplitude_ratio_21', 'freq_amplitude_ratio_31', 'freq_frequency_ratio_21', 'freq_frequency_ratio_31', 'freq_model_max_delta_mags', 'freq_model_min_delta_mags', 'freq_model_phi1_phi2', 'freq_n_alias', 'freq_signif_ratio_21', 'freq_signif_ratio_31', 'freq_varrat', 'freq_y_offset', 'linear_trend', 'medperc90_2p_p', 'p2p_scatter_2praw', 'p2p_scatter_over_mad', 'p2p_scatter_pfold_over_mad', 'p2p_ssqr_diff_over_var', 'scatter_res_raw']

# %% [markdown]
# ### Load the VALIDATION S4 sample data

# %%
s4_val = pd.read_csv(VAL_S4B_IN, sep=',', decimal='.')
s4_val
# Out:
#                 ID  Pulsating  frequency  amplitudeRV  offsetRV    refepochRV  \
# 0     B_Star-00000      False       0.00         0.00       0.0  2.457432e+06
# 1     B_Star-00001      False       0.00         0.00       0.0  2.457487e+06
# 2     B_Star-00002      False       0.00         0.00       0.0  2.457417e+06
# 3     B_Star-00003      False       0.00         0.00       0.0  2.457431e+06
# 4     B_Star-00004      False       0.00         0.00       0.0  2.461026e+06
# ...            ...        ...        ...          ...       ...           ...
# 3988  B_Star-03995      False       0.00         0.00       0.0  2.459911e+06
# 3989  B_Star-03996      False       0.00         0.00       0.0  2.457428e+06
# 3990  B_Star-03997      False       0.00         0.00       0.0  2.458409e+06
# 3991  B_Star-03998      False       0.00         0.00       0.0  2.457468e+06
# 3992  B_Star-03999       True      19.13         1.41       0.0  2.457400e+06
#
#       phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0      0.00                  116        J11511+352                  0.517637
# 1      0.00                   29        J20336+617                 -0.419742
# 2      0.00                  156        J08402+314                  0.517637
# 3      0.00                  180        J05421+124                  0.830097
# 4      0.00                   67        J17052-050                  0.830097
# ...     ...                  ...               ...                       ...
# 3988   0.00                   53        J18165+048                 -0.732202
# 3989   0.00                    8        J23216+172                 -1.669582
# 3990   0.00                    3        J23419+441                  0.205178
# 3991   0.00                  181        J05415+534                  0.205178
# 3992   0.45                  179        J06011+595                  1.767477
#
#       ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0     ...             -0.134573     1.418486       0.042013     -0.009545
# 1     ...              0.125231     0.579019       1.116863      0.000807
# 2     ...              1.350668    -0.929902      -0.047202      0.016980
# 3     ...             -0.058875     0.312563       0.586087     -0.005898
# 4     ...             -0.309842     0.665012      -0.000102     -0.008592
# ...   ...                   ...          ...            ...           ...
# 3988  ...             -0.754672     0.189341       0.511304      0.017560
# 3989  ...              0.936833     1.083443      -0.583714     -0.005475
# 3990  ...              0.416565     1.183910      -0.122027     -0.004456
# 3991  ...              0.272003     1.404428      -0.099327     -0.007536
# 3992  ...             -0.769949     0.302604      -0.217861     -0.011865
#
#       medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0          -0.025562           0.142376             -0.263196
# 1          -0.002270          -0.173628              0.037728
# 2           0.060763           0.030306              1.365530
# 3          -0.013044          -0.553518              0.269385
# 4          -0.002190          -0.588534              0.493010
# ...              ...                ...                   ...
# 3988       -0.040668           1.209315              0.189618
# 3989       -0.009577           0.188601             -0.225531
# 3990       -0.023344          -0.211972             -0.221623
# 3991       -0.028463          -0.020467             -0.110814
# 3992       -0.029365           0.410035             -0.410137
#
#       p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                       0.251708               -0.038958         1.237807
# 1                      -0.114574                0.549077        -0.031212
# 2                       0.577156                0.547318        -0.942817
# 3                      -0.201648                0.506757         0.267605
# 4                      -0.205573                0.753534         0.369862
# ...                          ...                     ...              ...
# 3988                   -0.023871               -1.992779         0.480138
# 3989                   -0.068249               -0.300657         0.228148
# 3990                   -0.018265                0.051901         1.076491
# 3991                   -0.065574                0.194104         0.845764
# 3992                   -0.117009               -0.671180         0.206791
#
# [3993 rows x 121 columns]

# %%
print(list(s4_val.columns))
# Out:
# ['ID', 'Pulsating', 'frequency', 'amplitudeRV', 'offsetRV', 'refepochRV', 'phase', 'CARMENES_source_idx', 'CARMENES_Ref_star', 'all_times_nhist_numpeaks', 'all_times_nhist_peak1_bin', 'all_times_nhist_peak2_bin', 'all_times_nhist_peak3_bin', 'all_times_nhist_peak4_bin', 'all_times_nhist_peak_1_to_2', 'all_times_nhist_peak_1_to_3', 'all_times_nhist_peak_1_to_4', 'all_times_nhist_peak_2_to_3', 'all_times_nhist_peak_2_to_4', 'all_times_nhist_peak_3_to_4', 'all_times_nhist_peak_val', 'avg_double_to_single_step', 'avg_err', 'avgt', 'cad_probs_1', 'cad_probs_10', 'cad_probs_20', 'cad_probs_30', 'cad_probs_40', 'cad_probs_50', 'cad_probs_100', 'cad_probs_500', 'cad_probs_1000', 'cad_probs_5000', 'cad_probs_10000', 'cad_probs_50000', 'cad_probs_100000', 'cad_probs_500000', 'cad_probs_1000000', 'cad_probs_5000000', 'cad_probs_10000000', 'cads_avg', 'cads_med', 'cads_std', 'mean', 'med_double_to_single_step', 'med_err', 'n_epochs', 'std_double_to_single_step', 'std_err', 'total_time', 'amplitude', 'flux_percentile_ratio_mid20', 'flux_percentile_ratio_mid35', 'flux_percentile_ratio_mid50', 'flux_percentile_ratio_mid65', 'flux_percentile_ratio_mid80', 'max_slope', 'maximum', 'median', 'median_absolute_deviation', 'minimum', 'percent_amplitude', 'percent_beyond_1_std', 'percent_close_to_median', 'percent_difference_flux_percentile', 'period_fast', 'qso_log_chi2_qsonu', 'qso_log_chi2nuNULL_chi2nu', 'skew', 'std', 'stetson_j', 'stetson_k', 'weighted_average', 'fold2P_slope_10percentile', 'fold2P_slope_90percentile', 'freq1_amplitude1', 'freq1_amplitude2', 'freq1_amplitude3', 'freq1_amplitude4', 'freq1_freq', 'freq1_lambda', 'freq1_rel_phase2', 'freq1_rel_phase3', 'freq1_rel_phase4', 'freq1_signif', 'freq2_amplitude1', 'freq2_amplitude2', 'freq2_amplitude3', 'freq2_amplitude4', 'freq2_freq', 'freq2_rel_phase2', 'freq2_rel_phase3', 'freq2_rel_phase4', 'freq3_amplitude1', 'freq3_amplitude2', 'freq3_amplitude3', 'freq3_amplitude4', 'freq3_freq', 'freq3_rel_phase2', 'freq3_rel_phase3', 'freq3_rel_phase4', 'freq_amplitude_ratio_21', 'freq_amplitude_ratio_31', 'freq_frequency_ratio_21', 'freq_frequency_ratio_31', 'freq_model_max_delta_mags', 'freq_model_min_delta_mags', 'freq_model_phi1_phi2', 'freq_n_alias', 'freq_signif_ratio_21', 'freq_signif_ratio_31', 'freq_varrat', 'freq_y_offset', 'linear_trend', 'medperc90_2p_p', 'p2p_scatter_2praw', 'p2p_scatter_over_mad', 'p2p_scatter_pfold_over_mad', 'p2p_ssqr_diff_over_var', 'scatter_res_raw']

# %% [markdown]
# ###  Read the CARMENES subsample data

# %%
carm = pd.read_csv(CARMENES_IN, sep=',', decimal='.')
carm
# Out:
#            Karmn  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0     J23505-095                  0.205178                  -0.570279
# 1     J23492+024                 -0.732202                  -0.712088
# 2     J23431+365                  0.517637                  -0.073948
# 3     J23419+441                  0.205178                   1.415047
# 4     J23381-162                 -0.107282                  -0.357566
# ..           ...                       ...                        ...
# 228   J00184+440                  1.142557                  -0.782993
# 229   J00183+440                  0.205178                  -0.570279
# 230  J00162+198E                  1.455017                  -0.215757
# 231   J00067-075                 -1.044662                   0.776906
# 232   J00051+457                  0.830097                  -1.137515
#
#      all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                     0.102548                  -0.937841
# 1                    -0.352490                  -0.029602
# 2                     0.633426                   1.786876
# 3                     0.330067                   1.181383
# 4                    -0.807528                  -0.635095
# ..                         ...                        ...
# 228                  -0.731688                  -1.164901
# 229                  -0.124971                  -0.029602
# 230                   0.178388                   0.727264
# 231                   0.481747                  -0.635095
# 232                   0.330067                  -0.180975
#
#      all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                     0.375123                    -0.538868
# 1                     0.452062                    -0.327090
# 2                    -1.009783                    -0.530743
# 3                    -1.009783                    -0.267795
# 4                     1.452272                    -0.010941
# ..                         ...                          ...
# 228                  -1.779174                    -0.638288
# 229                  -0.009573                     5.974603
# 230                  -1.009783                    -0.638288
# 231                   1.452272                    -0.271944
# 232                  -1.548357                    -0.018882
#
#      all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                      -0.683950                     0.963624
# 1                      -0.312174                     1.382266
# 2                      -0.698876                    -0.615420
# 3                      -0.401839                    -0.534849
# 4                       0.893571                     0.260497
# ..                           ...                          ...
# 228                    -0.632154                    -0.729271
# 229                     3.848480                     2.752565
# 230                    -0.645770                    -0.650724
# 231                    -0.255353                    -0.340739
# 232                    -0.195827                     0.015235
#
#      all_times_nhist_peak_2_to_3  ...  freq_signif_ratio_31  freq_varrat  \
# 0                      -0.495737  ...             -1.224593     0.375234
# 1                      -0.135084  ...             -2.085847     1.704012
# 2                      -0.528415  ...              0.220901    -0.980754
# 3                      -0.323011  ...             -1.875500     0.357589
# 4                       1.064851  ...             -0.748389     0.907884
# ..                           ...  ...                   ...          ...
# 228                    -0.298703  ...             -2.414100     0.391792
# 229                    -0.279287  ...             -2.683037     0.329324
# 230                    -0.323011  ...             -0.377701    -1.007479
# 231                    -0.111941  ...              0.535083     0.943346
# 232                    -0.270894  ...             -0.129863     0.527799
#
#      freq_y_offset  linear_trend  medperc90_2p_p  p2p_scatter_2praw  \
# 0         2.177405      0.038241       -0.007191           1.954330
# 1        -4.034985      0.003083       -0.020609           0.663629
# 2         0.372899      0.003590       -0.021224          -0.824111
# 3         0.817097     -0.017334       -0.020135           0.580317
# 4        -0.169309      0.008196       -0.017682           0.696254
# ..             ...           ...             ...                ...
# 228      -0.375132      0.024843       -0.020359           3.991311
# 229      -0.084762     -0.007546       -0.022694           1.122675
# 230      -1.456254      0.033312        0.052000           0.151270
# 231      -0.096890     -0.020070       -0.027295           1.539187
# 232      -0.081200      0.012105       -0.017483          -0.390045
#
#      p2p_scatter_over_mad  p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  \
# 0               -0.711851                   -0.142823               -2.452548
# 1               -0.697608                   -0.249360               -1.881067
# 2               -0.427596                   -0.448866               -0.437768
# 3               -0.710630                   -0.208997               -1.996610
# 4               -0.378200                   -0.098799               -0.068227
# ..                    ...                         ...                     ...
# 228             -0.772912                    0.053760               -3.177844
# 229             -1.010299                   -0.427458               -3.290765
# 230              0.487492                    0.227423               -0.913661
# 231             -0.336831                    0.130348               -1.344769
# 232              0.287263                    0.144621               -0.005296
#
#      scatter_res_raw
# 0           0.223693
# 1           1.582213
# 2          -1.022645
# 3           0.580664
# 4           0.267257
# ..               ...
# 228         1.308460
# 229         0.321142
# 230        -0.749305
# 231         0.805214
# 232         0.675452
#
# [233 rows x 113 columns]

# %% [markdown]
# #### Extract the _cesium_ feature list

# %%
cs_f_list = list(s4_tr.drop(columns=S4_ADD_COLUMNS).columns)
print(cs_f_list)
# Out:
# ['all_times_nhist_numpeaks', 'all_times_nhist_peak1_bin', 'all_times_nhist_peak2_bin', 'all_times_nhist_peak3_bin', 'all_times_nhist_peak4_bin', 'all_times_nhist_peak_1_to_2', 'all_times_nhist_peak_1_to_3', 'all_times_nhist_peak_1_to_4', 'all_times_nhist_peak_2_to_3', 'all_times_nhist_peak_2_to_4', 'all_times_nhist_peak_3_to_4', 'all_times_nhist_peak_val', 'avg_double_to_single_step', 'avg_err', 'avgt', 'cad_probs_1', 'cad_probs_10', 'cad_probs_20', 'cad_probs_30', 'cad_probs_40', 'cad_probs_50', 'cad_probs_100', 'cad_probs_500', 'cad_probs_1000', 'cad_probs_5000', 'cad_probs_10000', 'cad_probs_50000', 'cad_probs_100000', 'cad_probs_500000', 'cad_probs_1000000', 'cad_probs_5000000', 'cad_probs_10000000', 'cads_avg', 'cads_med', 'cads_std', 'mean', 'med_double_to_single_step', 'med_err', 'n_epochs', 'std_double_to_single_step', 'std_err', 'total_time', 'amplitude', 'flux_percentile_ratio_mid20', 'flux_percentile_ratio_mid35', 'flux_percentile_ratio_mid50', 'flux_percentile_ratio_mid65', 'flux_percentile_ratio_mid80', 'max_slope', 'maximum', 'median', 'median_absolute_deviation', 'minimum', 'percent_amplitude', 'percent_beyond_1_std', 'percent_close_to_median', 'percent_difference_flux_percentile', 'period_fast', 'qso_log_chi2_qsonu', 'qso_log_chi2nuNULL_chi2nu', 'skew', 'std', 'stetson_j', 'stetson_k', 'weighted_average', 'fold2P_slope_10percentile', 'fold2P_slope_90percentile', 'freq1_amplitude1', 'freq1_amplitude2', 'freq1_amplitude3', 'freq1_amplitude4', 'freq1_freq', 'freq1_lambda', 'freq1_rel_phase2', 'freq1_rel_phase3', 'freq1_rel_phase4', 'freq1_signif', 'freq2_amplitude1', 'freq2_amplitude2', 'freq2_amplitude3', 'freq2_amplitude4', 'freq2_freq', 'freq2_rel_phase2', 'freq2_rel_phase3', 'freq2_rel_phase4', 'freq3_amplitude1', 'freq3_amplitude2', 'freq3_amplitude3', 'freq3_amplitude4', 'freq3_freq', 'freq3_rel_phase2', 'freq3_rel_phase3', 'freq3_rel_phase4', 'freq_amplitude_ratio_21', 'freq_amplitude_ratio_31', 'freq_frequency_ratio_21', 'freq_frequency_ratio_31', 'freq_model_max_delta_mags', 'freq_model_min_delta_mags', 'freq_model_phi1_phi2', 'freq_n_alias', 'freq_signif_ratio_21', 'freq_signif_ratio_31', 'freq_varrat', 'freq_y_offset', 'linear_trend', 'medperc90_2p_p', 'p2p_scatter_2praw', 'p2p_scatter_over_mad', 'p2p_scatter_pfold_over_mad', 'p2p_ssqr_diff_over_var', 'scatter_res_raw']

# %% [markdown]
# ## Define and train the imputers

# %% [markdown]
# ### Imputer for TRAINING S4 sample

# %%
fit_data_s4_tr = s4_tr[cs_f_list].copy()
fit_data_s4_tr.head()
# Out:
#    all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0                  0.205178                  -0.570279
# 1                  0.205178                  -0.570279
# 2                  0.205178                  -0.570279
# 3                  0.205178                  -0.570279
# 4                  0.205178                  -0.570279
#
#    all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                   0.102548                  -0.937841
# 1                   0.102548                  -0.937841
# 2                   0.102548                  -0.937841
# 3                   0.102548                  -0.937841
# 4                   0.102548                  -0.937841
#
#    all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                   0.375123                    -0.538868
# 1                   0.375123                    -0.538868
# 2                   0.375123                    -0.538868
# 3                   0.375123                    -0.538868
# 4                   0.375123                    -0.538868
#
#    all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                     -0.68395                     0.963624
# 1                     -0.68395                     0.963624
# 2                     -0.68395                     0.963624
# 3                     -0.68395                     0.963624
# 4                     -0.68395                     0.963624
#
#    all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# 0                    -0.495737                     2.096091  ...
# 1                    -0.495737                     2.096091  ...
# 2                    -0.495737                     2.096091  ...
# 3                    -0.495737                     2.096091  ...
# 4                    -0.495737                     2.096091  ...
#
#    freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0             -0.908970     0.541171      -0.669931     -0.015526
# 1             -0.725712     0.832929       0.631644     -0.009818
# 2             -0.411204     0.857062       0.541050     -0.005791
# 3             -0.022857     1.028396      -0.061844     -0.002265
# 4             -0.272705     0.962090      -0.223832     -0.008516
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0       -0.019047          -0.007352             -0.442166
# 1       -0.021695           0.552345             -0.429826
# 2       -0.035445           0.013431             -0.327874
# 3       -0.031985           0.275371             -0.217636
# 4       -0.043389          -0.593592              0.261842
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                   -0.134743               -0.219987         0.356795
# 1                    0.007825               -0.005592         0.720584
# 2                   -0.179274               -0.090747         0.234164
# 3                    0.168502                0.170924         0.373533
# 4                   -0.171281                0.590502         1.231367
#
# [5 rows x 112 columns]

# %%
imputer_s4_tr = KNNImputer(weights='distance')
imputer_s4_tr.fit(fit_data_s4_tr)
# Out:
# KNNImputer(weights='distance')

# %% [markdown]
# #### Save the trained imputer (TRAINING S4 sample)

# %%
pickle.dump(imputer_s4_tr, open(TRAIN_S4B_IMP_FILE, 'wb'))

# %% [markdown]
# ### Imputer for VALIDATION S4 sample

# %%
fit_data_s4_val = s4_val[cs_f_list].copy()
fit_data_s4_val.head()
# Out:
#    all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0                  0.517637                  -1.137515
# 1                 -0.419742                   0.280575
# 2                  0.517637                  -1.137515
# 3                  0.830097                  -0.357566
# 4                  0.830097                  -0.570279
#
#    all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                  -0.580009                  -1.089214
# 1                   0.860945                   0.727264
# 2                   0.405907                   0.575891
# 3                  -0.049131                  -1.240587
# 4                   0.330067                  -0.256662
#
#    all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                   0.144305                     0.266356
# 1                   1.606150                    -0.585530
# 2                   1.760028                    -0.638288
# 3                  -1.240600                    -0.268982
# 4                  -0.240391                    -0.573261
#
#    all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                    -0.199470                    -0.372978
# 1                    -0.662208                    -0.547754
# 2                    -0.760832                    -0.827243
# 3                    -0.367065                    -0.512030
# 4                    -0.703301                    -0.789417
#
#    all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# 0                    -0.484844                    -0.634592  ...
# 1                    -0.411041                    -0.317319  ...
# 2                    -0.528415                    -0.752524  ...
# 3                    -0.272801                    -0.511149  ...
# 4                    -0.494181                    -0.730580  ...
#
#    freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0             -0.134573     1.418486       0.042013     -0.009545
# 1              0.125231     0.579019       1.116863      0.000807
# 2              1.350668    -0.929902      -0.047202      0.016980
# 3             -0.058875     0.312563       0.586087     -0.005898
# 4             -0.309842     0.665012      -0.000102     -0.008592
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0       -0.025562           0.142376             -0.263196
# 1       -0.002270          -0.173628              0.037728
# 2        0.060763           0.030306              1.365530
# 3       -0.013044          -0.553518              0.269385
# 4       -0.002190          -0.588534              0.493010
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                    0.251708               -0.038958         1.237807
# 1                   -0.114574                0.549077        -0.031212
# 2                    0.577156                0.547318        -0.942817
# 3                   -0.201648                0.506757         0.267605
# 4                   -0.205573                0.753534         0.369862
#
# [5 rows x 112 columns]

# %%
imputer_s4_val = KNNImputer(weights='distance')
imputer_s4_val.fit(fit_data_s4_val)
# Out:
# KNNImputer(weights='distance')

# %% [markdown]
# #### Save the trained imputer (VALIDATION S4 sample)

# %%
pickle.dump(imputer_s4_val, open(VAL_S4B_IMP_FILE, 'wb'))

# %% [markdown]
# ### Imputer for CARMENES subsample

# %%
fit_data_carm = carm[cs_f_list].copy()
fit_data_carm.head()
# Out:
#    all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0                  0.205178                  -0.570279
# 1                 -0.732202                  -0.712088
# 2                  0.517637                  -0.073948
# 3                  0.205178                   1.415047
# 4                 -0.107282                  -0.357566
#
#    all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                   0.102548                  -0.937841
# 1                  -0.352490                  -0.029602
# 2                   0.633426                   1.786876
# 3                   0.330067                   1.181383
# 4                  -0.807528                  -0.635095
#
#    all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                   0.375123                    -0.538868
# 1                   0.452062                    -0.327090
# 2                  -1.009783                    -0.530743
# 3                  -1.009783                    -0.267795
# 4                   1.452272                    -0.010941
#
#    all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                    -0.683950                     0.963624
# 1                    -0.312174                     1.382266
# 2                    -0.698876                    -0.615420
# 3                    -0.401839                    -0.534849
# 4                     0.893571                     0.260497
#
#    all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# 0                    -0.495737                     2.096091  ...
# 1                    -0.135084                     2.224898  ...
# 2                    -0.528415                    -0.476040  ...
# 3                    -0.323011                    -0.543324  ...
# 4                     1.064851                     0.268721  ...
#
#    freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0             -1.224593     0.375234       2.177405      0.038241
# 1             -2.085847     1.704012      -4.034985      0.003083
# 2              0.220901    -0.980754       0.372899      0.003590
# 3             -1.875500     0.357589       0.817097     -0.017334
# 4             -0.748389     0.907884      -0.169309      0.008196
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0       -0.007191           1.954330             -0.711851
# 1       -0.020609           0.663629             -0.697608
# 2       -0.021224          -0.824111             -0.427596
# 3       -0.020135           0.580317             -0.710630
# 4       -0.017682           0.696254             -0.378200
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                   -0.142823               -2.452548         0.223693
# 1                   -0.249360               -1.881067         1.582213
# 2                   -0.448866               -0.437768        -1.022645
# 3                   -0.208997               -1.996610         0.580664
# 4                   -0.098799               -0.068227         0.267257
#
# [5 rows x 112 columns]

# %%
imputer_carm = KNNImputer(weights='distance')
imputer_carm.fit(fit_data_carm)
# Out:
# KNNImputer(weights='distance')

# %% [markdown]
# #### Save the trained imputer (CARMENES subsample)

# %%
pickle.dump(imputer_carm, open(CARMENES_IMP_FILE, 'wb'))

# %% [markdown]
# ## Reload and apply the imputers

# %% [markdown]
# ### Imputer for TRAINING S4

# %% [markdown]
# #### Reload imputer

# %%
ld_imputer_s4_tr = pickle.load(open(TRAIN_S4B_IMP_FILE, 'rb'))
ld_imputer_s4_tr
# Out:
# KNNImputer(weights='distance')

# %% [markdown]
# #### Impute the features in TRAINING S4 sample

# %%
imputed_s4_tr = s4.copy()
imputed_s4_tr.head()
# Out:
#                  ID  Pulsating  frequency  amplitudeRV  offsetRV  refepochRV  \
# 0  ALT-B_Star-00000       True        8.0          0.1       0.0         0.0
# 1  ALT-B_Star-00001      False        0.0          0.0       0.0         0.0
# 2  ALT-B_Star-00002       True        8.0          0.1       0.0         0.0
# 3  ALT-B_Star-00003      False        0.0          0.0       0.0         0.0
# 4  ALT-B_Star-00004       True        8.0          0.1       0.0         0.0
#
#    phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0   0.00                    0        J23505-095                  0.205178
# 1   0.00                    0        J23505-095                  0.205178
# 2   0.25                    0        J23505-095                  0.205178
# 3   0.00                    0        J23505-095                  0.205178
# 4   0.50                    0        J23505-095                  0.205178
#
#    ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0  ...             -0.908970     0.541171      -0.669931     -0.015526
# 1  ...             -0.725712     0.832929       0.631644     -0.009818
# 2  ...             -0.411204     0.857062       0.541050     -0.005791
# 3  ...             -0.022857     1.028396      -0.061844     -0.002265
# 4  ...             -0.272705     0.962090      -0.223832     -0.008516
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0       -0.019047          -0.007352             -0.442166
# 1       -0.021695           0.552345             -0.429826
# 2       -0.035445           0.013431             -0.327874
# 3       -0.031985           0.275371             -0.217636
# 4       -0.043389          -0.593592              0.261842
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                   -0.134743               -0.219987         0.356795
# 1                    0.007825               -0.005592         0.720584
# 2                   -0.179274               -0.090747         0.234164
# 3                    0.168502                0.170924         0.373533
# 4                   -0.171281                0.590502         1.231367
#
# [5 rows x 121 columns]

# %%
imputed_s4_tr.loc[:, cs_f_list] = ld_imputer_s4_tr.transform(imputed_s4_tr.loc[:, cs_f_list])
imputed_s4_tr.head()
# Out:
#                  ID  Pulsating  frequency  amplitudeRV  offsetRV  refepochRV  \
# 0  ALT-B_Star-00000       True        8.0          0.1       0.0         0.0
# 1  ALT-B_Star-00001      False        0.0          0.0       0.0         0.0
# 2  ALT-B_Star-00002       True        8.0          0.1       0.0         0.0
# 3  ALT-B_Star-00003      False        0.0          0.0       0.0         0.0
# 4  ALT-B_Star-00004       True        8.0          0.1       0.0         0.0
#
#    phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0   0.00                    0        J23505-095                  0.205178
# 1   0.00                    0        J23505-095                  0.205178
# 2   0.25                    0        J23505-095                  0.205178
# 3   0.00                    0        J23505-095                  0.205178
# 4   0.50                    0        J23505-095                  0.205178
#
#    ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0  ...             -0.908970     0.541171      -0.669931     -0.015526
# 1  ...             -0.725712     0.832929       0.631644     -0.009818
# 2  ...             -0.411204     0.857062       0.541050     -0.005791
# 3  ...             -0.022857     1.028396      -0.061844     -0.002265
# 4  ...             -0.272705     0.962090      -0.223832     -0.008516
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0       -0.019047          -0.007352             -0.442166
# 1       -0.021695           0.552345             -0.429826
# 2       -0.035445           0.013431             -0.327874
# 3       -0.031985           0.275371             -0.217636
# 4       -0.043389          -0.593592              0.261842
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                   -0.134743               -0.219987         0.356795
# 1                    0.007825               -0.005592         0.720584
# 2                   -0.179274               -0.090747         0.234164
# 3                    0.168502                0.170924         0.373533
# 4                   -0.171281                0.590502         1.231367
#
# [5 rows x 121 columns]

# %% [markdown]
# #### Check correct imputing

# %%
s4_tr[cs_f_list].describe().loc[['count', 'mean', 'std', '50%']]
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count              3.728000e+04               3.728000e+04
# mean              -4.574309e-17              -1.036843e-16
# std                1.000013e+00               1.000013e+00
# 50%               -1.072824e-01              -3.575656e-01
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count               3.680000e+04               3.600000e+04
# mean                6.255865e-17              -4.105358e-17
# std                 1.000014e+00               1.000014e+00
# 50%                -2.008103e-01              -2.960186e-02
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count               3.472000e+04                 3.680000e+04
# mean               -3.929269e-17                 9.267949e-17
# std                 1.000014e+00                 1.000014e+00
# 50%                -9.573079e-03                -2.887663e-01
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                 3.600000e+04                 3.472000e+04
# mean                 -3.315866e-17                 1.015061e-16
# std                   1.000014e+00                 1.000014e+00
# 50%                  -2.775723e-01                -2.976853e-01
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                 3.600000e+04                 3.472000e+04  ...
# mean                  2.178998e-16                 5.239025e-17  ...
# std                   1.000014e+00                 1.000014e+00  ...
# 50%                  -2.669921e-01                -2.917182e-01  ...
#
#        freq_signif_ratio_31   freq_varrat  freq_y_offset  linear_trend  \
# count          3.726400e+04  3.726400e+04   3.726400e+04  3.726400e+04
# mean           2.745764e-17 -2.684747e-16   6.101698e-18  2.230933e-17
# std            1.000013e+00  1.000013e+00   1.000013e+00  1.000013e+00
# 50%           -3.934120e-02 -3.299619e-02   6.336377e-03 -5.353901e-03
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count    3.677800e+04       3.728000e+04          3.728000e+04
# mean     1.816059e-17      -8.729307e-17         -9.453573e-17
# std      1.000014e+00       1.000013e+00          1.000013e+00
# 50%     -1.708591e-02      -1.141285e-01         -1.272274e-01
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                3.728000e+04            3.728000e+04     3.726400e+04
# mean                 7.738207e-17           -5.565410e-16    -1.830509e-16
# std                  1.000013e+00            1.000013e+00     1.000013e+00
# 50%                 -6.110645e-02           -1.001276e-01    -1.495433e-01
#
# [4 rows x 112 columns]

# %%
imputed_s4_tr[cs_f_list].describe().loc[['count', 'mean', 'std', '50%']]
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count              3.728000e+04               3.728000e+04
# mean              -4.574309e-17              -1.036843e-16
# std                1.000013e+00               1.000013e+00
# 50%               -1.072824e-01              -3.575656e-01
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count               37280.000000               37280.000000
# mean                    0.022370                  -0.005005
# std                     1.013986                   0.994641
# 50%                    -0.200810                  -0.029602
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count               37280.000000                 37280.000000
# mean                    0.015581                     0.004847
# std                     0.988737                     0.996300
# 50%                    -0.009573                    -0.288766
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                 37280.000000                 37280.000000
# mean                      0.015257                     0.011455
# std                       0.990477                     0.979001
# 50%                      -0.277572                    -0.297685
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                 37280.000000                 37280.000000  ...
# mean                      0.023351                     0.017819  ...
# std                       0.996694                     0.981413  ...
# 50%                      -0.240850                    -0.291718  ...
#
#        freq_signif_ratio_31   freq_varrat  freq_y_offset  linear_trend  \
# count          37280.000000  37280.000000   37280.000000  37280.000000
# mean               0.001183     -0.000016       0.000046      0.000108
# std                1.001618      0.999856       0.999839      1.001360
# 50%               -0.038922     -0.032865       0.006336     -0.005353
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count    37280.000000       3.728000e+04          3.728000e+04
# mean         0.002971      -8.729307e-17         -9.453573e-17
# std          1.051442       1.000013e+00          1.000013e+00
# 50%         -0.016790      -1.141285e-01         -1.272274e-01
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                3.728000e+04            3.728000e+04     37280.000000
# mean                 7.738207e-17           -5.565410e-16         0.000476
# std                  1.000013e+00            1.000013e+00         1.000410
# 50%                 -6.110645e-02           -1.001276e-01        -0.149042
#
# [4 rows x 112 columns]

# %%
s4_tr.isna().sum()[s4_tr.isna().sum() > 0]
# Out:
# all_times_nhist_peak2_bin       480
# all_times_nhist_peak3_bin      1280
# all_times_nhist_peak4_bin      2560
# all_times_nhist_peak_1_to_2     480
# all_times_nhist_peak_1_to_3    1280
# all_times_nhist_peak_1_to_4    2560
# all_times_nhist_peak_2_to_3    1280
# all_times_nhist_peak_2_to_4    2560
# all_times_nhist_peak_3_to_4    2560
# fold2P_slope_10percentile       485
# fold2P_slope_90percentile       485
# freq1_amplitude1                 16
# freq1_amplitude2                 16
# freq1_amplitude3                 16
# freq1_amplitude4                 16
# freq1_rel_phase2                 16
# freq1_rel_phase3                 16
# freq1_rel_phase4                 16
# freq2_amplitude1                 16
# freq2_amplitude2                 16
# freq2_amplitude3                 16
# freq2_amplitude4                 16
# freq2_rel_phase2                 16
# freq2_rel_phase3                 16
# freq2_rel_phase4                 16
# freq3_amplitude1                 16
# freq3_amplitude2                 16
# freq3_amplitude3                 16
# freq3_amplitude4                 16
# freq3_rel_phase2                 16
# freq3_rel_phase3                 16
# freq3_rel_phase4                 16
# freq_amplitude_ratio_21          16
# freq_amplitude_ratio_31          16
# freq_model_max_delta_mags        16
# freq_model_min_delta_mags        16
# freq_signif_ratio_21             16
# freq_signif_ratio_31             16
# freq_varrat                      16
# freq_y_offset                    16
# linear_trend                     16
# medperc90_2p_p                  502
# scatter_res_raw                  16
# dtype: int64

# %%
imputed_s4_tr.isna().sum()[imputed_s4_tr.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
s4_tr[impute_f_list].describe()
# Out:
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count               3.680000e+04               3.600000e+04
# mean                6.255865e-17              -4.105358e-17
# std                 1.000014e+00               1.000014e+00
# min                -1.565925e+00              -1.846080e+00
# 25%                -8.833674e-01              -7.864677e-01
# 50%                -2.008103e-01              -2.960186e-02
# 75%                 7.851056e-01               8.029505e-01
# max                 2.150220e+00               1.862563e+00
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count               3.472000e+04                 3.680000e+04
# mean               -3.929269e-17                 9.267949e-17
# std                 1.000014e+00                 1.000014e+00
# min                -2.009992e+00                -6.382879e-01
# 25%                -9.328434e-01                -5.388684e-01
# 50%                -9.573079e-03                -2.887663e-01
# 75%                 8.367580e-01                 1.106870e-01
# max                 1.760028e+00                 8.153267e+00
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                 3.600000e+04                 3.472000e+04
# mean                 -3.315866e-17                 1.015061e-16
# std                   1.000014e+00                 1.000014e+00
# min                  -7.608323e-01                -8.272426e-01
# 25%                  -4.943731e-01                -5.624640e-01
# 50%                  -2.775723e-01                -2.976853e-01
# 75%                   6.697425e-02                 2.318719e-01
# max                   9.187762e+00                 6.586559e+00
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  \
# count                 3.600000e+04                 3.472000e+04
# mean                  2.178998e-16                 5.239025e-17
# std                   1.000014e+00                 1.000014e+00
# min                  -5.284149e-01                -7.525235e-01
# 25%                  -4.941809e-01                -5.356740e-01
# 50%                  -2.669921e-01                -2.917182e-01
# 75%                   1.130764e-01                 1.690871e-01
# max                   1.150672e+01                 6.961699e+00
#
#        all_times_nhist_peak_3_to_4  fold2P_slope_10percentile  ...  \
# count                 3.472000e+04               3.679500e+04  ...
# mean                  2.521281e-16              -3.398710e-17  ...
# std                   1.000014e+00               1.000014e+00  ...
# min                  -7.034631e-01              -1.047253e+02  ...
# 25%                  -6.330852e-01              -9.534969e-02  ...
# 50%                  -3.813333e-01               3.492266e-01  ...
# 75%                   3.320710e-01               3.909024e-01  ...
# max                   5.560173e+00               5.043307e-01  ...
#
#        freq_amplitude_ratio_31  freq_model_max_delta_mags  \
# count             3.726400e+04               3.726400e+04
# mean              4.347460e-17               5.224579e-17
# std               1.000013e+00               1.000013e+00
# min              -2.164458e-02              -7.337622e-03
# 25%              -2.164458e-02              -7.337576e-03
# 50%              -2.164458e-02              -7.337493e-03
# 75%              -2.164458e-02              -7.337345e-03
# max               1.517005e+02               1.815094e+02
#
#        freq_model_min_delta_mags  freq_signif_ratio_21  freq_signif_ratio_31  \
# count               3.726400e+04          3.726400e+04          3.726400e+04
# mean                5.110172e-17         -8.511869e-16          2.745764e-17
# std                 1.000013e+00          1.000013e+00          1.000013e+00
# min                -8.894588e-03         -7.160046e+00         -6.306264e+00
# 25%                -8.894376e-03         -5.211363e-01         -5.613034e-01
# 50%                -8.894011e-03         -2.816920e-02         -3.934120e-02
# 75%                -8.893426e-03          4.811128e-01          5.166123e-01
# max                 1.244601e+02          8.296186e+00          3.327655e+00
#
#         freq_varrat  freq_y_offset  linear_trend  scatter_res_raw  \
# count  3.726400e+04   3.726400e+04  3.726400e+04     3.726400e+04
# mean  -2.684747e-16   6.101698e-18  2.230933e-17    -1.830509e-16
# std    1.000013e+00   1.000013e+00  1.000013e+00     1.000013e+00
# min   -1.889190e+00  -6.489361e+00 -5.473265e+01    -1.345553e+00
# 25%   -8.982544e-01  -4.321774e-01 -1.037192e-02    -8.336991e-01
# 50%   -3.299619e-02   6.336377e-03 -5.353901e-03    -1.495433e-01
# 75%    8.490798e-01   4.297225e-01 -2.887420e-04     6.874313e-01
# max    2.181878e+00   8.600693e+00  4.287256e+01     4.010389e+01
#
#        std_double_to_single_step
# count               3.728000e+04
# mean                4.574309e-17
# std                 1.000013e+00
# min                -6.778085e-02
# 25%                -6.771991e-02
# 50%                -6.749057e-02
# 75%                -6.679420e-02
# max                 1.523114e+01
#
# [8 rows x 44 columns]

# %%
imputed_s4_tr[impute_f_list].describe()
# Out:
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count               37280.000000               37280.000000
# mean                    0.022370                  -0.005005
# std                     1.013986                   0.994641
# min                    -1.565925                  -1.846080
# 25%                    -0.883367                  -0.786468
# 50%                    -0.200810                  -0.029602
# 75%                     0.860945                   0.802951
# max                     2.150220                   1.862563
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count               37280.000000                 37280.000000
# mean                    0.015581                     0.004847
# std                     0.988737                     0.996300
# min                    -2.009992                    -0.638288
# 25%                    -0.855904                    -0.538425
# 50%                    -0.009573                    -0.288766
# 75%                     0.836758                     0.114528
# max                     1.760028                     8.153267
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                 37280.000000                 37280.000000
# mean                      0.015257                     0.011455
# std                       0.990477                     0.979001
# min                      -0.760832                    -0.827243
# 25%                      -0.492354                    -0.557650
# 50%                      -0.277572                    -0.297685
# 75%                       0.205688                     0.231872
# max                       9.187762                     6.586559
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  \
# count                 37280.000000                 37280.000000
# mean                      0.023351                     0.017819
# std                       0.996694                     0.981413
# min                      -0.528415                    -0.752524
# 25%                      -0.486313                    -0.522121
# 50%                      -0.240850                    -0.291718
# 75%                       0.190498                     0.169087
# max                      11.506715                     6.961699
#
#        all_times_nhist_peak_3_to_4  fold2P_slope_10percentile  ...  \
# count                 37280.000000               37280.000000  ...
# mean                      0.004510                   0.002958  ...
# std                       0.974633                   0.994538  ...
# min                      -0.703463                -104.725287  ...
# 25%                      -0.627077                  -0.085988  ...
# 50%                      -0.355483                   0.349134  ...
# 75%                       0.340476                   0.390902  ...
# max                       5.560173                   0.504331  ...
#
#        freq_amplitude_ratio_31  freq_model_max_delta_mags  \
# count             37280.000000               37280.000000
# mean                  0.000040                   0.002054
# std                   0.999818                   1.046046
# min                  -0.021645                  -0.007338
# 25%                  -0.021645                  -0.007338
# 50%                  -0.021645                  -0.007337
# 75%                  -0.021645                  -0.007337
# max                 151.700547                 181.509409
#
#        freq_model_min_delta_mags  freq_signif_ratio_21  freq_signif_ratio_31  \
# count               37280.000000          37280.000000          37280.000000
# mean                    0.001795              0.001218              0.001183
# std                     1.019847              1.001745              1.001618
# min                    -0.008895             -7.160046             -6.306264
# 25%                    -0.008894             -0.520969             -0.560841
# 50%                    -0.008894             -0.027760             -0.038922
# 75%                    -0.008893              0.482182              0.517508
# max                   124.460051              8.296186              3.327655
#
#         freq_varrat  freq_y_offset  linear_trend  scatter_res_raw  \
# count  37280.000000   37280.000000  37280.000000     37280.000000
# mean      -0.000016       0.000046      0.000108         0.000476
# std        0.999856       0.999839      1.001360         1.000410
# min       -1.889190      -6.489361    -54.732654        -1.345553
# 25%       -0.898124      -0.432064     -0.010372        -0.833620
# 50%       -0.032865       0.006336     -0.005353        -0.149042
# 75%        0.848637       0.429438     -0.000285         0.688447
# max        2.181878       8.600693     42.872563        40.103892
#
#        std_double_to_single_step
# count               3.728000e+04
# mean                4.574309e-17
# std                 1.000013e+00
# min                -6.778085e-02
# 25%                -6.771991e-02
# 50%                -6.749057e-02
# 75%                -6.679420e-02
# max                 1.523114e+01
#
# [8 rows x 44 columns]

# %% [markdown]
# Ok, now no feature has `NaN` value any longer, and the statistics remain similar for the imputed statistics. Although there are variations in the mean and standard deviation, both remain very close to 0 and 1 respectively (or in any case close to the value they had previously).
#
# For the non-imputed statistics, they remain equal.

# %% [markdown]
# #### Save the imputed TRAINING S4 sample dataset

# %%
imputed_s4_tr.to_csv(TRAIN_S4B_OUT, sep=',', decimal='.', index=False)

# %% [markdown]
# ### Imputer for VALIDATION S4

# %% [markdown]
# #### Reload imputer

# %%
ld_imputer_s4_val = pickle.load(open(VAL_S4B_IMP_FILE, 'rb'))
ld_imputer_s4_val
# Out:
# KNNImputer(weights='distance')

# %% [markdown]
# #### Impute the features in VALIDATION S4 sample

# %%
imputed_s4_val = s4_val.copy()
imputed_s4_val.head()
# Out:
#              ID  Pulsating  frequency  amplitudeRV  offsetRV    refepochRV  \
# 0  B_Star-00000      False        0.0          0.0       0.0  2.457432e+06
# 1  B_Star-00001      False        0.0          0.0       0.0  2.457487e+06
# 2  B_Star-00002      False        0.0          0.0       0.0  2.457417e+06
# 3  B_Star-00003      False        0.0          0.0       0.0  2.457431e+06
# 4  B_Star-00004      False        0.0          0.0       0.0  2.461026e+06
#
#    phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0    0.0                  116        J11511+352                  0.517637
# 1    0.0                   29        J20336+617                 -0.419742
# 2    0.0                  156        J08402+314                  0.517637
# 3    0.0                  180        J05421+124                  0.830097
# 4    0.0                   67        J17052-050                  0.830097
#
#    ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0  ...             -0.134573     1.418486       0.042013     -0.009545
# 1  ...              0.125231     0.579019       1.116863      0.000807
# 2  ...              1.350668    -0.929902      -0.047202      0.016980
# 3  ...             -0.058875     0.312563       0.586087     -0.005898
# 4  ...             -0.309842     0.665012      -0.000102     -0.008592
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0       -0.025562           0.142376             -0.263196
# 1       -0.002270          -0.173628              0.037728
# 2        0.060763           0.030306              1.365530
# 3       -0.013044          -0.553518              0.269385
# 4       -0.002190          -0.588534              0.493010
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                    0.251708               -0.038958         1.237807
# 1                   -0.114574                0.549077        -0.031212
# 2                    0.577156                0.547318        -0.942817
# 3                   -0.201648                0.506757         0.267605
# 4                   -0.205573                0.753534         0.369862
#
# [5 rows x 121 columns]

# %%
imputed_s4_val.loc[:, cs_f_list] = ld_imputer_s4_val.transform(imputed_s4_val.loc[:, cs_f_list])
imputed_s4_val.head()
# Out:
#              ID  Pulsating  frequency  amplitudeRV  offsetRV    refepochRV  \
# 0  B_Star-00000      False        0.0          0.0       0.0  2.457432e+06
# 1  B_Star-00001      False        0.0          0.0       0.0  2.457487e+06
# 2  B_Star-00002      False        0.0          0.0       0.0  2.457417e+06
# 3  B_Star-00003      False        0.0          0.0       0.0  2.457431e+06
# 4  B_Star-00004      False        0.0          0.0       0.0  2.461026e+06
#
#    phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0    0.0                  116        J11511+352                  0.517637
# 1    0.0                   29        J20336+617                 -0.419742
# 2    0.0                  156        J08402+314                  0.517637
# 3    0.0                  180        J05421+124                  0.830097
# 4    0.0                   67        J17052-050                  0.830097
#
#    ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0  ...             -0.134573     1.418486       0.042013     -0.009545
# 1  ...              0.125231     0.579019       1.116863      0.000807
# 2  ...              1.350668    -0.929902      -0.047202      0.016980
# 3  ...             -0.058875     0.312563       0.586087     -0.005898
# 4  ...             -0.309842     0.665012      -0.000102     -0.008592
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0       -0.025562           0.142376             -0.263196
# 1       -0.002270          -0.173628              0.037728
# 2        0.060763           0.030306              1.365530
# 3       -0.013044          -0.553518              0.269385
# 4       -0.002190          -0.588534              0.493010
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                    0.251708               -0.038958         1.237807
# 1                   -0.114574                0.549077        -0.031212
# 2                    0.577156                0.547318        -0.942817
# 3                   -0.201648                0.506757         0.267605
# 4                   -0.205573                0.753534         0.369862
#
# [5 rows x 121 columns]

# %% [markdown]
# #### Check correct imputing

# %%
s4_val[cs_f_list].describe().loc[['count', 'mean', 'std', '50%']]
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count               3993.000000                3993.000000
# mean                   0.004227                   0.000437
# std                    1.010121                   0.994044
# 50%                   -0.107282                  -0.357566
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count                3939.000000                3867.000000
# mean                    0.016774                   0.014123
# std                     1.007434                   1.004587
# 50%                    -0.200810                  -0.029602
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count                3728.000000                  3939.000000
# mean                   -0.006663                    -0.021442
# std                     1.004368                     0.969563
# 50%                    -0.086512                    -0.309973
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                  3867.000000                  3728.000000
# mean                      0.005803                     0.001576
# std                       1.026238                     1.006839
# 50%                      -0.277572                    -0.297685
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                  3867.000000                  3728.000000  ...
# mean                      0.024496                     0.017752  ...
# std                       1.052484                     1.045343  ...
# 50%                      -0.268383                    -0.291718  ...
#
#        freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# count           3987.000000  3987.000000    3987.000000   3987.000000
# mean               0.081534     0.026774       0.019621     -0.011142
# std                0.884413     1.008406       0.994507      0.774763
# 50%               -0.003054    -0.007826       0.006365     -0.005383
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count     3938.000000        3993.000000           3993.000000
# mean        -0.004974          -0.025440             -0.008408
# std          0.052022           0.947391              0.697579
# 50%         -0.017604          -0.128495             -0.125971
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                 3993.000000             3993.000000      3987.000000
# mean                    -0.016568                0.000833         0.004148
# std                      0.466829                0.974282         0.949807
# 50%                     -0.068249               -0.100736        -0.168325
#
# [4 rows x 112 columns]

# %%
imputed_s4_val[cs_f_list].describe().loc[['count', 'mean', 'std', '50%']]
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count               3993.000000                3993.000000
# mean                   0.004227                   0.000437
# std                    1.010121                   0.994044
# 50%                   -0.107282                  -0.357566
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count                3993.000000                3993.000000
# mean                    0.034947                   0.009940
# std                     1.015055                   0.996017
# 50%                    -0.200810                  -0.100236
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count                3993.000000                  3993.000000
# mean                    0.013156                    -0.014491
# std                     0.985942                     0.966574
# 50%                    -0.009573                    -0.288766
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                  3993.000000                  3993.000000
# mean                      0.018311                     0.011398
# std                       1.016337                     0.987415
# 50%                      -0.277572                    -0.297685
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                  3993.000000                  3993.000000  ...
# mean                      0.039985                     0.022895  ...
# std                       1.045123                     1.016448  ...
# 50%                      -0.240850                    -0.291718  ...
#
#        freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# count           3993.000000  3993.000000    3993.000000   3993.000000
# mean               0.086101     0.026586       0.019553     -0.015139
# std                0.891655     1.007851       0.993798      0.785755
# 50%               -0.000923    -0.003964       0.006410     -0.005400
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count     3993.000000        3993.000000           3993.000000
# mean        -0.004614          -0.025440             -0.008408
# std          0.051971           0.947391              0.697579
# 50%         -0.017261          -0.128495             -0.125971
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                 3993.000000             3993.000000      3993.000000
# mean                    -0.016568                0.000833         0.005616
# std                      0.466829                0.974282         0.950607
# 50%                     -0.068249               -0.100736        -0.166726
#
# [4 rows x 112 columns]

# %%
s4_val.isna().sum()[s4_val.isna().sum() > 0]
# Out:
# all_times_nhist_peak2_bin       54
# all_times_nhist_peak3_bin      126
# all_times_nhist_peak4_bin      265
# all_times_nhist_peak_1_to_2     54
# all_times_nhist_peak_1_to_3    126
# all_times_nhist_peak_1_to_4    265
# all_times_nhist_peak_2_to_3    126
# all_times_nhist_peak_2_to_4    265
# all_times_nhist_peak_3_to_4    265
# fold2P_slope_10percentile       49
# fold2P_slope_90percentile       49
# freq1_amplitude1                 6
# freq1_amplitude2                 6
# freq1_amplitude3                 6
# freq1_amplitude4                 6
# freq1_rel_phase2                 6
# freq1_rel_phase3                 6
# freq1_rel_phase4                 6
# freq2_amplitude1                 6
# freq2_amplitude2                 6
# freq2_amplitude3                 6
# freq2_amplitude4                 6
# freq2_rel_phase2                 6
# freq2_rel_phase3                 6
# freq2_rel_phase4                 6
# freq3_amplitude1                 6
# freq3_amplitude2                 6
# freq3_amplitude3                 6
# freq3_amplitude4                 6
# freq3_rel_phase2                 6
# freq3_rel_phase3                 6
# freq3_rel_phase4                 6
# freq_amplitude_ratio_21          6
# freq_amplitude_ratio_31          6
# freq_model_max_delta_mags        6
# freq_model_min_delta_mags        6
# freq_signif_ratio_21             6
# freq_signif_ratio_31             6
# freq_varrat                      6
# freq_y_offset                    6
# linear_trend                     6
# medperc90_2p_p                  55
# scatter_res_raw                  6
# dtype: int64

# %%
imputed_s4_val.isna().sum()[imputed_s4_val.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
s4_val[impute_f_list].describe()
# Out:
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count                3939.000000                3867.000000
# mean                    0.016774                   0.014123
# std                     1.007434                   1.004587
# min                    -1.565925                  -1.846080
# 25%                    -0.883367                  -0.786468
# 50%                    -0.200810                  -0.029602
# 75%                     0.785106                   0.878637
# max                     2.150220                   1.862563
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count                3728.000000                  3939.000000
# mean                   -0.006663                    -0.021442
# std                     1.004368                     0.969563
# min                    -2.009992                    -0.638288
# 25%                    -0.932843                    -0.545082
# 50%                    -0.086512                    -0.309973
# 75%                     0.836758                     0.092596
# max                     1.760028                     8.153267
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                  3867.000000                  3728.000000
# mean                      0.005803                     0.001576
# std                       1.026238                     1.006839
# min                      -0.760832                    -0.827243
# 25%                      -0.518420                    -0.562464
# 50%                      -0.277572                    -0.297685
# 75%                       0.138256                     0.231872
# max                       9.187762                     6.586559
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  \
# count                  3867.000000                  3728.000000
# mean                      0.024496                     0.017752
# std                       1.052484                     1.045343
# min                      -0.528415                    -0.752524
# 25%                      -0.495737                    -0.535674
# 50%                      -0.268383                    -0.291718
# 75%                       0.125142                     0.169087
# max                      11.506715                     6.961699
#
#        all_times_nhist_peak_3_to_4  fold2P_slope_10percentile  ...  \
# count                  3728.000000                3944.000000  ...
# mean                     -0.007400                   0.023494  ...
# std                       0.977518                   0.807887  ...
# min                      -0.703463                 -18.685852  ...
# 25%                      -0.633085                  -0.065811  ...
# 50%                      -0.381333                   0.353264  ...
# 75%                       0.332071                   0.390902  ...
# max                       5.560173                   0.514521  ...
#
#        freq_amplitude_ratio_31  freq_model_max_delta_mags  \
# count              3987.000000               3.987000e+03
# mean                 -0.015434              -7.337412e-03
# std                   0.137604               2.550330e-07
# min                  -0.021645              -7.337622e-03
# 25%                  -0.021645              -7.337577e-03
# 50%                  -0.021645              -7.337496e-03
# 75%                  -0.021645              -7.337354e-03
# max                   7.168335              -7.335418e-03
#
#        freq_model_min_delta_mags  freq_signif_ratio_21  freq_signif_ratio_31  \
# count               3.987000e+03           3987.000000           3987.000000
# mean               -8.893802e-03              0.083113              0.081534
# std                 7.347424e-07              0.875585              0.884413
# min                -8.894588e-03             -5.045137             -4.476570
# 25%                -8.894375e-03             -0.448198             -0.491335
# 50%                -8.894010e-03              0.014706             -0.003054
# 75%                -8.893411e-03              0.508181              0.527522
# max                -8.889638e-03              3.459856              3.327655
#
#        freq_varrat  freq_y_offset  linear_trend  scatter_res_raw  \
# count  3987.000000    3987.000000   3987.000000      3987.000000
# mean      0.026774       0.019621     -0.011142         0.004148
# std       1.008406       0.994507      0.774763         0.949807
# min      -1.839401      -5.768502    -20.751503        -1.315462
# 25%      -0.876238      -0.390831     -0.010355        -0.813875
# 50%      -0.007826       0.006365     -0.005383        -0.168325
# 75%       0.872792       0.437119     -0.000329         0.675763
# max       2.166616       6.469539     34.152774         9.344787
#
#        std_double_to_single_step
# count                3993.000000
# mean                   -0.013986
# std                     0.879818
# min                    -0.067781
# 25%                    -0.067728
# 50%                    -0.067491
# 75%                    -0.066794
# max                    15.231474
#
# [8 rows x 44 columns]

# %%
imputed_s4_val[impute_f_list].describe()
# Out:
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count                3993.000000                3993.000000
# mean                    0.034947                   0.009940
# std                     1.015055                   0.996017
# min                    -1.565925                  -1.846080
# 25%                    -0.807528                  -0.786468
# 50%                    -0.200810                  -0.100236
# 75%                     0.860945                   0.802951
# max                     2.150220                   1.862563
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count                3993.000000                  3993.000000
# mean                    0.013156                    -0.014491
# std                     0.985942                     0.966574
# min                    -2.009992                    -0.638288
# 25%                    -0.855904                    -0.541329
# 50%                    -0.009573                    -0.288766
# 75%                     0.835478                     0.110687
# max                     1.760028                     8.153267
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                  3993.000000                  3993.000000
# mean                      0.018311                     0.011398
# std                       1.016337                     0.987415
# min                      -0.760832                    -0.827243
# 25%                      -0.510870                    -0.557650
# 50%                      -0.277572                    -0.297685
# 75%                       0.205688                     0.231872
# max                       9.187762                     6.586559
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  \
# count                  3993.000000                  3993.000000
# mean                      0.039985                     0.022895
# std                       1.045123                     1.016448
# min                      -0.528415                    -0.752524
# 25%                      -0.490719                    -0.522121
# 50%                      -0.240850                    -0.291718
# 75%                       0.190498                     0.169087
# max                      11.506715                     6.961699
#
#        all_times_nhist_peak_3_to_4  fold2P_slope_10percentile  ...  \
# count                  3993.000000                3993.000000  ...
# mean                     -0.006584                   0.025045  ...
# std                       0.950944                   0.804416  ...
# min                      -0.703463                 -18.685852  ...
# 25%                      -0.624887                  -0.061483  ...
# 50%                      -0.355483                   0.352584  ...
# 75%                       0.316982                   0.390902  ...
# max                       5.560173                   0.514521  ...
#
#        freq_amplitude_ratio_31  freq_model_max_delta_mags  \
# count              3993.000000               3.993000e+03
# mean                 -0.015444              -7.337412e-03
# std                   0.137501               2.549365e-07
# min                  -0.021645              -7.337622e-03
# 25%                  -0.021645              -7.337577e-03
# 50%                  -0.021645              -7.337496e-03
# 75%                  -0.021645              -7.337354e-03
# max                   7.168335              -7.335418e-03
#
#        freq_model_min_delta_mags  freq_signif_ratio_21  freq_signif_ratio_31  \
# count               3.993000e+03           3993.000000           3993.000000
# mean               -8.893803e-03              0.087871              0.086101
# std                 7.345775e-07              0.883580              0.891655
# min                -8.894588e-03             -5.045137             -4.476570
# 25%                -8.894377e-03             -0.447739             -0.490642
# 50%                -8.894012e-03              0.017045             -0.000923
# 75%                -8.893412e-03              0.511255              0.531346
# max                -8.889638e-03              3.459856              3.327655
#
#        freq_varrat  freq_y_offset  linear_trend  scatter_res_raw  \
# count  3993.000000    3993.000000   3993.000000      3993.000000
# mean      0.026586       0.019553     -0.015139         0.005616
# std       1.007851       0.993798      0.785755         0.950607
# min      -1.839401      -5.768502    -20.751503        -1.315462
# 25%      -0.876200      -0.390817     -0.010374        -0.813766
# 50%      -0.003964       0.006410     -0.005400        -0.166726
# 75%       0.871478       0.435942     -0.000329         0.676512
# max       2.166616       6.469539     34.152774         9.344787
#
#        std_double_to_single_step
# count                3993.000000
# mean                   -0.013986
# std                     0.879818
# min                    -0.067781
# 25%                    -0.067728
# 50%                    -0.067491
# 75%                    -0.066794
# max                    15.231474
#
# [8 rows x 44 columns]

# %% [markdown]
# Ok, now no feature has `NaN` value any longer, and the statistics remain similar for the imputed statistics. Although there are variations in the mean and standard deviation, both remain very close to 0 and 1 respectively (or in any case close to the value they had previously).
#
# For the non-imputed statistics, they remain equal.

# %% [markdown]
# #### Save the imputed VALIDATION S4 sample dataset

# %%
imputed_s4_val.to_csv(VAL_S4B_OUT, sep=',', decimal='.', index=False)

# %% [markdown]
# ### Imputer for CARMENES subsample

# %% [markdown]
# #### Reload imputer

# %%
ld_imputer_carm = pickle.load(open(CARMENES_IMP_FILE, 'rb'))
ld_imputer_carm
# Out:
# KNNImputer(weights='distance')

# %% [markdown]
# #### Impute the features in CARMENES ML sample

# %%
imputed_carm = carm.copy()
imputed_carm.head()
# Out:
#         Karmn  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0  J23505-095                  0.205178                  -0.570279
# 1  J23492+024                 -0.732202                  -0.712088
# 2  J23431+365                  0.517637                  -0.073948
# 3  J23419+441                  0.205178                   1.415047
# 4  J23381-162                 -0.107282                  -0.357566
#
#    all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                   0.102548                  -0.937841
# 1                  -0.352490                  -0.029602
# 2                   0.633426                   1.786876
# 3                   0.330067                   1.181383
# 4                  -0.807528                  -0.635095
#
#    all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                   0.375123                    -0.538868
# 1                   0.452062                    -0.327090
# 2                  -1.009783                    -0.530743
# 3                  -1.009783                    -0.267795
# 4                   1.452272                    -0.010941
#
#    all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                    -0.683950                     0.963624
# 1                    -0.312174                     1.382266
# 2                    -0.698876                    -0.615420
# 3                    -0.401839                    -0.534849
# 4                     0.893571                     0.260497
#
#    all_times_nhist_peak_2_to_3  ...  freq_signif_ratio_31  freq_varrat  \
# 0                    -0.495737  ...             -1.224593     0.375234
# 1                    -0.135084  ...             -2.085847     1.704012
# 2                    -0.528415  ...              0.220901    -0.980754
# 3                    -0.323011  ...             -1.875500     0.357589
# 4                     1.064851  ...             -0.748389     0.907884
#
#    freq_y_offset  linear_trend  medperc90_2p_p  p2p_scatter_2praw  \
# 0       2.177405      0.038241       -0.007191           1.954330
# 1      -4.034985      0.003083       -0.020609           0.663629
# 2       0.372899      0.003590       -0.021224          -0.824111
# 3       0.817097     -0.017334       -0.020135           0.580317
# 4      -0.169309      0.008196       -0.017682           0.696254
#
#    p2p_scatter_over_mad  p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  \
# 0             -0.711851                   -0.142823               -2.452548
# 1             -0.697608                   -0.249360               -1.881067
# 2             -0.427596                   -0.448866               -0.437768
# 3             -0.710630                   -0.208997               -1.996610
# 4             -0.378200                   -0.098799               -0.068227
#
#    scatter_res_raw
# 0         0.223693
# 1         1.582213
# 2        -1.022645
# 3         0.580664
# 4         0.267257
#
# [5 rows x 113 columns]

# %%
imputed_carm.loc[:, cs_f_list] = ld_imputer_carm.transform(imputed_carm.loc[:, cs_f_list])
imputed_carm.head()
# Out:
#         Karmn  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0  J23505-095                  0.205178                  -0.570279
# 1  J23492+024                 -0.732202                  -0.712088
# 2  J23431+365                  0.517637                  -0.073948
# 3  J23419+441                  0.205178                   1.415047
# 4  J23381-162                 -0.107282                  -0.357566
#
#    all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                   0.102548                  -0.937841
# 1                  -0.352490                  -0.029602
# 2                   0.633426                   1.786876
# 3                   0.330067                   1.181383
# 4                  -0.807528                  -0.635095
#
#    all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                   0.375123                    -0.538868
# 1                   0.452062                    -0.327090
# 2                  -1.009783                    -0.530743
# 3                  -1.009783                    -0.267795
# 4                   1.452272                    -0.010941
#
#    all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                    -0.683950                     0.963624
# 1                    -0.312174                     1.382266
# 2                    -0.698876                    -0.615420
# 3                    -0.401839                    -0.534849
# 4                     0.893571                     0.260497
#
#    all_times_nhist_peak_2_to_3  ...  freq_signif_ratio_31  freq_varrat  \
# 0                    -0.495737  ...             -1.224593     0.375234
# 1                    -0.135084  ...             -2.085847     1.704012
# 2                    -0.528415  ...              0.220901    -0.980754
# 3                    -0.323011  ...             -1.875500     0.357589
# 4                     1.064851  ...             -0.748389     0.907884
#
#    freq_y_offset  linear_trend  medperc90_2p_p  p2p_scatter_2praw  \
# 0       2.177405      0.038241       -0.007191           1.954330
# 1      -4.034985      0.003083       -0.020609           0.663629
# 2       0.372899      0.003590       -0.021224          -0.824111
# 3       0.817097     -0.017334       -0.020135           0.580317
# 4      -0.169309      0.008196       -0.017682           0.696254
#
#    p2p_scatter_over_mad  p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  \
# 0             -0.711851                   -0.142823               -2.452548
# 1             -0.697608                   -0.249360               -1.881067
# 2             -0.427596                   -0.448866               -0.437768
# 3             -0.710630                   -0.208997               -1.996610
# 4             -0.378200                   -0.098799               -0.068227
#
#    scatter_res_raw
# 0         0.223693
# 1         1.582213
# 2        -1.022645
# 3         0.580664
# 4         0.267257
#
# [5 rows x 113 columns]

# %% [markdown]
# #### Check correct imputing

# %%
carm[cs_f_list].describe().loc[['count', 'mean', 'std', '50%']]
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count              2.330000e+02               2.330000e+02
# mean               7.623849e-17              -7.623849e-17
# std                1.002153e+00               1.002153e+00
# 50%               -1.072824e-01              -3.575656e-01
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count               2.300000e+02               2.250000e+02
# mean                7.337126e-17              -4.736952e-17
# std                 1.002181e+00               1.002230e+00
# 50%                -2.008103e-01              -2.960186e-02
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count               2.170000e+02                 2.300000e+02
# mean               -8.185976e-18                 1.081261e-16
# std                 1.002312e+00                 1.002181e+00
# 50%                -9.573079e-03                -2.887663e-01
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                 2.250000e+02                 2.170000e+02
# mean                 -4.144833e-17                 1.227896e-16
# std                   1.002230e+00                 1.002312e+00
# 50%                  -2.775723e-01                -2.976853e-01
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                 2.250000e+02                 2.170000e+02  ...
# mean                  2.368476e-16                 3.274390e-17  ...
# std                   1.002230e+00                 1.002312e+00  ...
# 50%                  -2.669921e-01                -2.917182e-01  ...
#
#        freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# count            233.000000   233.000000     233.000000    233.000000
# mean              -0.271566    -0.230007       0.204185     -0.062786
# std                1.128264     0.855456       2.128576      0.655705
# 50%               -0.243356    -0.334207       0.057353     -0.001805
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count      228.000000         233.000000            233.000000
# mean        -0.004035           0.576555             -0.192094
# std          0.038165           1.282657              1.174251
# 50%         -0.013939           0.417663             -0.393730
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                  233.000000              233.000000       233.000000
# mean                     0.024057               -0.945874        -0.130916
# std                      0.817402                1.235812         0.815313
# 50%                     -0.085134               -1.074622        -0.199803
#
# [4 rows x 112 columns]

# %%
imputed_carm[cs_f_list].describe().loc[['count', 'mean', 'std', '50%']]
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count              2.330000e+02               2.330000e+02
# mean               7.623849e-17              -7.623849e-17
# std                1.002153e+00               1.002153e+00
# 50%               -1.072824e-01              -3.575656e-01
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count                 233.000000                 233.000000
# mean                    0.007979                   0.007233
# std                     0.998942                   0.989065
# 50%                    -0.200810                  -0.029602
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count                 233.000000                   233.000000
# mean                    0.004780                    -0.003130
# std                     0.973791                     0.996213
# 50%                    -0.009573                    -0.288766
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                   233.000000                   233.000000
# mean                     -0.001616                     0.009433
# std                       0.985729                     0.976627
# 50%                      -0.277572                    -0.297685
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                   233.000000                   233.000000  ...
# mean                      0.004840                     0.007673  ...
# std                       0.986461                     0.969850  ...
# 50%                      -0.240850                    -0.279264  ...
#
#        freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# count            233.000000   233.000000     233.000000    233.000000
# mean              -0.271566    -0.230007       0.204185     -0.062786
# std                1.128264     0.855456       2.128576      0.655705
# 50%               -0.243356    -0.334207       0.057353     -0.001805
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count      233.000000         233.000000            233.000000
# mean        -0.003598           0.576555             -0.192094
# std          0.037986           1.282657              1.174251
# 50%         -0.012902           0.417663             -0.393730
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                  233.000000              233.000000       233.000000
# mean                     0.024057               -0.945874        -0.130916
# std                      0.817402                1.235812         0.815313
# 50%                     -0.085134               -1.074622        -0.199803
#
# [4 rows x 112 columns]

# %%
carm.isna().sum()[carm.isna().sum() > 0]
# Out:
# all_times_nhist_peak2_bin       3
# all_times_nhist_peak3_bin       8
# all_times_nhist_peak4_bin      16
# all_times_nhist_peak_1_to_2     3
# all_times_nhist_peak_1_to_3     8
# all_times_nhist_peak_1_to_4    16
# all_times_nhist_peak_2_to_3     8
# all_times_nhist_peak_2_to_4    16
# all_times_nhist_peak_3_to_4    16
# fold2P_slope_10percentile       5
# fold2P_slope_90percentile       5
# medperc90_2p_p                  5
# dtype: int64

# %%
imputed_carm.isna().sum()[imputed_carm.isna().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
carm[impute_f_list].describe()
# Out:
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count               2.300000e+02               2.250000e+02
# mean                7.337126e-17              -4.736952e-17
# std                 1.002181e+00               1.002230e+00
# min                -1.565925e+00              -1.846080e+00
# 25%                -8.833674e-01              -7.864677e-01
# 50%                -2.008103e-01              -2.960186e-02
# 75%                 7.851056e-01               8.029505e-01
# max                 2.150220e+00               1.862563e+00
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count               2.170000e+02                 2.300000e+02
# mean               -8.185976e-18                 1.081261e-16
# std                 1.002312e+00                 1.002181e+00
# min                -2.009992e+00                -6.382879e-01
# 25%                -9.328434e-01                -5.387575e-01
# 50%                -9.573079e-03                -2.887663e-01
# 75%                 8.367580e-01                 1.065261e-01
# max                 1.760028e+00                 8.153267e+00
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                 2.250000e+02                 2.170000e+02
# mean                 -4.144833e-17                 1.227896e-16
# std                   1.002230e+00                 1.002312e+00
# min                  -7.608323e-01                -8.272426e-01
# 25%                  -4.943731e-01                -5.624640e-01
# 50%                  -2.775723e-01                -2.976853e-01
# 75%                   6.697425e-02                 2.318719e-01
# max                   9.187762e+00                 6.586559e+00
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  \
# count                 2.250000e+02                 2.170000e+02
# mean                  2.368476e-16                 3.274390e-17
# std                   1.002230e+00                 1.002312e+00
# min                  -5.284149e-01                -7.525235e-01
# 25%                  -4.941809e-01                -5.356740e-01
# 50%                  -2.669921e-01                -2.917182e-01
# 75%                   1.130764e-01                 1.690871e-01
# max                   1.150672e+01                 6.961699e+00
#
#        all_times_nhist_peak_3_to_4  fold2P_slope_10percentile  ...  \
# count                 2.170000e+02                 228.000000  ...
# mean                  2.783232e-16                  -0.084037  ...
# std                   1.002312e+00                   1.263167  ...
# min                  -7.034631e-01                 -10.187285  ...
# 25%                  -6.330852e-01                   0.148410  ...
# 50%                  -3.813333e-01                   0.356422  ...
# 75%                   3.320710e-01                   0.390902  ...
# max                   5.560173e+00                   0.395996  ...
#
#        freq_amplitude_ratio_31  freq_model_max_delta_mags  \
# count             2.330000e+02                 233.000000
# mean             -2.164458e-02                   0.550467
# std               4.290984e-10                   7.187458
# min              -2.164458e-02                  -0.007338
# 25%              -2.164458e-02                  -0.007338
# 50%              -2.164458e-02                  -0.007337
# 75%              -2.164458e-02                  -0.007337
# max              -2.164458e-02                 107.620232
#
#        freq_model_min_delta_mags  freq_signif_ratio_21  freq_signif_ratio_31  \
# count                 233.000000            233.000000            233.000000
# mean                    3.173603             -0.133645             -0.271566
# std                    34.032918              1.082541              1.128264
# min                    -0.008895             -2.943778             -3.099925
# 25%                    -0.008894             -0.742544             -0.953505
# 50%                    -0.008893             -0.090383             -0.243356
# 75%                    -0.008892              0.455428              0.342597
# max                   465.799387              3.459848              3.327644
#
#        freq_varrat  freq_y_offset  linear_trend  scatter_res_raw  \
# count   233.000000     233.000000    233.000000       233.000000
# mean     -0.230007       0.204185     -0.062786        -0.130916
# std       0.855456       2.128576      0.655705         0.815313
# min      -1.684524      -6.111399     -9.827589        -1.276013
# 25%      -0.980227      -0.694258     -0.022823        -0.874639
# 50%      -0.334207       0.057353     -0.001805        -0.199803
# 75%       0.397944       1.192571      0.012517         0.390301
# max       2.187744       8.245187      0.563320         3.290234
#
#        std_double_to_single_step
# count                 233.000000
# mean                    0.000001
# std                     1.002168
# min                    -0.067781
# 25%                    -0.067720
# 50%                    -0.067491
# 75%                    -0.066794
# max                    15.231372
#
# [8 rows x 44 columns]

# %%
imputed_carm[impute_f_list].describe()
# Out:
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count                 233.000000                 233.000000
# mean                    0.007979                   0.007233
# std                     0.998942                   0.989065
# min                    -1.565925                  -1.846080
# 25%                    -0.883367                  -0.786468
# 50%                    -0.200810                  -0.029602
# 75%                     0.785106                   0.802951
# max                     2.150220                   1.862563
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count                 233.000000                   233.000000
# mean                    0.004780                    -0.003130
# std                     0.973791                     0.996213
# min                    -2.009992                    -0.638288
# 25%                    -0.778965                    -0.538425
# 50%                    -0.009573                    -0.288766
# 75%                     0.759819                     0.094043
# max                     1.760028                     8.153267
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                   233.000000                   233.000000
# mean                     -0.001616                     0.009433
# std                       0.985729                     0.976627
# min                      -0.760832                    -0.827243
# 25%                      -0.492354                    -0.547754
# 50%                      -0.277572                    -0.297685
# 75%                       0.087471                     0.231872
# max                       9.187762                     6.586559
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  \
# count                   233.000000                   233.000000
# mean                      0.004840                     0.007673
# std                       0.986461                     0.969850
# min                      -0.528415                    -0.752524
# 25%                      -0.484844                    -0.518682
# 50%                      -0.240850                    -0.279264
# 75%                       0.125142                     0.169087
# max                      11.506715                     6.961699
#
#        all_times_nhist_peak_3_to_4  fold2P_slope_10percentile  ...  \
# count                   233.000000                 233.000000  ...
# mean                      0.010287                  -0.082035  ...
# std                       0.973593                   1.250777  ...
# min                      -0.703463                 -10.187285  ...
# 25%                      -0.615087                   0.135099  ...
# 50%                      -0.355483                   0.353642  ...
# 75%                       0.340476                   0.390902  ...
# max                       5.560173                   0.395996  ...
#
#        freq_amplitude_ratio_31  freq_model_max_delta_mags  \
# count             2.330000e+02                 233.000000
# mean             -2.164458e-02                   0.550467
# std               4.290984e-10                   7.187458
# min              -2.164458e-02                  -0.007338
# 25%              -2.164458e-02                  -0.007338
# 50%              -2.164458e-02                  -0.007337
# 75%              -2.164458e-02                  -0.007337
# max              -2.164458e-02                 107.620232
#
#        freq_model_min_delta_mags  freq_signif_ratio_21  freq_signif_ratio_31  \
# count                 233.000000            233.000000            233.000000
# mean                    3.173603             -0.133645             -0.271566
# std                    34.032918              1.082541              1.128264
# min                    -0.008895             -2.943778             -3.099925
# 25%                    -0.008894             -0.742544             -0.953505
# 50%                    -0.008893             -0.090383             -0.243356
# 75%                    -0.008892              0.455428              0.342597
# max                   465.799387              3.459848              3.327644
#
#        freq_varrat  freq_y_offset  linear_trend  scatter_res_raw  \
# count   233.000000     233.000000    233.000000       233.000000
# mean     -0.230007       0.204185     -0.062786        -0.130916
# std       0.855456       2.128576      0.655705         0.815313
# min      -1.684524      -6.111399     -9.827589        -1.276013
# 25%      -0.980227      -0.694258     -0.022823        -0.874639
# 50%      -0.334207       0.057353     -0.001805        -0.199803
# 75%       0.397944       1.192571      0.012517         0.390301
# max       2.187744       8.245187      0.563320         3.290234
#
#        std_double_to_single_step
# count                 233.000000
# mean                    0.000001
# std                     1.002168
# min                    -0.067781
# 25%                    -0.067720
# 50%                    -0.067491
# 75%                    -0.066794
# max                    15.231372
#
# [8 rows x 44 columns]

# %% [markdown]
# Again, no feature has `NaN` value any longer, and the statistics remain similar for the imputed statistics. Although there are variations in the mean and standard deviation, both remain very close to 0 and 1 respectively (or in any case close to the value they had previously).
#
# For the non-imputed statistics, they remain equal.

# %% [markdown]
# #### Save the imputed ML subsample dataset

# %%
imputed_carm.to_csv(CARMENES_OUT, sep=',', decimal='.', index=False)

# %% [markdown]
# ## Summary

# %% [markdown]
# **RESULTS:**
#
# - We have created and saved a `KNNImputer`, fitted with the data in S4 sample (notice that `NaN` values are ignored during the fit and maintained during the transform)
# - We have reloaded that scaler and applied to the _cesium_ features of the S4 sample and the ML subsample.
# - It has been observed that the imputing operation has not greatly affected the statistics of the features of each dataset.
