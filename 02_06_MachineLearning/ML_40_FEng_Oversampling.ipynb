# %% [markdown]
# #  DATASET OVERSAMPLING

# %% [markdown]
# In this Notebook we explore the possibility of oversampling the S4 sample so as to make it balanced with pulsating and non-pulsating classes.
#
# We will use the `imblearn` module, and the `SMOTE`, set with the parameter `k_neighbors` = 3, because this is the value returned initially by `GridSearchCV` for the `KNeighborsClassifier`.

# %% [markdown]
# ## Modules and configuration

# %% [markdown]
# ### Modules

# %%
import pandas as pd
import numpy as np

#import warnings

from imblearn.over_sampling import SMOTE

#from sklearn.feature_selection import SelectKBest, mutual_info_classif, f_classif

import pickle

#import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set_style("white", {'figure.figsize':(15,10)})

#from IPython.display import display

# %% [markdown]
# ### Configuration

# %%
RANDOM_STATE = 11 # For reproducibility

S4_TRAIN_SET_IN = "../data/DATASETS_ML/S4_02_DS_AfterImputing_TrainTest.csv"
# Train set for S4 sample, all 112 features

REL_FEATURES_IN = "../data/ML_MODELS/ML_pipeline_steps/Reliable_features.pickle"

S4_TRAIN_SET_OUT_OVS = "../data/DATASETS_ML/S4_02_DS_AfterImputing_TrainTest_OVERSAMPLED_n3.csv"
# Oversampled train set for S4 sample, all 112 features

#ML_ADD_COLUMNS = ['Karmn'] # Only cesium features and this column will be kept.
S4_ADD_COLUMNS = ['ID', 'Pulsating', 'frequency', 'amplitudeRV',
                  'offsetRV', 'refepochRV', 'phase'] # Only cesium features and these columns will be kept.

IMAGE_FOLDER = './img/'

# %% [markdown]
# ### Functions

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Load training data

# %% [markdown]
# We load the data, which are the S4 sample dataset, scaled, and with `NaN` values imputed by a `KNNImputer`.

# %%
s4 = pd.read_csv(S4_TRAIN_SET_IN, sep=',', decimal='.')
s4
# Out:
#              ID  Pulsating  frequency  amplitudeRV  offsetRV    refepochRV  \
# 0    Star-00163      False        0.0         0.00       0.0  2.457444e+06
# 1    Star-00123       True       30.0         0.72       0.0  2.457401e+06
# 2    Star-00022      False        0.0         0.00       0.0  2.457430e+06
# 3    Star-00708      False        0.0         0.00       0.0  2.459677e+06
# 4    Star-00484      False        0.0         0.00       0.0  2.457400e+06
# ..          ...        ...        ...          ...       ...           ...
# 745  Star-00795      False        0.0         0.00       0.0  2.457410e+06
# 746  Star-00221      False        0.0         0.00       0.0  2.457478e+06
# 747  Star-00463      False        0.0         0.00       0.0  2.457409e+06
# 748  Star-00873      False        0.0         0.00       0.0  2.457416e+06
# 749  Star-00998      False        0.0         0.00       0.0  2.457397e+06
#
#      phase  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0     0.00                 -0.674126                   0.519174
# 1     0.37                 -1.626729                   1.911247
# 2     0.00                 -0.039057                  -1.012107
# 3     0.00                 -0.039057                   1.632833
# 4     0.00                  0.596012                  -0.176863
# ..     ...                       ...                        ...
# 745   0.00                  0.278478                  -0.803296
# 746   0.00                 -0.039057                  -1.290522
# 747   0.00                  0.596012                  -0.733692
# 748   0.00                 -0.674126                  -0.524881
# 749   0.00                 -0.356591                  -0.037656
#
#      all_times_nhist_peak2_bin  ...  freq_signif_ratio_31  freq_varrat  \
# 0                     0.466681  ...             -0.712310    -1.187392
# 1                    -0.740748  ...              0.040924    -1.110488
# 2                     0.013895  ...             -0.943428     0.637603
# 3                    -0.514355  ...             -1.091456     0.759880
# 4                    -1.042605  ...             -0.696260     0.153752
# ..                         ...  ...                   ...          ...
# 745                   1.070396  ...             -0.390463    -0.320856
# 746                  -0.438891  ...              0.703166    -1.543128
# 747                  -1.193534  ...             -0.741328     1.272454
# 748                   0.542146  ...              0.798791    -1.532917
# 749                  -0.891677  ...             -0.288419     1.285370
#
#      freq_y_offset  linear_trend  medperc90_2p_p  p2p_scatter_2praw  \
# 0         0.425026     -0.002305        0.495906          -0.537353
# 1        -0.289189      0.056551        0.555375          -0.699590
# 2        -0.679383      0.020496       -0.496592          -0.001214
# 3        -0.161363     -0.210930        0.135863           0.662121
# 4         0.936459      0.070402       -0.067689          -0.656553
# ..             ...           ...             ...                ...
# 745      -0.058001      0.061510       -0.608276          -1.229502
# 746      -0.386300      0.084782       -0.063902           0.199957
# 747      -0.054747      0.066032       -0.327664           0.414920
# 748      -2.547988      0.149859        1.751137          -0.416064
# 749       0.083736      0.024976       -0.290043           0.132179
#
#      p2p_scatter_over_mad  p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  \
# 0               -0.028926                   -0.262548               -0.135686
# 1               -0.292135                   -0.013533                0.443673
# 2               -0.101526                   -0.011097               -0.293389
# 3               -0.492481                    0.015621               -0.724783
# 4               -0.237337                   -0.032597               -0.139141
# ..                    ...                         ...                     ...
# 745             -0.332122                   -0.410947                1.478398
# 746              0.689712                   -0.526121                1.559757
# 747              0.069037                    0.039541               -0.218490
# 748             -0.361215                    0.544014               -1.894647
# 749             -0.323890                   -0.160471                0.052323
#
#      scatter_res_raw
# 0          -0.705143
# 1          -1.207278
# 2           0.242263
# 3           0.682494
# 4          -0.098080
# ..               ...
# 745        -0.121757
# 746        -1.150793
# 747         1.238094
# 748        -1.094748
# 749         1.120890
#
# [750 rows x 119 columns]

# %%
s4['Pulsating'] = s4['Pulsating'].map(lambda x: 1 if x == True else 0)
s4
# Out:
#              ID  Pulsating  frequency  amplitudeRV  offsetRV    refepochRV  \
# 0    Star-00163          0        0.0         0.00       0.0  2.457444e+06
# 1    Star-00123          1       30.0         0.72       0.0  2.457401e+06
# 2    Star-00022          0        0.0         0.00       0.0  2.457430e+06
# 3    Star-00708          0        0.0         0.00       0.0  2.459677e+06
# 4    Star-00484          0        0.0         0.00       0.0  2.457400e+06
# ..          ...        ...        ...          ...       ...           ...
# 745  Star-00795          0        0.0         0.00       0.0  2.457410e+06
# 746  Star-00221          0        0.0         0.00       0.0  2.457478e+06
# 747  Star-00463          0        0.0         0.00       0.0  2.457409e+06
# 748  Star-00873          0        0.0         0.00       0.0  2.457416e+06
# 749  Star-00998          0        0.0         0.00       0.0  2.457397e+06
#
#      phase  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0     0.00                 -0.674126                   0.519174
# 1     0.37                 -1.626729                   1.911247
# 2     0.00                 -0.039057                  -1.012107
# 3     0.00                 -0.039057                   1.632833
# 4     0.00                  0.596012                  -0.176863
# ..     ...                       ...                        ...
# 745   0.00                  0.278478                  -0.803296
# 746   0.00                 -0.039057                  -1.290522
# 747   0.00                  0.596012                  -0.733692
# 748   0.00                 -0.674126                  -0.524881
# 749   0.00                 -0.356591                  -0.037656
#
#      all_times_nhist_peak2_bin  ...  freq_signif_ratio_31  freq_varrat  \
# 0                     0.466681  ...             -0.712310    -1.187392
# 1                    -0.740748  ...              0.040924    -1.110488
# 2                     0.013895  ...             -0.943428     0.637603
# 3                    -0.514355  ...             -1.091456     0.759880
# 4                    -1.042605  ...             -0.696260     0.153752
# ..                         ...  ...                   ...          ...
# 745                   1.070396  ...             -0.390463    -0.320856
# 746                  -0.438891  ...              0.703166    -1.543128
# 747                  -1.193534  ...             -0.741328     1.272454
# 748                   0.542146  ...              0.798791    -1.532917
# 749                  -0.891677  ...             -0.288419     1.285370
#
#      freq_y_offset  linear_trend  medperc90_2p_p  p2p_scatter_2praw  \
# 0         0.425026     -0.002305        0.495906          -0.537353
# 1        -0.289189      0.056551        0.555375          -0.699590
# 2        -0.679383      0.020496       -0.496592          -0.001214
# 3        -0.161363     -0.210930        0.135863           0.662121
# 4         0.936459      0.070402       -0.067689          -0.656553
# ..             ...           ...             ...                ...
# 745      -0.058001      0.061510       -0.608276          -1.229502
# 746      -0.386300      0.084782       -0.063902           0.199957
# 747      -0.054747      0.066032       -0.327664           0.414920
# 748      -2.547988      0.149859        1.751137          -0.416064
# 749       0.083736      0.024976       -0.290043           0.132179
#
#      p2p_scatter_over_mad  p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  \
# 0               -0.028926                   -0.262548               -0.135686
# 1               -0.292135                   -0.013533                0.443673
# 2               -0.101526                   -0.011097               -0.293389
# 3               -0.492481                    0.015621               -0.724783
# 4               -0.237337                   -0.032597               -0.139141
# ..                    ...                         ...                     ...
# 745             -0.332122                   -0.410947                1.478398
# 746              0.689712                   -0.526121                1.559757
# 747              0.069037                    0.039541               -0.218490
# 748             -0.361215                    0.544014               -1.894647
# 749             -0.323890                   -0.160471                0.052323
#
#      scatter_res_raw
# 0          -0.705143
# 1          -1.207278
# 2           0.242263
# 3           0.682494
# 4          -0.098080
# ..               ...
# 745        -0.121757
# 746        -1.150793
# 747         1.238094
# 748        -1.094748
# 749         1.120890
#
# [750 rows x 119 columns]

# %% [markdown]
# ### Load reliable features

# %%
rel_features = pickle.load(open(REL_FEATURES_IN, 'rb'))
print(rel_features)
# Out:
# ['all_times_nhist_numpeaks', 'all_times_nhist_peak1_bin', 'all_times_nhist_peak2_bin', 'all_times_nhist_peak3_bin', 'all_times_nhist_peak4_bin', 'all_times_nhist_peak_1_to_2', 'all_times_nhist_peak_1_to_3', 'all_times_nhist_peak_1_to_4', 'all_times_nhist_peak_2_to_3', 'all_times_nhist_peak_2_to_4', 'all_times_nhist_peak_3_to_4', 'all_times_nhist_peak_val', 'avg_double_to_single_step', 'cad_probs_1', 'cad_probs_10', 'cad_probs_20', 'cad_probs_30', 'cad_probs_40', 'cad_probs_50', 'cad_probs_100', 'cad_probs_500', 'cad_probs_1000', 'cad_probs_5000', 'cad_probs_10000', 'cad_probs_50000', 'cad_probs_100000', 'cad_probs_500000', 'cad_probs_1000000', 'cad_probs_5000000', 'cad_probs_10000000', 'cads_avg', 'cads_med', 'cads_std', 'med_double_to_single_step', 'n_epochs', 'std_double_to_single_step', 'total_time', 'percent_beyond_1_std', 'freq1_rel_phase2', 'freq1_rel_phase3', 'freq1_rel_phase4', 'freq2_rel_phase2', 'freq2_rel_phase3', 'freq2_rel_phase4', 'freq3_rel_phase2', 'freq3_rel_phase3', 'freq3_rel_phase4', 'freq_model_phi1_phi2']

# %% [markdown]
# ## Apply standard oversampling

# %% [markdown]
# We first extract the relevant columns (metadata are not to be oversampled).

# %%
X, y = s4[rel_features], s4['Pulsating']

# %% [markdown]
# Create the oversampler (all parameters by default

# %%
sm = SMOTE(sampling_strategy='auto', random_state=RANDOM_STATE, k_neighbors=3, n_jobs=None)
sm
# Out:
# SMOTE(k_neighbors=3, random_state=11)

# %% [markdown]
# And we now apply the oversampling:

# %%
X_res, y_res = sm.fit_resample(X, y)

# %%
X_res
# Out:
#       all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0                    -0.674126                   0.519174
# 1                    -1.626729                   1.911247
# 2                    -0.039057                  -1.012107
# 3                    -0.039057                   1.632833
# 4                     0.596012                  -0.176863
# ...                        ...                        ...
# 1339                  0.473173                  -0.668664
# 1340                 -0.993662                  -0.524004
# 1341                  0.610021                  -1.068148
# 1342                  1.061356                  -0.373715
# 1343                  0.385500                  -0.307476
#
#       all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                      0.466681                   0.766297
# 1                     -0.740748                   0.691384
# 2                      0.013895                  -0.357397
# 3                     -0.514355                   0.166993
# 4                     -1.042605                  -0.432310
# ...                         ...                        ...
# 1339                   0.135630                  -0.259518
# 1340                   0.918516                   1.589867
# 1341                   0.492761                   0.150468
# 1342                   0.099776                  -0.660900
# 1343                  -0.104800                  -1.105693
#
#       all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                      1.786498                    -0.304944
# 1                      0.168331                     1.522002
# 2                      1.168762                    -0.232282
# 3                      1.477630                    -0.544204
# 4                      0.242158                    -0.277263
# ...                         ...                          ...
# 1339                  -1.373200                    -0.470559
# 1340                  -0.372796                    -0.377095
# 1341                  -0.980256                    -0.169826
# 1342                  -1.102506                     0.339215
# 1343                  -0.701796                     0.663158
#
#       all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                        0.843252                     0.189055
# 1                        1.166420                     0.157675
# 2                       -0.443941                    -0.136007
# 3                       -0.572606                    -0.586661
# 4                       -0.498198                    -0.370020
# ...                           ...                          ...
# 1339                    -0.589896                    -0.548709
# 1340                    -0.318659                    -0.118490
# 1341                    -0.341273                    -0.177918
# 1342                    -0.083127                     0.190607
# 1343                     0.246839                    -0.178181
#
#       all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# 0                        1.390901                     0.462908  ...
# 1                        0.019744                    -0.192345  ...
# 2                       -0.412519                    -0.042766  ...
# 3                       -0.338658                    -0.449412  ...
# 4                       -0.451106                    -0.321570  ...
# ...                           ...                          ...  ...
# 1339                    -0.448373                    -0.491607  ...
# 1340                    -0.120285                     0.108136  ...
# 1341                    -0.341825                    -0.169797  ...
# 1342                    -0.361995                    -0.066276  ...
# 1343                    -0.246785                    -0.582739  ...
#
#       freq1_rel_phase2  freq1_rel_phase3  freq1_rel_phase4  freq2_rel_phase2  \
# 0             0.646033          0.908818          1.305379          1.413989
# 1             1.532902         -1.224350          0.710232         -1.272791
# 2             0.384058          0.882515          1.044322         -1.204443
# 3             1.457441         -0.921750         -1.095322         -0.031960
# 4            -0.829296         -0.057582          0.541269          1.529879
# ...                ...               ...               ...               ...
# 1339         -0.038051         -0.958444          0.386309         -0.805888
# 1340          0.036617          1.595782          0.586577         -0.903790
# 1341         -0.194276         -0.105307          1.257649         -0.697622
# 1342         -0.124422         -0.875222          1.033421         -0.335086
# 1343          1.543458          0.709110         -0.986673          1.122309
#
#       freq2_rel_phase3  freq2_rel_phase4  freq3_rel_phase2  freq3_rel_phase3  \
# 0             0.174334         -0.188773          0.985693         -0.258841
# 1             1.617586          1.392776          0.260283          0.708876
# 2            -0.593335         -1.011092          0.592500          0.135213
# 3            -0.068737          1.152465         -0.672518          0.391616
# 4            -0.689578          1.475290         -1.268004          1.297212
# ...                ...               ...               ...               ...
# 1339          0.697947          0.293784         -0.667106         -0.192877
# 1340          0.315474         -0.690108         -0.846619          0.819517
# 1341         -0.195618         -0.123771         -0.670504          0.582847
# 1342         -0.822268         -0.909756         -0.608352         -0.050957
# 1343         -0.152466         -1.478277         -1.115881         -1.387955
#
#       freq3_rel_phase4  freq_model_phi1_phi2
# 0            -1.099919             -0.461571
# 1             1.030413              0.400968
# 2             0.725303             -0.319881
# 3            -1.301501              0.559262
# 4             1.327633             -0.059789
# ...                ...                   ...
# 1339          1.224979             -1.394465
# 1340         -0.407266             -1.583849
# 1341          1.003724             -1.285203
# 1342          1.095146             -1.091260
# 1343          0.029941              1.153847
#
# [1344 rows x 48 columns]

# %%
y_res
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1339    1
# 1340    1
# 1341    1
# 1342    1
# 1343    1
# Name: Pulsating, Length: 1344, dtype: int64

# %%
y_res[y_res == 0].shape
# Out:
# (672,)

# %%
y_res[y_res == 1].shape
# Out:
# (672,)

# %% [markdown]
# Hence, we now have a balanced dataset. The only problem is that we cannot put the metadata, as they are really unknown.

# %% [markdown]
# We merge the resulting features and targets together before saving

# %%
train_res = pd.concat([y_res, X_res], axis=1)
train_res
# Out:
#       Pulsating  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0             0                 -0.674126                   0.519174
# 1             1                 -1.626729                   1.911247
# 2             0                 -0.039057                  -1.012107
# 3             0                 -0.039057                   1.632833
# 4             0                  0.596012                  -0.176863
# ...         ...                       ...                        ...
# 1339          1                  0.473173                  -0.668664
# 1340          1                 -0.993662                  -0.524004
# 1341          1                  0.610021                  -1.068148
# 1342          1                  1.061356                  -0.373715
# 1343          1                  0.385500                  -0.307476
#
#       all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                      0.466681                   0.766297
# 1                     -0.740748                   0.691384
# 2                      0.013895                  -0.357397
# 3                     -0.514355                   0.166993
# 4                     -1.042605                  -0.432310
# ...                         ...                        ...
# 1339                   0.135630                  -0.259518
# 1340                   0.918516                   1.589867
# 1341                   0.492761                   0.150468
# 1342                   0.099776                  -0.660900
# 1343                  -0.104800                  -1.105693
#
#       all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                      1.786498                    -0.304944
# 1                      0.168331                     1.522002
# 2                      1.168762                    -0.232282
# 3                      1.477630                    -0.544204
# 4                      0.242158                    -0.277263
# ...                         ...                          ...
# 1339                  -1.373200                    -0.470559
# 1340                  -0.372796                    -0.377095
# 1341                  -0.980256                    -0.169826
# 1342                  -1.102506                     0.339215
# 1343                  -0.701796                     0.663158
#
#       all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                        0.843252                     0.189055
# 1                        1.166420                     0.157675
# 2                       -0.443941                    -0.136007
# 3                       -0.572606                    -0.586661
# 4                       -0.498198                    -0.370020
# ...                           ...                          ...
# 1339                    -0.589896                    -0.548709
# 1340                    -0.318659                    -0.118490
# 1341                    -0.341273                    -0.177918
# 1342                    -0.083127                     0.190607
# 1343                     0.246839                    -0.178181
#
#       all_times_nhist_peak_2_to_3  ...  freq1_rel_phase2  freq1_rel_phase3  \
# 0                        1.390901  ...          0.646033          0.908818
# 1                        0.019744  ...          1.532902         -1.224350
# 2                       -0.412519  ...          0.384058          0.882515
# 3                       -0.338658  ...          1.457441         -0.921750
# 4                       -0.451106  ...         -0.829296         -0.057582
# ...                           ...  ...               ...               ...
# 1339                    -0.448373  ...         -0.038051         -0.958444
# 1340                    -0.120285  ...          0.036617          1.595782
# 1341                    -0.341825  ...         -0.194276         -0.105307
# 1342                    -0.361995  ...         -0.124422         -0.875222
# 1343                    -0.246785  ...          1.543458          0.709110
#
#       freq1_rel_phase4  freq2_rel_phase2  freq2_rel_phase3  freq2_rel_phase4  \
# 0             1.305379          1.413989          0.174334         -0.188773
# 1             0.710232         -1.272791          1.617586          1.392776
# 2             1.044322         -1.204443         -0.593335         -1.011092
# 3            -1.095322         -0.031960         -0.068737          1.152465
# 4             0.541269          1.529879         -0.689578          1.475290
# ...                ...               ...               ...               ...
# 1339          0.386309         -0.805888          0.697947          0.293784
# 1340          0.586577         -0.903790          0.315474         -0.690108
# 1341          1.257649         -0.697622         -0.195618         -0.123771
# 1342          1.033421         -0.335086         -0.822268         -0.909756
# 1343         -0.986673          1.122309         -0.152466         -1.478277
#
#       freq3_rel_phase2  freq3_rel_phase3  freq3_rel_phase4  \
# 0             0.985693         -0.258841         -1.099919
# 1             0.260283          0.708876          1.030413
# 2             0.592500          0.135213          0.725303
# 3            -0.672518          0.391616         -1.301501
# 4            -1.268004          1.297212          1.327633
# ...                ...               ...               ...
# 1339         -0.667106         -0.192877          1.224979
# 1340         -0.846619          0.819517         -0.407266
# 1341         -0.670504          0.582847          1.003724
# 1342         -0.608352         -0.050957          1.095146
# 1343         -1.115881         -1.387955          0.029941
#
#       freq_model_phi1_phi2
# 0                -0.461571
# 1                 0.400968
# 2                -0.319881
# 3                 0.559262
# 4                -0.059789
# ...                    ...
# 1339             -1.394465
# 1340             -1.583849
# 1341             -1.285203
# 1342             -1.091260
# 1343              1.153847
#
# [1344 rows x 49 columns]

# %% [markdown]
# The next two cells were used to check if the new execution, adding the star identifier, did not change the oversampled train set.

# %% [raw]
# train_res_old = pd.read_csv("../data/DATASETS_ML/OLD_S4_02_DS_AfterImputing_TrainTest_OVERSAMPLED_n3.csv",
#                             sep=',', decimal='.')
# train_res_old.head()

# %% [raw]
# np.allclose(train_res, train_res_old)

# %% [markdown]
# ### Add the `ID` field for the original stars (new data points will not have that ID)

# %% [markdown]
# For the new data points created for `SMOTE` we just assign them an identifier with the index (SMOTE-\<xxxx\>).

# %%
train_res.insert(0, 'ID', "-")
train_res.head()
# Out:
#   ID  Pulsating  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0  -          0                 -0.674126                   0.519174
# 1  -          1                 -1.626729                   1.911247
# 2  -          0                 -0.039057                  -1.012107
# 3  -          0                 -0.039057                   1.632833
# 4  -          0                  0.596012                  -0.176863
#
#    all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                   0.466681                   0.766297
# 1                  -0.740748                   0.691384
# 2                   0.013895                  -0.357397
# 3                  -0.514355                   0.166993
# 4                  -1.042605                  -0.432310
#
#    all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                   1.786498                    -0.304944
# 1                   0.168331                     1.522002
# 2                   1.168762                    -0.232282
# 3                   1.477630                    -0.544204
# 4                   0.242158                    -0.277263
#
#    all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  ...  \
# 0                     0.843252                     0.189055  ...
# 1                     1.166420                     0.157675  ...
# 2                    -0.443941                    -0.136007  ...
# 3                    -0.572606                    -0.586661  ...
# 4                    -0.498198                    -0.370020  ...
#
#    freq1_rel_phase2  freq1_rel_phase3  freq1_rel_phase4  freq2_rel_phase2  \
# 0          0.646033          0.908818          1.305379          1.413989
# 1          1.532902         -1.224350          0.710232         -1.272791
# 2          0.384058          0.882515          1.044322         -1.204443
# 3          1.457441         -0.921750         -1.095322         -0.031960
# 4         -0.829296         -0.057582          0.541269          1.529879
#
#    freq2_rel_phase3  freq2_rel_phase4  freq3_rel_phase2  freq3_rel_phase3  \
# 0          0.174334         -0.188773          0.985693         -0.258841
# 1          1.617586          1.392776          0.260283          0.708876
# 2         -0.593335         -1.011092          0.592500          0.135213
# 3         -0.068737          1.152465         -0.672518          0.391616
# 4         -0.689578          1.475290         -1.268004          1.297212
#
#    freq3_rel_phase4  freq_model_phi1_phi2
# 0         -1.099919             -0.461571
# 1          1.030413              0.400968
# 2          0.725303             -0.319881
# 3         -1.301501              0.559262
# 4          1.327633             -0.059789
#
# [5 rows x 50 columns]

# %%
train_res.loc[0:len(s4)-1, :]
# Out:
#     ID  Pulsating  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0    -          0                 -0.674126                   0.519174
# 1    -          1                 -1.626729                   1.911247
# 2    -          0                 -0.039057                  -1.012107
# 3    -          0                 -0.039057                   1.632833
# 4    -          0                  0.596012                  -0.176863
# ..  ..        ...                       ...                        ...
# 745  -          0                  0.278478                  -0.803296
# 746  -          0                 -0.039057                  -1.290522
# 747  -          0                  0.596012                  -0.733692
# 748  -          0                 -0.674126                  -0.524881
# 749  -          0                 -0.356591                  -0.037656
#
#      all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                     0.466681                   0.766297
# 1                    -0.740748                   0.691384
# 2                     0.013895                  -0.357397
# 3                    -0.514355                   0.166993
# 4                    -1.042605                  -0.432310
# ..                         ...                        ...
# 745                   1.070396                   0.991036
# 746                  -0.438891                  -1.630917
# 747                  -1.193534                  -0.731962
# 748                   0.542146                   0.916123
# 749                  -0.891677                   0.316819
#
#      all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                     1.786498                    -0.304944
# 1                     0.168331                     1.522002
# 2                     1.168762                    -0.232282
# 3                     1.477630                    -0.544204
# 4                     0.242158                    -0.277263
# ..                         ...                          ...
# 745                   1.168762                     0.022969
# 746                  -0.916097                     1.116014
# 747                  -0.993314                    -0.671992
# 748                   1.245979                     0.340946
# 749                   0.087724                    -0.677428
#
#      all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  ...  \
# 0                       0.843252                     0.189055  ...
# 1                       1.166420                     0.157675  ...
# 2                      -0.443941                    -0.136007  ...
# 3                      -0.572606                    -0.586661  ...
# 4                      -0.498198                    -0.370020  ...
# ..                           ...                          ...  ...
# 745                    -0.301300                    -0.379804  ...
# 746                     0.520084                    -0.017803  ...
# 747                     0.345105                    -0.083419  ...
# 748                     0.439292                    -0.069517  ...
# 749                    -0.686637                    -0.777780  ...
#
#      freq1_rel_phase2  freq1_rel_phase3  freq1_rel_phase4  freq2_rel_phase2  \
# 0            0.646033          0.908818          1.305379          1.413989
# 1            1.532902         -1.224350          0.710232         -1.272791
# 2            0.384058          0.882515          1.044322         -1.204443
# 3            1.457441         -0.921750         -1.095322         -0.031960
# 4           -0.829296         -0.057582          0.541269          1.529879
# ..                ...               ...               ...               ...
# 745         -0.288258         -0.848774         -0.854496          1.491923
# 746          1.636850         -1.044746          0.342069         -1.435674
# 747          0.554391         -1.609160          1.073499         -1.750994
# 748         -1.035107          0.803325         -0.968768         -1.073748
# 749          0.139384          0.388687         -0.000302          1.710044
#
#      freq2_rel_phase3  freq2_rel_phase4  freq3_rel_phase2  freq3_rel_phase3  \
# 0            0.174334         -0.188773          0.985693         -0.258841
# 1            1.617586          1.392776          0.260283          0.708876
# 2           -0.593335         -1.011092          0.592500          0.135213
# 3           -0.068737          1.152465         -0.672518          0.391616
# 4           -0.689578          1.475290         -1.268004          1.297212
# ..                ...               ...               ...               ...
# 745          1.008801         -0.519740         -1.680259         -1.300470
# 746         -1.390858         -0.052260         -1.612403          1.449496
# 747         -1.230980         -0.473819         -0.204503          0.349673
# 748         -0.666836          0.702556         -0.746085          1.140938
# 749          0.342520          0.410963         -0.811926         -0.752704
#
#      freq3_rel_phase4  freq_model_phi1_phi2
# 0           -1.099919             -0.461571
# 1            1.030413              0.400968
# 2            0.725303             -0.319881
# 3           -1.301501              0.559262
# 4            1.327633             -0.059789
# ..                ...                   ...
# 745          0.307095             -1.189971
# 746         -0.028414              1.009892
# 747          0.121996             -0.524541
# 748         -1.325713              0.126896
# 749         -1.525543             -0.335513
#
# [750 rows x 50 columns]

# %%
train_res.loc[0:len(s4)-1, 'ID'] = s4['ID']
train_res
# Out:
#               ID  Pulsating  all_times_nhist_numpeaks  \
# 0     Star-00163          0                 -0.674126
# 1     Star-00123          1                 -1.626729
# 2     Star-00022          0                 -0.039057
# 3     Star-00708          0                 -0.039057
# 4     Star-00484          0                  0.596012
# ...          ...        ...                       ...
# 1339           -          1                  0.473173
# 1340           -          1                 -0.993662
# 1341           -          1                  0.610021
# 1342           -          1                  1.061356
# 1343           -          1                  0.385500
#
#       all_times_nhist_peak1_bin  all_times_nhist_peak2_bin  \
# 0                      0.519174                   0.466681
# 1                      1.911247                  -0.740748
# 2                     -1.012107                   0.013895
# 3                      1.632833                  -0.514355
# 4                     -0.176863                  -1.042605
# ...                         ...                        ...
# 1339                  -0.668664                   0.135630
# 1340                  -0.524004                   0.918516
# 1341                  -1.068148                   0.492761
# 1342                  -0.373715                   0.099776
# 1343                  -0.307476                  -0.104800
#
#       all_times_nhist_peak3_bin  all_times_nhist_peak4_bin  \
# 0                      0.766297                   1.786498
# 1                      0.691384                   0.168331
# 2                     -0.357397                   1.168762
# 3                      0.166993                   1.477630
# 4                     -0.432310                   0.242158
# ...                         ...                        ...
# 1339                  -0.259518                  -1.373200
# 1340                   1.589867                  -0.372796
# 1341                   0.150468                  -0.980256
# 1342                  -0.660900                  -1.102506
# 1343                  -1.105693                  -0.701796
#
#       all_times_nhist_peak_1_to_2  all_times_nhist_peak_1_to_3  \
# 0                       -0.304944                     0.843252
# 1                        1.522002                     1.166420
# 2                       -0.232282                    -0.443941
# 3                       -0.544204                    -0.572606
# 4                       -0.277263                    -0.498198
# ...                           ...                          ...
# 1339                    -0.470559                    -0.589896
# 1340                    -0.377095                    -0.318659
# 1341                    -0.169826                    -0.341273
# 1342                     0.339215                    -0.083127
# 1343                     0.663158                     0.246839
#
#       all_times_nhist_peak_1_to_4  ...  freq1_rel_phase2  freq1_rel_phase3  \
# 0                        0.189055  ...          0.646033          0.908818
# 1                        0.157675  ...          1.532902         -1.224350
# 2                       -0.136007  ...          0.384058          0.882515
# 3                       -0.586661  ...          1.457441         -0.921750
# 4                       -0.370020  ...         -0.829296         -0.057582
# ...                           ...  ...               ...               ...
# 1339                    -0.548709  ...         -0.038051         -0.958444
# 1340                    -0.118490  ...          0.036617          1.595782
# 1341                    -0.177918  ...         -0.194276         -0.105307
# 1342                     0.190607  ...         -0.124422         -0.875222
# 1343                    -0.178181  ...          1.543458          0.709110
#
#       freq1_rel_phase4  freq2_rel_phase2  freq2_rel_phase3  freq2_rel_phase4  \
# 0             1.305379          1.413989          0.174334         -0.188773
# 1             0.710232         -1.272791          1.617586          1.392776
# 2             1.044322         -1.204443         -0.593335         -1.011092
# 3            -1.095322         -0.031960         -0.068737          1.152465
# 4             0.541269          1.529879         -0.689578          1.475290
# ...                ...               ...               ...               ...
# 1339          0.386309         -0.805888          0.697947          0.293784
# 1340          0.586577         -0.903790          0.315474         -0.690108
# 1341          1.257649         -0.697622         -0.195618         -0.123771
# 1342          1.033421         -0.335086         -0.822268         -0.909756
# 1343         -0.986673          1.122309         -0.152466         -1.478277
#
#       freq3_rel_phase2  freq3_rel_phase3  freq3_rel_phase4  \
# 0             0.985693         -0.258841         -1.099919
# 1             0.260283          0.708876          1.030413
# 2             0.592500          0.135213          0.725303
# 3            -0.672518          0.391616         -1.301501
# 4            -1.268004          1.297212          1.327633
# ...                ...               ...               ...
# 1339         -0.667106         -0.192877          1.224979
# 1340         -0.846619          0.819517         -0.407266
# 1341         -0.670504          0.582847          1.003724
# 1342         -0.608352         -0.050957          1.095146
# 1343         -1.115881         -1.387955          0.029941
#
#       freq_model_phi1_phi2
# 0                -0.461571
# 1                 0.400968
# 2                -0.319881
# 3                 0.559262
# 4                -0.059789
# ...                    ...
# 1339             -1.394465
# 1340             -1.583849
# 1341             -1.285203
# 1342             -1.091260
# 1343              1.153847
#
# [1344 rows x 50 columns]

# %%
smote_id = list(train_res.loc[len(s4):len(train_res)-1, 'ID'].index)
print(smote_id)
# Out:
# [750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 787, 788, 789, 790, 791, 792, 793, 794, 795, 796, 797, 798, 799, 800, 801, 802, 803, 804, 805, 806, 807, 808, 809, 810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 820, 821, 822, 823, 824, 825, 826, 827, 828, 829, 830, 831, 832, 833, 834, 835, 836, 837, 838, 839, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 854, 855, 856, 857, 858, 859, 860, 861, 862, 863, 864, 865, 866, 867, 868, 869, 870, 871, 872, 873, 874, 875, 876, 877, 878, 879, 880, 881, 882, 883, 884, 885, 886, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 899, 900, 901, 902, 903, 904, 905, 906, 907, 908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 927, 928, 929, 930, 931, 932, 933, 934, 935, 936, 937, 938, 939, 940, 941, 942, 943, 944, 945, 946, 947, 948, 949, 950, 951, 952, 953, 954, 955, 956, 957, 958, 959, 960, 961, 962, 963, 964, 965, 966, 967, 968, 969, 970, 971, 972, 973, 974, 975, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 1047, 1048, 1049, 1050, 1051, 1052, 1053, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343]

# %%
smote_id = ["SMOTE-" + str(elem + 10000).zfill(5) for elem in smote_id]
print(smote_id)
# Out:
# ['SMOTE-10750', 'SMOTE-10751', 'SMOTE-10752', 'SMOTE-10753', 'SMOTE-10754', 'SMOTE-10755', 'SMOTE-10756', 'SMOTE-10757', 'SMOTE-10758', 'SMOTE-10759', 'SMOTE-10760', 'SMOTE-10761', 'SMOTE-10762', 'SMOTE-10763', 'SMOTE-10764', 'SMOTE-10765', 'SMOTE-10766', 'SMOTE-10767', 'SMOTE-10768', 'SMOTE-10769', 'SMOTE-10770', 'SMOTE-10771', 'SMOTE-10772', 'SMOTE-10773', 'SMOTE-10774', 'SMOTE-10775', 'SMOTE-10776', 'SMOTE-10777', 'SMOTE-10778', 'SMOTE-10779', 'SMOTE-10780', 'SMOTE-10781', 'SMOTE-10782', 'SMOTE-10783', 'SMOTE-10784', 'SMOTE-10785', 'SMOTE-10786', 'SMOTE-10787', 'SMOTE-10788', 'SMOTE-10789', 'SMOTE-10790', 'SMOTE-10791', 'SMOTE-10792', 'SMOTE-10793', 'SMOTE-10794', 'SMOTE-10795', 'SMOTE-10796', 'SMOTE-10797', 'SMOTE-10798', 'SMOTE-10799', 'SMOTE-10800', 'SMOTE-10801', 'SMOTE-10802', 'SMOTE-10803', 'SMOTE-10804', 'SMOTE-10805', 'SMOTE-10806', 'SMOTE-10807', 'SMOTE-10808', 'SMOTE-10809', 'SMOTE-10810', 'SMOTE-10811', 'SMOTE-10812', 'SMOTE-10813', 'SMOTE-10814', 'SMOTE-10815', 'SMOTE-10816', 'SMOTE-10817', 'SMOTE-10818', 'SMOTE-10819', 'SMOTE-10820', 'SMOTE-10821', 'SMOTE-10822', 'SMOTE-10823', 'SMOTE-10824', 'SMOTE-10825', 'SMOTE-10826', 'SMOTE-10827', 'SMOTE-10828', 'SMOTE-10829', 'SMOTE-10830', 'SMOTE-10831', 'SMOTE-10832', 'SMOTE-10833', 'SMOTE-10834', 'SMOTE-10835', 'SMOTE-10836', 'SMOTE-10837', 'SMOTE-10838', 'SMOTE-10839', 'SMOTE-10840', 'SMOTE-10841', 'SMOTE-10842', 'SMOTE-10843', 'SMOTE-10844', 'SMOTE-10845', 'SMOTE-10846', 'SMOTE-10847', 'SMOTE-10848', 'SMOTE-10849', 'SMOTE-10850', 'SMOTE-10851', 'SMOTE-10852', 'SMOTE-10853', 'SMOTE-10854', 'SMOTE-10855', 'SMOTE-10856', 'SMOTE-10857', 'SMOTE-10858', 'SMOTE-10859', 'SMOTE-10860', 'SMOTE-10861', 'SMOTE-10862', 'SMOTE-10863', 'SMOTE-10864', 'SMOTE-10865', 'SMOTE-10866', 'SMOTE-10867', 'SMOTE-10868', 'SMOTE-10869', 'SMOTE-10870', 'SMOTE-10871', 'SMOTE-10872', 'SMOTE-10873', 'SMOTE-10874', 'SMOTE-10875', 'SMOTE-10876', 'SMOTE-10877', 'SMOTE-10878', 'SMOTE-10879', 'SMOTE-10880', 'SMOTE-10881', 'SMOTE-10882', 'SMOTE-10883', 'SMOTE-10884', 'SMOTE-10885', 'SMOTE-10886', 'SMOTE-10887', 'SMOTE-10888', 'SMOTE-10889', 'SMOTE-10890', 'SMOTE-10891', 'SMOTE-10892', 'SMOTE-10893', 'SMOTE-10894', 'SMOTE-10895', 'SMOTE-10896', 'SMOTE-10897', 'SMOTE-10898', 'SMOTE-10899', 'SMOTE-10900', 'SMOTE-10901', 'SMOTE-10902', 'SMOTE-10903', 'SMOTE-10904', 'SMOTE-10905', 'SMOTE-10906', 'SMOTE-10907', 'SMOTE-10908', 'SMOTE-10909', 'SMOTE-10910', 'SMOTE-10911', 'SMOTE-10912', 'SMOTE-10913', 'SMOTE-10914', 'SMOTE-10915', 'SMOTE-10916', 'SMOTE-10917', 'SMOTE-10918', 'SMOTE-10919', 'SMOTE-10920', 'SMOTE-10921', 'SMOTE-10922', 'SMOTE-10923', 'SMOTE-10924', 'SMOTE-10925', 'SMOTE-10926', 'SMOTE-10927', 'SMOTE-10928', 'SMOTE-10929', 'SMOTE-10930', 'SMOTE-10931', 'SMOTE-10932', 'SMOTE-10933', 'SMOTE-10934', 'SMOTE-10935', 'SMOTE-10936', 'SMOTE-10937', 'SMOTE-10938', 'SMOTE-10939', 'SMOTE-10940', 'SMOTE-10941', 'SMOTE-10942', 'SMOTE-10943', 'SMOTE-10944', 'SMOTE-10945', 'SMOTE-10946', 'SMOTE-10947', 'SMOTE-10948', 'SMOTE-10949', 'SMOTE-10950', 'SMOTE-10951', 'SMOTE-10952', 'SMOTE-10953', 'SMOTE-10954', 'SMOTE-10955', 'SMOTE-10956', 'SMOTE-10957', 'SMOTE-10958', 'SMOTE-10959', 'SMOTE-10960', 'SMOTE-10961', 'SMOTE-10962', 'SMOTE-10963', 'SMOTE-10964', 'SMOTE-10965', 'SMOTE-10966', 'SMOTE-10967', 'SMOTE-10968', 'SMOTE-10969', 'SMOTE-10970', 'SMOTE-10971', 'SMOTE-10972', 'SMOTE-10973', 'SMOTE-10974', 'SMOTE-10975', 'SMOTE-10976', 'SMOTE-10977', 'SMOTE-10978', 'SMOTE-10979', 'SMOTE-10980', 'SMOTE-10981', 'SMOTE-10982', 'SMOTE-10983', 'SMOTE-10984', 'SMOTE-10985', 'SMOTE-10986', 'SMOTE-10987', 'SMOTE-10988', 'SMOTE-10989', 'SMOTE-10990', 'SMOTE-10991', 'SMOTE-10992', 'SMOTE-10993', 'SMOTE-10994', 'SMOTE-10995', 'SMOTE-10996', 'SMOTE-10997', 'SMOTE-10998', 'SMOTE-10999', 'SMOTE-11000', 'SMOTE-11001', 'SMOTE-11002', 'SMOTE-11003', 'SMOTE-11004', 'SMOTE-11005', 'SMOTE-11006', 'SMOTE-11007', 'SMOTE-11008', 'SMOTE-11009', 'SMOTE-11010', 'SMOTE-11011', 'SMOTE-11012', 'SMOTE-11013', 'SMOTE-11014', 'SMOTE-11015', 'SMOTE-11 ...

# %%
train_res.loc[len(s4):len(train_res)-1, 'ID'] = smote_id
train_res
# Out:
#                ID  Pulsating  all_times_nhist_numpeaks  \
# 0      Star-00163          0                 -0.674126
# 1      Star-00123          1                 -1.626729
# 2      Star-00022          0                 -0.039057
# 3      Star-00708          0                 -0.039057
# 4      Star-00484          0                  0.596012
# ...           ...        ...                       ...
# 1339  SMOTE-11339          1                  0.473173
# 1340  SMOTE-11340          1                 -0.993662
# 1341  SMOTE-11341          1                  0.610021
# 1342  SMOTE-11342          1                  1.061356
# 1343  SMOTE-11343          1                  0.385500
#
#       all_times_nhist_peak1_bin  all_times_nhist_peak2_bin  \
# 0                      0.519174                   0.466681
# 1                      1.911247                  -0.740748
# 2                     -1.012107                   0.013895
# 3                      1.632833                  -0.514355
# 4                     -0.176863                  -1.042605
# ...                         ...                        ...
# 1339                  -0.668664                   0.135630
# 1340                  -0.524004                   0.918516
# 1341                  -1.068148                   0.492761
# 1342                  -0.373715                   0.099776
# 1343                  -0.307476                  -0.104800
#
#       all_times_nhist_peak3_bin  all_times_nhist_peak4_bin  \
# 0                      0.766297                   1.786498
# 1                      0.691384                   0.168331
# 2                     -0.357397                   1.168762
# 3                      0.166993                   1.477630
# 4                     -0.432310                   0.242158
# ...                         ...                        ...
# 1339                  -0.259518                  -1.373200
# 1340                   1.589867                  -0.372796
# 1341                   0.150468                  -0.980256
# 1342                  -0.660900                  -1.102506
# 1343                  -1.105693                  -0.701796
#
#       all_times_nhist_peak_1_to_2  all_times_nhist_peak_1_to_3  \
# 0                       -0.304944                     0.843252
# 1                        1.522002                     1.166420
# 2                       -0.232282                    -0.443941
# 3                       -0.544204                    -0.572606
# 4                       -0.277263                    -0.498198
# ...                           ...                          ...
# 1339                    -0.470559                    -0.589896
# 1340                    -0.377095                    -0.318659
# 1341                    -0.169826                    -0.341273
# 1342                     0.339215                    -0.083127
# 1343                     0.663158                     0.246839
#
#       all_times_nhist_peak_1_to_4  ...  freq1_rel_phase2  freq1_rel_phase3  \
# 0                        0.189055  ...          0.646033          0.908818
# 1                        0.157675  ...          1.532902         -1.224350
# 2                       -0.136007  ...          0.384058          0.882515
# 3                       -0.586661  ...          1.457441         -0.921750
# 4                       -0.370020  ...         -0.829296         -0.057582
# ...                           ...  ...               ...               ...
# 1339                    -0.548709  ...         -0.038051         -0.958444
# 1340                    -0.118490  ...          0.036617          1.595782
# 1341                    -0.177918  ...         -0.194276         -0.105307
# 1342                     0.190607  ...         -0.124422         -0.875222
# 1343                    -0.178181  ...          1.543458          0.709110
#
#       freq1_rel_phase4  freq2_rel_phase2  freq2_rel_phase3  freq2_rel_phase4  \
# 0             1.305379          1.413989          0.174334         -0.188773
# 1             0.710232         -1.272791          1.617586          1.392776
# 2             1.044322         -1.204443         -0.593335         -1.011092
# 3            -1.095322         -0.031960         -0.068737          1.152465
# 4             0.541269          1.529879         -0.689578          1.475290
# ...                ...               ...               ...               ...
# 1339          0.386309         -0.805888          0.697947          0.293784
# 1340          0.586577         -0.903790          0.315474         -0.690108
# 1341          1.257649         -0.697622         -0.195618         -0.123771
# 1342          1.033421         -0.335086         -0.822268         -0.909756
# 1343         -0.986673          1.122309         -0.152466         -1.478277
#
#       freq3_rel_phase2  freq3_rel_phase3  freq3_rel_phase4  \
# 0             0.985693         -0.258841         -1.099919
# 1             0.260283          0.708876          1.030413
# 2             0.592500          0.135213          0.725303
# 3            -0.672518          0.391616         -1.301501
# 4            -1.268004          1.297212          1.327633
# ...                ...               ...               ...
# 1339         -0.667106         -0.192877          1.224979
# 1340         -0.846619          0.819517         -0.407266
# 1341         -0.670504          0.582847          1.003724
# 1342         -0.608352         -0.050957          1.095146
# 1343         -1.115881         -1.387955          0.029941
#
#       freq_model_phi1_phi2
# 0                -0.461571
# 1                 0.400968
# 2                -0.319881
# 3                 0.559262
# 4                -0.059789
# ...                    ...
# 1339             -1.394465
# 1340             -1.583849
# 1341             -1.285203
# 1342             -1.091260
# 1343              1.153847
#
# [1344 rows x 50 columns]

# %%
train_res[745:755]
# Out:
#               ID  Pulsating  all_times_nhist_numpeaks  \
# 745   Star-00795          0                  0.278478
# 746   Star-00221          0                 -0.039057
# 747   Star-00463          0                  0.596012
# 748   Star-00873          0                 -0.674126
# 749   Star-00998          0                 -0.356591
# 750  SMOTE-10750          1                 -0.299310
# 751  SMOTE-10751          1                  1.231081
# 752  SMOTE-10752          1                 -0.588071
# 753  SMOTE-10753          1                 -0.058033
# 754  SMOTE-10754          1                 -0.674126
#
#      all_times_nhist_peak1_bin  all_times_nhist_peak2_bin  \
# 745                  -0.803296                   1.070396
# 746                  -1.290522                  -0.438891
# 747                  -0.733692                  -1.193534
# 748                  -0.524881                   0.542146
# 749                  -0.037656                  -0.891677
# 750                  -1.119379                   0.055917
# 751                  -0.834230                  -1.367520
# 752                  -0.748973                  -0.438891
# 753                  -0.535140                  -1.113560
# 754                  -0.524881                   0.013895
#
#      all_times_nhist_peak3_bin  all_times_nhist_peak4_bin  \
# 745                   0.991036                   1.168762
# 746                  -1.630917                  -0.916097
# 747                  -0.731962                  -0.993314
# 748                   0.916123                   1.245979
# 749                   0.316819                   0.087724
# 750                  -1.467186                  -0.409797
# 751                   0.620631                   0.799833
# 752                  -0.141392                   1.019764
# 753                  -0.613474                   0.273229
# 754                   0.691384                   0.396592
#
#      all_times_nhist_peak_1_to_2  all_times_nhist_peak_1_to_3  \
# 745                     0.022969                    -0.301300
# 746                     1.116014                     0.520084
# 747                    -0.671992                     0.345105
# 748                     0.340946                     0.439292
# 749                    -0.677428                    -0.686637
# 750                     0.621930                     0.608374
# 751                    -0.189566                    -0.218250
# 752                     0.222623                    -0.248203
# 753                    -0.564595                     0.195820
# 754                    -0.466417                     1.196717
#
#      all_times_nhist_peak_1_to_4  ...  freq1_rel_phase2  freq1_rel_phase3  \
# 745                    -0.379804  ...         -0.288258         -0.848774
# 746                    -0.017803  ...          1.636850         -1.044746
# 747                    -0.083419  ...          0.554391         -1.609160
# 748                    -0.069517  ...         -1.035107          0.803325
# 749                    -0.777780  ...          0.139384          0.388687
# 750                     0.038711  ...          1.025909          1.347524
# 751                    -0.484800  ...          0.486116          0.527300
# 752                    -0.457994  ...          0.482778          1.362256
# 753                     0.769002  ...          0.270333          0.938805
# 754                     2.700897  ...         -0.026856          0.340841
#
#      freq1_rel_phase4  freq2_rel_phase2  freq2_rel_phase3  freq2_rel_phase4  \
# 745         -0.854496          1.491923          1.008801         -0.519740
# 746          0.342069         -1.435674         -1.390858         -0.052260
# 747          1.073499         -1.750994         -1.230980         -0.473819
# 748         -0.968768         -1.073748         -0.666836          0.702556
# 749         -0.000302          1.710044          0.342520          0.410963
# 750         -0.026255          1.265853         -0.827561         -0.503325
# 751          0.037320          0.872223          0.224272          0.667999
# 752         -0.877604          0.255059          0.780206          0.152106
# 753          1.109692         -0.133342         -1.186573          0.970733
# 754         -0.346971          0.652152          0.147600         -0.162988
#
#      freq3_rel_phase2  freq3_rel_phase3  freq3_rel_phase4  \
# 745         -1.680259         -1.300470          0.307095
# 746         -1.612403          1.449496         -0.028414
# 747         -0.204503          0.349673          0.121996
# 748         -0.746085          1.140938         -1.325713
# 749         -0.811926         -0.752704         -1.525543
# 750          1.469225         -1.126742         -1.194729
# 751          1.179798         -1.263541          0.781706
# 752          1.055986         -1.575578         -0.556325
# 753         -0.157676          0.057997          1.626616
# 754         -0.034958          1.225039         -0.530609
#
#      freq_model_phi1_phi2
# 745             -1.189971
# 746              1.009892
# 747             -0.524541
# 748              0.126896
# 749             -0.335513
# 750              0.084397
# 751             -0.192169
# 752             -0.164382
# 753             -1.347084
# 754             -1.265664
#
# [10 rows x 50 columns]

# %% [markdown]
# ## Save results

# %% [markdown]
# ### Save the oversampled train set

# %%
train_res.to_csv(S4_TRAIN_SET_OUT_OVS, sep=',', decimal='.', index=False)

# %% [markdown]
# ### Check with the OLD one:

# %%
old_train_res = pd.read_csv("../data/DATASETS_ML/OLD_S4_02_DS_AfterImputing_TrainTest_OVERSAMPLED_n3.csv",
                            sep=',', decimal='.')
old_train_res
# Out:
#       Pulsating  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0             0                 -0.674126                   0.519174
# 1             1                 -1.626729                   1.911247
# 2             0                 -0.039057                  -1.012107
# 3             0                 -0.039057                   1.632833
# 4             0                  0.596012                  -0.176863
# ...         ...                       ...                        ...
# 1339          1                  0.473173                  -0.668664
# 1340          1                 -0.993662                  -0.524004
# 1341          1                  0.610021                  -1.068148
# 1342          1                  1.061356                  -0.373715
# 1343          1                  0.385500                  -0.307476
#
#       all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                      0.466681                   0.766297
# 1                     -0.740748                   0.691384
# 2                      0.013895                  -0.357397
# 3                     -0.514355                   0.166993
# 4                     -1.042605                  -0.432310
# ...                         ...                        ...
# 1339                   0.135630                  -0.259518
# 1340                   0.918516                   1.589867
# 1341                   0.492761                   0.150468
# 1342                   0.099776                  -0.660900
# 1343                  -0.104800                  -1.105693
#
#       all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                      1.786498                    -0.304944
# 1                      0.168331                     1.522002
# 2                      1.168762                    -0.232282
# 3                      1.477630                    -0.544204
# 4                      0.242158                    -0.277263
# ...                         ...                          ...
# 1339                  -1.373200                    -0.470559
# 1340                  -0.372796                    -0.377095
# 1341                  -0.980256                    -0.169826
# 1342                  -1.102506                     0.339215
# 1343                  -0.701796                     0.663158
#
#       all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                        0.843252                     0.189055
# 1                        1.166420                     0.157675
# 2                       -0.443941                    -0.136007
# 3                       -0.572606                    -0.586661
# 4                       -0.498198                    -0.370020
# ...                           ...                          ...
# 1339                    -0.589896                    -0.548709
# 1340                    -0.318659                    -0.118490
# 1341                    -0.341273                    -0.177918
# 1342                    -0.083127                     0.190607
# 1343                     0.246839                    -0.178181
#
#       all_times_nhist_peak_2_to_3  ...  freq1_rel_phase2  freq1_rel_phase3  \
# 0                        1.390901  ...          0.646033          0.908818
# 1                        0.019744  ...          1.532902         -1.224350
# 2                       -0.412519  ...          0.384058          0.882515
# 3                       -0.338658  ...          1.457441         -0.921750
# 4                       -0.451106  ...         -0.829296         -0.057582
# ...                           ...  ...               ...               ...
# 1339                    -0.448373  ...         -0.038051         -0.958444
# 1340                    -0.120285  ...          0.036617          1.595782
# 1341                    -0.341825  ...         -0.194276         -0.105307
# 1342                    -0.361995  ...         -0.124422         -0.875222
# 1343                    -0.246785  ...          1.543458          0.709110
#
#       freq1_rel_phase4  freq2_rel_phase2  freq2_rel_phase3  freq2_rel_phase4  \
# 0             1.305379          1.413989          0.174334         -0.188773
# 1             0.710232         -1.272791          1.617586          1.392776
# 2             1.044322         -1.204443         -0.593335         -1.011092
# 3            -1.095322         -0.031960         -0.068737          1.152465
# 4             0.541269          1.529879         -0.689578          1.475290
# ...                ...               ...               ...               ...
# 1339          0.386309         -0.805888          0.697947          0.293784
# 1340          0.586577         -0.903790          0.315474         -0.690108
# 1341          1.257649         -0.697622         -0.195618         -0.123771
# 1342          1.033421         -0.335086         -0.822268         -0.909756
# 1343         -0.986673          1.122309         -0.152466         -1.478277
#
#       freq3_rel_phase2  freq3_rel_phase3  freq3_rel_phase4  \
# 0             0.985693         -0.258841         -1.099919
# 1             0.260283          0.708876          1.030413
# 2             0.592500          0.135213          0.725303
# 3            -0.672518          0.391616         -1.301501
# 4            -1.268004          1.297212          1.327633
# ...                ...               ...               ...
# 1339         -0.667106         -0.192877          1.224979
# 1340         -0.846619          0.819517         -0.407266
# 1341         -0.670504          0.582847          1.003724
# 1342         -0.608352         -0.050957          1.095146
# 1343         -1.115881         -1.387955          0.029941
#
#       freq_model_phi1_phi2
# 0                -0.461571
# 1                 0.400968
# 2                -0.319881
# 3                 0.559262
# 4                -0.059789
# ...                    ...
# 1339             -1.394465
# 1340             -1.583849
# 1341             -1.285203
# 1342             -1.091260
# 1343              1.153847
#
# [1344 rows x 49 columns]

# %%
np.allclose(train_res.drop(columns=['ID']), train_res_old)
# Out:
# True

# %% [markdown]
# ## Summary

# %% [markdown]
# **RESULTS:**
#
# - We applied the oversampling over the Train set, and stored the results.
# - We also added the `ID` for the original stars, and created a new identifier for the stars added for SMOTE.
