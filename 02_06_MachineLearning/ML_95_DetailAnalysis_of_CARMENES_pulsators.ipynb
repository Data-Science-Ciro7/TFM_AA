# %% [markdown]
# # DETAILED ANALYSIS OF CARMENES STARS

# %% [markdown]
# In this notebook we make a detailed analysis of the two stars marked as pulsators by the default ML model.

# %% [markdown]
# ## Modules and configuration

# %% [markdown]
# ### Modules

# %%
import pandas as pd
import numpy as np

import sys

from matplotlib import pyplot as plt

import seaborn as sns
sns.set_style("white", {'figure.figsize':(15,10)})

# %% [markdown]
# ### Configuration

# %%
CARMENES_PREDICTIONS_IN = "../data/ML_MODELS/Results_DecisionTree/FINAL_DT_Scaled_CARMENES_Predictions_wMetadata.csv"
PG_INFO_IN = "../data/SELECTION_for_ML_CARM_VIS_objects_with_PG.csv"

SYNTHETIC_CURVES_IN = "../data/SYNTH_RV_SAMPLES/RV_ALTERNATIVE_S4B_Sample.csv"

CARMENES_DETAILS_OUT = "../data/ML_MODELS/Results_DecisionTree/FINAL_DT_Scaled_CARMENES_Predictions_CompleteInfo.csv"

# 2 PULSATORS:
CARM_2PULSATORS_DETAILS_OUT = "../data/FINAL_CARMENES_2Pulsators_Details.csv"
LTX_CARM_2PULSATORS_DETAILS_OUT = "../data/ML_MODELS/Results_DecisionTree/FINAL_CARMENES_2Pulsators_Details.tex"
LTX_CARM_PRED_WITH_INFO = "../data/ML_MODELS/Results_DecisionTree/FINAL_CARMENES_Predictions_wInfo.tex"

IMG_FOLDER = "./img/"

# %% [markdown]
# ### Functions

# %% [markdown]
# ## Load and transform data

# %% [markdown]
# ### Load the CARMENES predictions

# %%
carm_pred_load = pd.read_csv(CARMENES_PREDICTIONS_IN, sep=',', decimal='.')
carm_pred_load
# Out:
#            Karmn  Pulsation predicted  Pulsation probability        Name Comp  \
# 0     J23505-095                    0               0.009009  LP 763-012    -
# 1     J23492+024                    0               0.009009      BR Psc    -
# 2     J23431+365                    0               0.000000     GJ 1289    -
# 3     J23419+441                    0               0.000000      HH And    -
# 4     J23381-162                    0               0.000000   G 273-093    -
# ..           ...                  ...                    ...         ...  ...
# 228   J00184+440                    0               0.285714      GQ And    B
# 229   J00183+440                    0               0.000000      GX And    A
# 230  J00162+198E                    0               0.000000  LP 404-062    B
# 231   J00067-075                    0               0.000000     GJ 1002    -
# 232   J00051+457                    0               0.000000        GJ 2    C
#
#         GJ  RA_J2016_deg  DE_J2016_deg     RA_J2000     DE_J2000  ...  \
# 0     4367    357.634705     -9.560964  23:50:31.64  -09:33:32.7  ...
# 1      908    357.306604      2.396918  23:49:12.53  +02:24:04.4  ...
# 2     1289    355.781509     36.536310  23:43:06.31  +36:32:13.1  ...
# 3      905    355.480015     44.170376  23:41:55.04  +44:10:38.8  ...
# 4     4352    354.532687    -16.236514  23:38:08.16  -16:14:10.2  ...
# ..     ...           ...           ...          ...          ...  ...
# 228    15B      4.625301     44.028745  00:18:25.82  +44:01:38.1  ...
# 229    15A      4.613226     44.024787  00:18:22.88  +44:01:22.6  ...
# 230  1006B      4.070651     19.860692  00:16:16.15  +19:51:50.5  ...
# 231   1002      1.676350     -7.546475  00:06:43.20  -07:32:17.0  ...
# 232      2      1.300921     45.785894  00:05:10.89  +45:47:11.6  ...
#
#      LoRes_spectrum  HiRes_spectrum LoRes_imaging          HiRes_imaging  \
# 0               NaN           FEROS           NaN     FastCam (Astralux)
# 1               NaN      CAFE FEROS           NaN         FastCam [WD15]
# 2               NaN             NaN           NaN                FastCam
# 3             CAFOS             NaN           NaN  (Astralux) [LuckyCam]
# 4               NaN           FEROS           NaN                FastCam
# ..              ...             ...           ...                    ...
# 228             NaN             NaN           TCP                FastCam
# 229           CAFOS             NaN           TCP         FastCam [WD15]
# 230           CAFOS           FEROS           TCP   (FastCam) (Astralux)
# 231             NaN             NaN           NaN                FastCam
# 232             NaN            CAFE           NaN                 [WD15]
#
#      Class Survey  Notes            Gaia_id_1          2MASS_id      TIC_id
# 0    Alpha    GTO    NaN  2435125446129139712  23503159-0933320     9697711
# 1    Alpha    GTO    NaN  2739689239311660672  23491255+0224037   267255253
# 2    Alpha    GTO    NaN  2879455480942629248  23430628+3632132   352593978
# 3    Alpha    GTO    NaN  1926461164913660160  23415498+4410407  2041185141
# 4    Alpha    GTO    NaN  2395413147718069504  23380819-1614100   434106275
# ..     ...    ...    ...                  ...               ...         ...
# 228  Alpha    GTO    NaN   385334196532776576  00182549+4401376   440109718
# 229  Alpha    GTO    NaN   385334230892516480  00182256+4401222   440109725
# 230  Alpha    GTO    NaN  2797745549200773120  00161607+1951515   150899677
# 231  Alpha    GTO    NaN  2441630500517079808  00064325-0732147   176287658
# 232  Alpha    GTO    NaN   386655019234959872  00051079+4547116   439946126
#
# [233 rows x 177 columns]

# %%
print(list(carm_pred_load.columns))
# Out:
# ['Karmn', 'Pulsation predicted', 'Pulsation probability', 'Name', 'Comp', 'GJ', 'RA_J2016_deg', 'DE_J2016_deg', 'RA_J2000', 'DE_J2000', 'l_J2016_deg', 'b_J2016_deg', 'Ref01', 'SpT', 'SpTnum', 'Ref02', 'Teff_K', 'eTeff_K', 'logg', 'elogg', '[Fe/H]', 'e[Fe/H]', 'Ref03', 'L_Lsol', 'eL_Lsol', 'Ref04', 'R_Rsol', 'eR_Rsol', 'Ref05', 'M_Msol', 'eM_Msol', 'Ref06', 'muRA_masa-1', 'emuRA_masa-1', 'muDE_masa-1', 'emuDE_masa-1', 'Ref07', 'pi_mas', 'epi_mas', 'Ref08', 'd_pc', 'ed_pc', 'Ref09', 'Vr_kms-1', 'eVr_kms-1', 'Ref10', 'ruwe', 'Ref11', 'U_kms-1', 'eU_kms-1', 'V_kms-1', 'eV_kms-1', 'W_kms-1', 'eW_kms-1', 'Ref12', 'sa_m/s/a', 'esa_m/s/a', 'Ref13', 'SKG', 'Ref14', 'SKG_lit', 'Ref14_lit', 'Pop', 'Ref15', 'vsini_flag', 'vsini_kms-1', 'evsini_kms-1', 'Ref16', 'P_d', 'eP_d', 'Ref17', 'pEWHalpha_A', 'epEWHalpha_A', 'Ref18', 'log(LHalpha/Lbol)', 'elog(LHalpha/Lbol)', 'Ref19', '1RXS', 'CRT_s-1', 'eCRT_s-1', 'HR1', 'eHR1', 'HR2', 'eHR2', 'Flux_X_E-13_ergcm-2s-1', 'eFlux_X_E-13_ergcm-2s-1', 'LX/LJ', 'eLX/LJ', 'Ref20', 'Activity', 'Ref21', 'FUV_mag', 'eFUV_mag', 'NUV_mag', 'eNUV_mag', 'Ref22', 'u_mag', 'eu_mag', 'Ref23', 'BT_mag', 'eBT_mag', 'Ref24', 'B_mag', 'eB_mag', 'Ref25', 'BP_mag', 'eBP_mag', 'Ref26', 'g_mag', 'eg_mag', 'Ref27', 'VT_mag', 'eVT_mag', 'Ref28', 'V_mag', 'eV_mag', 'Ref29', 'Ra_mag', 'Ref30', 'r_mag', 'er_mag', 'Ref31', 'GG_mag', 'eGG_mag', 'Ref32', 'i_mag', 'ei_mag', 'Ref33', 'RP_mag', 'eRP_mag', 'Ref34', 'IN_mag', 'Ref35', 'J_mag', 'eJ_mag', 'H_mag', 'eH_mag', 'Ks_mag', 'eKs_mag', 'QFlag_2M', 'Ref36', 'W1_mag', 'eW1_mag', 'W2_mag', 'eW2_mag', 'W3_mag', 'eW3_mag', 'W4_mag', 'eW4_mag', 'QFlag_WISE', 'Ref37', 'Multiplicity', 'WideWDS', 'Widerho_arcsec', 'eWiderho_arcsec', 'Ref38', 'WideCompanionName', 'WideCompanionSpT', 'CloseWDS', 'Closerho_arcsec', 'eCloserho_arcsec', 'Ref39', 'CloseCompanionSpT', 'RV', 'Planet', 'Ref40', 'PlanetNum', 'LoRes_spectrum', 'HiRes_spectrum', 'LoRes_imaging', 'HiRes_imaging', 'Class', 'Survey', 'Notes', 'Gaia_id_1', '2MASS_id', 'TIC_id']

# %% [markdown]
# ### Load the periodogram info

# %%
pg_info = pd.read_csv(PG_INFO_IN, sep=',', decimal='.')
pg_info
# Out:
#            Karmn        Name Comp     GJ  RA_J2016_deg  DE_J2016_deg  \
# 0     J23505-095  LP 763-012    -   4367    357.634705     -9.560964
# 1     J23492+024      BR Psc    -    908    357.306604      2.396918
# 2     J23431+365     GJ 1289    -   1289    355.781509     36.536310
# 3     J23419+441      HH And    -    905    355.480015     44.170376
# 4     J23381-162   G 273-093    -   4352    354.532687    -16.236514
# ..           ...         ...  ...    ...           ...           ...
# 228   J00184+440      GQ And    B    15B      4.625301     44.028745
# 229   J00183+440      GX And    A    15A      4.613226     44.024787
# 230  J00162+198E  LP 404-062    B  1006B      4.070651     19.860692
# 231   J00067-075     GJ 1002    -   1002      1.676350     -7.546475
# 232   J00051+457        GJ 2    C      2      1.300921     45.785894
#
#         RA_J2000     DE_J2000  l_J2016_deg  b_J2016_deg  ...  \
# 0    23:50:31.64  -09:33:32.7    80.777067   -67.303426  ...
# 1    23:49:12.53  +02:24:04.4    93.567467   -56.885396  ...
# 2    23:43:06.31  +36:32:13.1   107.922839   -24.336479  ...
# 3    23:41:55.04  +44:10:38.8   109.989338   -16.947350  ...
# 4    23:38:08.16  -16:14:10.2    61.845437   -69.825220  ...
# ..           ...          ...          ...          ...  ...
# 228  00:18:25.82  +44:01:38.1   116.700222   -18.444111  ...
# 229  00:18:22.88  +44:01:22.6   116.690592   -18.446865  ...
# 230  00:16:16.15  +19:51:50.5   111.738263   -42.245679  ...
# 231  00:06:43.20  -07:32:17.0    92.444693   -67.730511  ...
# 232  00:05:10.89  +45:47:11.6   114.559789   -16.332933  ...
#
#     WF_offset_PG_TESS WF_e_offset_PG_TESS  WF_FAP_PG_TESS WF_valid_PG_TESS  \
# 0         1000.000122        9.022946e-07             1.0              1.0
# 1                 NaN                 NaN             NaN              0.0
# 2          999.999512        4.306074e-06             1.0              1.0
# 3                 NaN                 NaN             NaN              0.0
# 4         1000.000122        9.022946e-07             1.0              1.0
# ..                ...                 ...             ...              ...
# 228               NaN                 NaN             NaN              0.0
# 229        999.999756        2.134945e-06             1.0              1.0
# 230               NaN                 NaN             NaN              0.0
# 231               NaN                 NaN             NaN              0.0
# 232        999.999756        2.134945e-06             1.0              1.0
#
#                                       WF_error_PG_TESS  \
# 0                                                  NaN
# 1    Not recognized as a supported data product:\nn...
# 2                                                  NaN
# 3    Not recognized as a supported data product:\nn...
# 4                                                  NaN
# ..                                                 ...
# 228  Not recognized as a supported data product:\nn...
# 229                                                NaN
# 230  Not recognized as a supported data product:\nn...
# 231  Not recognized as a supported data product:\nn...
# 232                                                NaN
#
#      WF_elapsed_time_PG_TESS  \
# 0                 132.607176
# 1                   0.001995
# 2                  97.939914
# 3                   0.000998
# 4                 136.603404
# ..                       ...
# 228                 0.000998
# 229               191.241441
# 230                 0.001995
# 231                 0.001995
# 232               187.918468
#
#                                     WF_plain_file_TESS  \
# 0    ../data/CARM_VIS_TESS_WinFunc_PGs/WF_J23505-09...
# 1                                                  NaN
# 2    ../data/CARM_VIS_TESS_WinFunc_PGs/WF_J23431+36...
# 3                                                  NaN
# 4    ../data/CARM_VIS_TESS_WinFunc_PGs/WF_J23381-16...
# ..                                                 ...
# 228                                                NaN
# 229  ../data/CARM_VIS_TESS_WinFunc_PGs/WF_J00183+44...
# 230                                                NaN
# 231                                                NaN
# 232  ../data/CARM_VIS_TESS_WinFunc_PGs/WF_J00051+45...
#
#                                       WF_fig_file_TESS  \
# 0    ../data/CARM_VIS_TESS_WinFunc_PGs/figures/WF_J...
# 1                                                  NaN
# 2    ../data/CARM_VIS_TESS_WinFunc_PGs/figures/WF_J...
# 3                                                  NaN
# 4    ../data/CARM_VIS_TESS_WinFunc_PGs/figures/WF_J...
# ..                                                 ...
# 228                                                NaN
# 229  ../data/CARM_VIS_TESS_WinFunc_PGs/figures/WF_J...
# 230                                                NaN
# 231                                                NaN
# 232  ../data/CARM_VIS_TESS_WinFunc_PGs/figures/WF_J...
#
#                                          PG_file_RV  \
# 0     ../data/CARM_VIS_RVs_PGs/J23505-095_RV_PG.dat
# 1     ../data/CARM_VIS_RVs_PGs/J23492+024_RV_PG.dat
# 2     ../data/CARM_VIS_RVs_PGs/J23431+365_RV_PG.dat
# 3     ../data/CARM_VIS_RVs_PGs/J23419+441_RV_PG.dat
# 4     ../data/CARM_VIS_RVs_PGs/J23381-162_RV_PG.dat
# ..                                              ...
# 228   ../data/CARM_VIS_RVs_PGs/J00184+440_RV_PG.dat
# 229   ../data/CARM_VIS_RVs_PGs/J00183+440_RV_PG.dat
# 230  ../data/CARM_VIS_RVs_PGs/J00162+198E_RV_PG.dat
# 231   ../data/CARM_VIS_RVs_PGs/J00067-075_RV_PG.dat
# 232   ../data/CARM_VIS_RVs_PGs/J00051+457_RV_PG.dat
#
#                                        PG_file_TESS
# 0    ../data/CARM_VIS_TESS_PGs/J23505-095_RV_PG.dat
# 1                                               NaN
# 2    ../data/CARM_VIS_TESS_PGs/J23431+365_RV_PG.dat
# 3                                               NaN
# 4    ../data/CARM_VIS_TESS_PGs/J23381-162_RV_PG.dat
# ..                                              ...
# 228                                             NaN
# 229  ../data/CARM_VIS_TESS_PGs/J00183+440_RV_PG.dat
# 230                                             NaN
# 231                                             NaN
# 232  ../data/CARM_VIS_TESS_PGs/J00051+457_RV_PG.dat
#
# [233 rows x 300 columns]

# %%
print(list(pg_info.columns))
# Out:
# ['Karmn', 'Name', 'Comp', 'GJ', 'RA_J2016_deg', 'DE_J2016_deg', 'RA_J2000', 'DE_J2000', 'l_J2016_deg', 'b_J2016_deg', 'Ref01', 'SpT', 'SpTnum', 'Ref02', 'Teff_K', 'eTeff_K', 'logg', 'elogg', '[Fe/H]', 'e[Fe/H]', 'Ref03', 'L_Lsol', 'eL_Lsol', 'Ref04', 'R_Rsol', 'eR_Rsol', 'Ref05', 'M_Msol', 'eM_Msol', 'Ref06', 'muRA_masa-1', 'emuRA_masa-1', 'muDE_masa-1', 'emuDE_masa-1', 'Ref07', 'pi_mas', 'epi_mas', 'Ref08', 'd_pc', 'ed_pc', 'Ref09', 'Vr_kms-1', 'eVr_kms-1', 'Ref10', 'ruwe', 'Ref11', 'U_kms-1', 'eU_kms-1', 'V_kms-1', 'eV_kms-1', 'W_kms-1', 'eW_kms-1', 'Ref12', 'sa_m/s/a', 'esa_m/s/a', 'Ref13', 'SKG', 'Ref14', 'SKG_lit', 'Ref14_lit', 'Pop', 'Ref15', 'vsini_flag', 'vsini_kms-1', 'evsini_kms-1', 'Ref16', 'P_d', 'eP_d', 'Ref17', 'pEWHalpha_A', 'epEWHalpha_A', 'Ref18', 'log(LHalpha/Lbol)', 'elog(LHalpha/Lbol)', 'Ref19', '1RXS', 'CRT_s-1', 'eCRT_s-1', 'HR1', 'eHR1', 'HR2', 'eHR2', 'Flux_X_E-13_ergcm-2s-1', 'eFlux_X_E-13_ergcm-2s-1', 'LX/LJ', 'eLX/LJ', 'Ref20', 'Activity', 'Ref21', 'FUV_mag', 'eFUV_mag', 'NUV_mag', 'eNUV_mag', 'Ref22', 'u_mag', 'eu_mag', 'Ref23', 'BT_mag', 'eBT_mag', 'Ref24', 'B_mag', 'eB_mag', 'Ref25', 'BP_mag', 'eBP_mag', 'Ref26', 'g_mag', 'eg_mag', 'Ref27', 'VT_mag', 'eVT_mag', 'Ref28', 'V_mag', 'eV_mag', 'Ref29', 'Ra_mag', 'Ref30', 'r_mag', 'er_mag', 'Ref31', 'GG_mag', 'eGG_mag', 'Ref32', 'i_mag', 'ei_mag', 'Ref33', 'RP_mag', 'eRP_mag', 'Ref34', 'IN_mag', 'Ref35', 'J_mag', 'eJ_mag', 'H_mag', 'eH_mag', 'Ks_mag', 'eKs_mag', 'QFlag_2M', 'Ref36', 'W1_mag', 'eW1_mag', 'W2_mag', 'eW2_mag', 'W3_mag', 'eW3_mag', 'W4_mag', 'eW4_mag', 'QFlag_WISE', 'Ref37', 'Multiplicity', 'WideWDS', 'Widerho_arcsec', 'eWiderho_arcsec', 'Ref38', 'WideCompanionName', 'WideCompanionSpT', 'CloseWDS', 'Closerho_arcsec', 'eCloserho_arcsec', 'Ref39', 'CloseCompanionSpT', 'RV', 'Planet', 'Ref40', 'PlanetNum', 'LoRes_spectrum', 'HiRes_spectrum', 'LoRes_imaging', 'HiRes_imaging', 'Class', 'Survey', 'Notes', 'Gaia_id_1', '2MASS_id', 'TIC_id', 'Teff_min_K', 'Teff_max_K', 'logg_min', 'logg_max', 'is_GTO', 'rv_file', 'lc_file', 'has_rv', 'has_lc', 'InstBand_nominal', 'InstBand_ranged', 'n_RV', 'Ps_RV', 'fs_RV', 'wmean_RV', 'wrms_RV', 'info_PG_RV', 'maxP_PG_RV', 'maxSNR_PG_RV', 'rms_PG_RV', 'f_PG_RV', 'e_f_PG_RV', 'Pd_PG_RV', 'e_Pd_PG_RV', 'Ph_PG_RV', 'e_Ph_PG_RV', 'Pm_PG_RV', 'e_Pm_PG_RV', 'A_PG_RV', 'e_A_PG_RV', 'ph_PG_RV', 'e_ph_PG_RV', 'T0_PG_RV', 'e_T0_PG_RV', 'offset_PG_RV', 'e_offset_PG_RV', 'FAP_PG_RV', 'valid_PG_RV', 'error_PG_RV', 'elapsed_time_PG_RV', 'fits_file_RV', 'fig_file_RV', 'n_TESS', 'Ps_TESS', 'fs_TESS', 'wmean_TESS', 'wrms_TESS', 'info_PG_TESS', 'maxP_PG_TESS', 'maxSNR_PG_TESS', 'rms_PG_TESS', 'f_PG_TESS', 'e_f_PG_TESS', 'Pd_PG_TESS', 'e_Pd_PG_TESS', 'Ph_PG_TESS', 'e_Ph_PG_TESS', 'Pm_PG_TESS', 'e_Pm_PG_TESS', 'A_PG_TESS', 'e_A_PG_TESS', 'ph_PG_TESS', 'e_ph_PG_TESS', 'T0_PG_TESS', 'e_T0_PG_TESS', 'offset_PG_TESS', 'e_offset_PG_TESS', 'FAP_PG_TESS', 'valid_PG_TESS', 'error_PG_TESS', 'elapsed_time_PG_TESS', 'fits_file_TESS', 'fig_file_TESS', 'WF_maxP_PG_RV', 'WF_maxSNR_PG_RV', 'WF_rms_PG_RV', 'WF_f_PG_RV', 'WF_e_f_PG_RV', 'WF_Pd_PG_RV', 'WF_e_Pd_PG_RV', 'WF_Ph_PG_RV', 'WF_e_Ph_PG_RV', 'WF_Pm_PG_RV', 'WF_e_Pm_PG_RV', 'WF_A_PG_RV', 'WF_e_A_PG_RV', 'WF_ph_PG_RV', 'WF_e_ph_PG_RV', 'WF_T0_PG_RV', 'WF_e_T0_PG_RV', 'WF_offset_PG_RV', 'WF_e_offset_PG_RV', 'WF_FAP_PG_RV', 'WF_valid_PG_RV', 'WF_error_PG_RV', 'WF_elapsed_time_PG_RV', 'WF_plain_file_RV', 'WF_fig_file_RV', 'WF_maxP_PG_TESS', 'WF_maxSNR_PG_TESS', 'WF_rms_PG_TESS', 'WF_f_PG_TESS', 'WF_e_f_PG_TESS', 'WF_Pd_PG_TESS', 'WF_e_Pd_PG_TESS', 'WF_Ph_PG_TESS', 'WF_e_Ph_PG_TESS', 'WF_Pm_PG_TESS', 'WF_e_Pm_PG_TESS', 'WF_A_PG_TESS', 'WF_e_A_PG_TESS', 'WF_ph_PG_TESS', 'WF_e_ph_PG_TESS', 'WF_T0_PG_TESS', 'WF_e_T0_PG_TESS', 'WF_offset_PG_TESS', 'WF_e_offset_PG_TESS', 'WF_FAP_PG_TESS', 'WF_valid_PG_TESS', 'WF_error_PG_TESS', 'WF_elapsed_time_PG_TESS', 'WF_plain_file_TESS', 'WF_fig_file_TESS', 'PG_file_RV', 'PG_file_TESS']

# %% [markdown]
# ### Merge periodogram info to predictions

# %%
cols_to_merge = [col for col in list(pg_info.columns) if (col[-3:] == "_RV") or (col[:-5] == "_TESS") \
                 or col == "Karmn" or col == 'InstBand_nominal' or col == 'InstBand_ranged']
print(cols_to_merge)
# Out:
# ['Karmn', 'InstBand_nominal', 'InstBand_ranged', 'n_RV', 'Ps_RV', 'fs_RV', 'wmean_RV', 'wrms_RV', 'info_PG_RV', 'maxP_PG_RV', 'maxSNR_PG_RV', 'rms_PG_RV', 'f_PG_RV', 'e_f_PG_RV', 'Pd_PG_RV', 'e_Pd_PG_RV', 'Ph_PG_RV', 'e_Ph_PG_RV', 'Pm_PG_RV', 'e_Pm_PG_RV', 'A_PG_RV', 'e_A_PG_RV', 'ph_PG_RV', 'e_ph_PG_RV', 'T0_PG_RV', 'e_T0_PG_RV', 'offset_PG_RV', 'e_offset_PG_RV', 'FAP_PG_RV', 'valid_PG_RV', 'error_PG_RV', 'elapsed_time_PG_RV', 'fits_file_RV', 'fig_file_RV', 'WF_maxP_PG_RV', 'WF_maxSNR_PG_RV', 'WF_rms_PG_RV', 'WF_f_PG_RV', 'WF_e_f_PG_RV', 'WF_Pd_PG_RV', 'WF_e_Pd_PG_RV', 'WF_Ph_PG_RV', 'WF_e_Ph_PG_RV', 'WF_Pm_PG_RV', 'WF_e_Pm_PG_RV', 'WF_A_PG_RV', 'WF_e_A_PG_RV', 'WF_ph_PG_RV', 'WF_e_ph_PG_RV', 'WF_T0_PG_RV', 'WF_e_T0_PG_RV', 'WF_offset_PG_RV', 'WF_e_offset_PG_RV', 'WF_FAP_PG_RV', 'WF_valid_PG_RV', 'WF_error_PG_RV', 'WF_elapsed_time_PG_RV', 'WF_plain_file_RV', 'WF_fig_file_RV', 'PG_file_RV']

# %%
carm_pred = carm_pred_load.merge(pg_info[cols_to_merge], how='left', on='Karmn')
carm_pred
# Out:
#            Karmn  Pulsation predicted  Pulsation probability        Name Comp  \
# 0     J23505-095                    0               0.009009  LP 763-012    -
# 1     J23492+024                    0               0.009009      BR Psc    -
# 2     J23431+365                    0               0.000000     GJ 1289    -
# 3     J23419+441                    0               0.000000      HH And    -
# 4     J23381-162                    0               0.000000   G 273-093    -
# ..           ...                  ...                    ...         ...  ...
# 228   J00184+440                    0               0.285714      GQ And    B
# 229   J00183+440                    0               0.000000      GX And    A
# 230  J00162+198E                    0               0.000000  LP 404-062    B
# 231   J00067-075                    0               0.000000     GJ 1002    -
# 232   J00051+457                    0               0.000000        GJ 2    C
#
#         GJ  RA_J2016_deg  DE_J2016_deg     RA_J2000     DE_J2000  ...  \
# 0     4367    357.634705     -9.560964  23:50:31.64  -09:33:32.7  ...
# 1      908    357.306604      2.396918  23:49:12.53  +02:24:04.4  ...
# 2     1289    355.781509     36.536310  23:43:06.31  +36:32:13.1  ...
# 3      905    355.480015     44.170376  23:41:55.04  +44:10:38.8  ...
# 4     4352    354.532687    -16.236514  23:38:08.16  -16:14:10.2  ...
# ..     ...           ...           ...          ...          ...  ...
# 228    15B      4.625301     44.028745  00:18:25.82  +44:01:38.1  ...
# 229    15A      4.613226     44.024787  00:18:22.88  +44:01:22.6  ...
# 230  1006B      4.070651     19.860692  00:16:16.15  +19:51:50.5  ...
# 231   1002      1.676350     -7.546475  00:06:43.20  -07:32:17.0  ...
# 232      2      1.300921     45.785894  00:05:10.89  +45:47:11.6  ...
#
#      WF_e_T0_PG_RV  WF_offset_PG_RV WF_e_offset_PG_RV   WF_FAP_PG_RV  \
# 0              NaN              1.0               NaN            NaN
# 1              NaN              1.0               NaN -5.559949e-114
# 2              NaN              1.0               NaN            NaN
# 3              NaN              1.0               NaN            NaN
# 4              NaN              1.0               NaN            NaN
# ..             ...              ...               ...            ...
# 228            NaN              1.0               NaN            NaN
# 229            NaN              1.0               NaN            NaN
# 230            NaN              1.0               NaN            NaN
# 231            NaN              1.0               NaN  -3.648325e+31
# 232            NaN              1.0               NaN            NaN
#
#      WF_valid_PG_RV WF_error_PG_RV  WF_elapsed_time_PG_RV  \
# 0               1.0            NaN              32.203607
# 1               1.0            NaN              52.214123
# 2               1.0            NaN              29.366164
# 3               1.0            NaN              34.566373
# 4               1.0            NaN              31.849893
# ..              ...            ...                    ...
# 228             1.0            NaN              41.455405
# 229             1.0            NaN              42.959178
# 230             1.0            NaN              29.341945
# 231             1.0            NaN              33.967957
# 232             1.0            NaN              31.368232
#
#                                       WF_plain_file_RV  \
# 0    ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J23505-095...
# 1    ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J23492+024...
# 2    ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J23431+365...
# 3    ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J23419+441...
# 4    ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J23381-162...
# ..                                                 ...
# 228  ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J00184+440...
# 229  ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J00183+440...
# 230  ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J00162+198...
# 231  ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J00067-075...
# 232  ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J00051+457...
#
#                                         WF_fig_file_RV  \
# 0    ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J2...
# 1    ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J2...
# 2    ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J2...
# 3    ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J2...
# 4    ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J2...
# ..                                                 ...
# 228  ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J0...
# 229  ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J0...
# 230  ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J0...
# 231  ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J0...
# 232  ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J0...
#
#                                          PG_file_RV
# 0     ../data/CARM_VIS_RVs_PGs/J23505-095_RV_PG.dat
# 1     ../data/CARM_VIS_RVs_PGs/J23492+024_RV_PG.dat
# 2     ../data/CARM_VIS_RVs_PGs/J23431+365_RV_PG.dat
# 3     ../data/CARM_VIS_RVs_PGs/J23419+441_RV_PG.dat
# 4     ../data/CARM_VIS_RVs_PGs/J23381-162_RV_PG.dat
# ..                                              ...
# 228   ../data/CARM_VIS_RVs_PGs/J00184+440_RV_PG.dat
# 229   ../data/CARM_VIS_RVs_PGs/J00183+440_RV_PG.dat
# 230  ../data/CARM_VIS_RVs_PGs/J00162+198E_RV_PG.dat
# 231   ../data/CARM_VIS_RVs_PGs/J00067-075_RV_PG.dat
# 232   ../data/CARM_VIS_RVs_PGs/J00051+457_RV_PG.dat
#
# [233 rows x 236 columns]

# %% [markdown]
# Sort the predictions in descending order:

# %%
carm_pred.sort_values(by=['Pulsation probability', 'Karmn'], ascending=[False, True], inplace=True)
carm_pred
# Out:
#           Karmn  Pulsation predicted  Pulsation probability        Name Comp  \
# 161  J08126-215                    1               0.533333      GJ 300    -
# 69   J16581+257                    1               0.533333  BD+25 3173    -
# 214  J02070+496                    0               0.483871   G 173-037    -
# 192  J04376-110                    0               0.483871   BD-11 916    -
# 191  J04429+189                    0               0.483871   HD 285968    -
# ..          ...                  ...                    ...         ...  ...
# 15   J22021+014                    0               0.000000  BD+00 4810    -
# 11   J22503-070                    0               0.000000  BD-07 5871    -
# 4    J23381-162                    0               0.000000   G 273-093    -
# 3    J23419+441                    0               0.000000      HH And    -
# 2    J23431+365                    0               0.000000     GJ 1289    -
#
#        GJ  RA_J2016_deg  DE_J2016_deg     RA_J2000     DE_J2000  ...  \
# 161   300    123.170435    -21.555024  08:12:40.89  -21:33:07.0  ...
# 69    649    254.536304     25.741901  16:58:08.85  +25:44:39.0  ...
# 214   NaN     31.767675     49.643504  02:07:03.86  +49:38:43.5  ...
# 192   173     69.423413    -11.039752  04:37:41.87  -11:02:20.0  ...
# 191   176     70.735482     18.953203  04:42:55.77  +18:57:29.4  ...
# ..    ...           ...           ...          ...          ...  ...
# 15    846    330.540802      1.398992  22:02:10.28  +01:24:00.8  ...
# 11    875    342.580457     -7.089644  22:50:19.42  -07:05:24.4  ...
# 4    4352    354.532687    -16.236514  23:38:08.16  -16:14:10.2  ...
# 3     905    355.480015     44.170376  23:41:55.04  +44:10:38.8  ...
# 2    1289    355.781509     36.536310  23:43:06.31  +36:32:13.1  ...
#
#      WF_e_T0_PG_RV  WF_offset_PG_RV WF_e_offset_PG_RV  WF_FAP_PG_RV  \
# 161            NaN              1.0               NaN           NaN
# 69        0.000123              1.0      8.245824e-18  3.881759e-09
# 214            NaN              1.0               NaN           NaN
# 192            NaN              1.0               NaN           NaN
# 191            NaN              1.0               NaN           NaN
# ..             ...              ...               ...           ...
# 15             NaN              1.0               NaN           NaN
# 11             NaN              1.0               NaN           NaN
# 4              NaN              1.0               NaN           NaN
# 3              NaN              1.0               NaN           NaN
# 2              NaN              1.0               NaN           NaN
#
#      WF_valid_PG_RV WF_error_PG_RV  WF_elapsed_time_PG_RV  \
# 161             1.0            NaN              30.181885
# 69              1.0            NaN              34.175749
# 214             1.0            NaN              29.911611
# 192             1.0            NaN              30.409549
# 191             1.0            NaN              29.675312
# ..              ...            ...                    ...
# 15              1.0            NaN              32.872645
# 11              1.0            NaN              32.156295
# 4               1.0            NaN              31.849893
# 3               1.0            NaN              34.566373
# 2               1.0            NaN              29.366164
#
#                                       WF_plain_file_RV  \
# 161  ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J08126-215...
# 69   ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J16581+257...
# 214  ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J02070+496...
# 192  ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J04376-110...
# 191  ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J04429+189...
# ..                                                 ...
# 15   ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J22021+014...
# 11   ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J22503-070...
# 4    ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J23381-162...
# 3    ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J23419+441...
# 2    ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J23431+365...
#
#                                         WF_fig_file_RV  \
# 161  ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J0...
# 69   ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J1...
# 214  ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J0...
# 192  ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J0...
# 191  ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J0...
# ..                                                 ...
# 15   ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J2...
# 11   ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J2...
# 4    ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J2...
# 3    ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J2...
# 2    ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J2...
#
#                                         PG_file_RV
# 161  ../data/CARM_VIS_RVs_PGs/J08126-215_RV_PG.dat
# 69   ../data/CARM_VIS_RVs_PGs/J16581+257_RV_PG.dat
# 214  ../data/CARM_VIS_RVs_PGs/J02070+496_RV_PG.dat
# 192  ../data/CARM_VIS_RVs_PGs/J04376-110_RV_PG.dat
# 191  ../data/CARM_VIS_RVs_PGs/J04429+189_RV_PG.dat
# ..                                             ...
# 15   ../data/CARM_VIS_RVs_PGs/J22021+014_RV_PG.dat
# 11   ../data/CARM_VIS_RVs_PGs/J22503-070_RV_PG.dat
# 4    ../data/CARM_VIS_RVs_PGs/J23381-162_RV_PG.dat
# 3    ../data/CARM_VIS_RVs_PGs/J23419+441_RV_PG.dat
# 2    ../data/CARM_VIS_RVs_PGs/J23431+365_RV_PG.dat
#
# [233 rows x 236 columns]

# %% [markdown]
# ### Save the full, sorted results

# %%
carm_pred.to_csv(CARMENES_DETAILS_OUT, sep=',', decimal='.', index=False)

# %%
print(list(carm_pred.columns))
# Out:
# ['Karmn', 'Pulsation predicted', 'Pulsation probability', 'Name', 'Comp', 'GJ', 'RA_J2016_deg', 'DE_J2016_deg', 'RA_J2000', 'DE_J2000', 'l_J2016_deg', 'b_J2016_deg', 'Ref01', 'SpT', 'SpTnum', 'Ref02', 'Teff_K', 'eTeff_K', 'logg', 'elogg', '[Fe/H]', 'e[Fe/H]', 'Ref03', 'L_Lsol', 'eL_Lsol', 'Ref04', 'R_Rsol', 'eR_Rsol', 'Ref05', 'M_Msol', 'eM_Msol', 'Ref06', 'muRA_masa-1', 'emuRA_masa-1', 'muDE_masa-1', 'emuDE_masa-1', 'Ref07', 'pi_mas', 'epi_mas', 'Ref08', 'd_pc', 'ed_pc', 'Ref09', 'Vr_kms-1', 'eVr_kms-1', 'Ref10', 'ruwe', 'Ref11', 'U_kms-1', 'eU_kms-1', 'V_kms-1', 'eV_kms-1', 'W_kms-1', 'eW_kms-1', 'Ref12', 'sa_m/s/a', 'esa_m/s/a', 'Ref13', 'SKG', 'Ref14', 'SKG_lit', 'Ref14_lit', 'Pop', 'Ref15', 'vsini_flag', 'vsini_kms-1', 'evsini_kms-1', 'Ref16', 'P_d', 'eP_d', 'Ref17', 'pEWHalpha_A', 'epEWHalpha_A', 'Ref18', 'log(LHalpha/Lbol)', 'elog(LHalpha/Lbol)', 'Ref19', '1RXS', 'CRT_s-1', 'eCRT_s-1', 'HR1', 'eHR1', 'HR2', 'eHR2', 'Flux_X_E-13_ergcm-2s-1', 'eFlux_X_E-13_ergcm-2s-1', 'LX/LJ', 'eLX/LJ', 'Ref20', 'Activity', 'Ref21', 'FUV_mag', 'eFUV_mag', 'NUV_mag', 'eNUV_mag', 'Ref22', 'u_mag', 'eu_mag', 'Ref23', 'BT_mag', 'eBT_mag', 'Ref24', 'B_mag', 'eB_mag', 'Ref25', 'BP_mag', 'eBP_mag', 'Ref26', 'g_mag', 'eg_mag', 'Ref27', 'VT_mag', 'eVT_mag', 'Ref28', 'V_mag', 'eV_mag', 'Ref29', 'Ra_mag', 'Ref30', 'r_mag', 'er_mag', 'Ref31', 'GG_mag', 'eGG_mag', 'Ref32', 'i_mag', 'ei_mag', 'Ref33', 'RP_mag', 'eRP_mag', 'Ref34', 'IN_mag', 'Ref35', 'J_mag', 'eJ_mag', 'H_mag', 'eH_mag', 'Ks_mag', 'eKs_mag', 'QFlag_2M', 'Ref36', 'W1_mag', 'eW1_mag', 'W2_mag', 'eW2_mag', 'W3_mag', 'eW3_mag', 'W4_mag', 'eW4_mag', 'QFlag_WISE', 'Ref37', 'Multiplicity', 'WideWDS', 'Widerho_arcsec', 'eWiderho_arcsec', 'Ref38', 'WideCompanionName', 'WideCompanionSpT', 'CloseWDS', 'Closerho_arcsec', 'eCloserho_arcsec', 'Ref39', 'CloseCompanionSpT', 'RV', 'Planet', 'Ref40', 'PlanetNum', 'LoRes_spectrum', 'HiRes_spectrum', 'LoRes_imaging', 'HiRes_imaging', 'Class', 'Survey', 'Notes', 'Gaia_id_1', '2MASS_id', 'TIC_id', 'InstBand_nominal', 'InstBand_ranged', 'n_RV', 'Ps_RV', 'fs_RV', 'wmean_RV', 'wrms_RV', 'info_PG_RV', 'maxP_PG_RV', 'maxSNR_PG_RV', 'rms_PG_RV', 'f_PG_RV', 'e_f_PG_RV', 'Pd_PG_RV', 'e_Pd_PG_RV', 'Ph_PG_RV', 'e_Ph_PG_RV', 'Pm_PG_RV', 'e_Pm_PG_RV', 'A_PG_RV', 'e_A_PG_RV', 'ph_PG_RV', 'e_ph_PG_RV', 'T0_PG_RV', 'e_T0_PG_RV', 'offset_PG_RV', 'e_offset_PG_RV', 'FAP_PG_RV', 'valid_PG_RV', 'error_PG_RV', 'elapsed_time_PG_RV', 'fits_file_RV', 'fig_file_RV', 'WF_maxP_PG_RV', 'WF_maxSNR_PG_RV', 'WF_rms_PG_RV', 'WF_f_PG_RV', 'WF_e_f_PG_RV', 'WF_Pd_PG_RV', 'WF_e_Pd_PG_RV', 'WF_Ph_PG_RV', 'WF_e_Ph_PG_RV', 'WF_Pm_PG_RV', 'WF_e_Pm_PG_RV', 'WF_A_PG_RV', 'WF_e_A_PG_RV', 'WF_ph_PG_RV', 'WF_e_ph_PG_RV', 'WF_T0_PG_RV', 'WF_e_T0_PG_RV', 'WF_offset_PG_RV', 'WF_e_offset_PG_RV', 'WF_FAP_PG_RV', 'WF_valid_PG_RV', 'WF_error_PG_RV', 'WF_elapsed_time_PG_RV', 'WF_plain_file_RV', 'WF_fig_file_RV', 'PG_file_RV']

# %%
sel_cols_for_predtable = [['Karmn', 'Pulsation probability',
                           'SpT', 'Teff_K', 'logg', '[Fe/H]', 'L_Lsol', 'R_Rsol', 'eR_Rsol', 'Ref05', 'M_Msol', 'eM_Msol', 'Ref06', 'muRA_masa-1', 'emuRA_masa-1', 'muDE_masa-1', 'emuDE_masa-1', 'Ref07', 'pi_mas', 'epi_mas', 'Ref08', 'd_pc', 'ed_pc', 'Ref09', 'Vr_kms-1', 'eVr_kms-1', 'Ref10', 'ruwe', 'Ref11', 'U_kms-1', 'eU_kms-1', 'V_kms-1', 'eV_kms-1', 'W_kms-1', 'eW_kms-1', 'Ref12', 'sa_m/s/a', 'esa_m/s/a', 'Ref13', 'SKG', 'Ref14', 'SKG_lit', 'Ref14_lit', 'Pop', 'Ref15', 'vsini_flag', 'vsini_kms-1', 'evsini_kms-1', 'Ref16', 'P_d', 'eP_d', 'Ref17', 'pEWHalpha_A', 'epEWHalpha_A', 'Ref18', 'log(LHalpha/Lbol)', 'elog(LHalpha/Lbol)', 'Ref19', '1RXS', 'CRT_s-1', 'eCRT_s-1', 'HR1', 'eHR1', 'HR2', 'eHR2', 'Flux_X_E-13_ergcm-2s-1', 'eFlux_X_E-13_ergcm-2s-1', 'LX/LJ', 'eLX/LJ', 'Ref20', 'Activity', 'Ref21', 'FUV_mag', 'eFUV_mag', 'NUV_mag', 'eNUV_mag', 'Ref22', 'u_mag', 'eu_mag', 'Ref23', 'BT_mag', 'eBT_mag', 'Ref24', 'B_mag', 'eB_mag', 'Ref25', 'BP_mag', 'eBP_mag', 'Ref26', 'g_mag', 'eg_mag', 'Ref27', 'VT_mag', 'eVT_mag', 'Ref28', 'V_mag', 'eV_mag', 'Ref29', 'Ra_mag', 'Ref30', 'r_mag', 'er_mag', 'Ref31', 'GG_mag', 'eGG_mag', 'Ref32', 'i_mag', 'ei_mag', 'Ref33', 'RP_mag', 'eRP_mag', 'Ref34', 'IN_mag', 'Ref35', 'J_mag', 'eJ_mag', 'H_mag', 'eH_mag', 'Ks_mag', 'eKs_mag', 'QFlag_2M', 'Ref36', 'W1_mag', 'eW1_mag', 'W2_mag', 'eW2_mag', 'W3_mag', 'eW3_mag', 'W4_mag', 'eW4_mag', 'QFlag_WISE', 'Ref37', 'Multiplicity', 'WideWDS', 'Widerho_arcsec', 'eWiderho_arcsec', 'Ref38', 'WideCompanionName', 'WideCompanionSpT', 'CloseWDS', 'Closerho_arcsec', 'eCloserho_arcsec', 'Ref39', 'CloseCompanionSpT', 'RV', 'Planet', 'Ref40', 'PlanetNum', 'LoRes_spectrum', 'HiRes_spectrum', 'LoRes_imaging', 'HiRes_imaging', 'Class', 'Survey', 'Notes', 'Gaia_id_1', '2MASS_id', 'TIC_id', 'n_RV', 'Ps_RV', 'fs_RV', 'wmean_RV', 'wrms_RV', 'info_PG_RV', 'maxP_PG_RV', 'maxSNR_PG_RV', 'rms_PG_RV', 'f_PG_RV', 'e_f_PG_RV', 'Pd_PG_RV', 'e_Pd_PG_RV', 'Ph_PG_RV', 'e_Ph_PG_RV', 'Pm_PG_RV', 'e_Pm_PG_RV', 'A_PG_RV', 'e_A_PG_RV', 'ph_PG_RV', 'e_ph_PG_RV', 'T0_PG_RV', 'e_T0_PG_RV', 'offset_PG_RV', 'e_offset_PG_RV', 'FAP_PG_RV', 'valid_PG_RV', 'error_PG_RV', 'elapsed_time_PG_RV', 'fits_file_RV', 'fig_file_RV', 'WF_maxP_PG_RV', 'WF_maxSNR_PG_RV', 'WF_rms_PG_RV', 'WF_f_PG_RV', 'WF_e_f_PG_RV', 'WF_Pd_PG_RV', 'WF_e_Pd_PG_RV', 'WF_Ph_PG_RV', 'WF_e_Ph_PG_RV', 'WF_Pm_PG_RV', 'WF_e_Pm_PG_RV', 'WF_A_PG_RV', 'WF_e_A_PG_RV', 'WF_ph_PG_RV', 'WF_e_ph_PG_RV', 'WF_T0_PG_RV', 'WF_e_T0_PG_RV', 'WF_offset_PG_RV', 'WF_e_offset_PG_RV', 'WF_FAP_PG_RV', 'WF_valid_PG_RV', 'WF_error_PG_RV', 'WF_elapsed_time_PG_RV', 'WF_plain_file_RV', 'WF_fig_file_RV', 'PG_file_RV']]

# %% [markdown]
# ### Load the synthetic curves information

# %%
syn_df = pd.read_csv(SYNTHETIC_CURVES_IN, sep=',', decimal='.')
syn_df
# Out:
#                      ID  Pulsating  frequency  amplitudeRV  offsetRV  \
# 0      ALT-B_Star-00000       True        8.0          0.1       0.0
# 1      ALT-B_Star-00001      False        0.0          0.0       0.0
# 2      ALT-B_Star-00002       True        8.0          0.1       0.0
# 3      ALT-B_Star-00003      False        0.0          0.0       0.0
# 4      ALT-B_Star-00004       True        8.0          0.1       0.0
# ...                 ...        ...        ...          ...       ...
# 37275  ALT-B_Star-37275      False        0.0          0.0       0.0
# 37276  ALT-B_Star-37276       True       64.0          1.6       0.0
# 37277  ALT-B_Star-37277      False        0.0          0.0       0.0
# 37278  ALT-B_Star-37278       True       64.0          1.6       0.0
# 37279  ALT-B_Star-37279      False        0.0          0.0       0.0
#
#        refepochRV  phase  CARMENES_source_idx CARMENES_Ref_star  \
# 0             0.0   0.00                    0        J23505-095
# 1             0.0   0.00                    0        J23505-095
# 2             0.0   0.25                    0        J23505-095
# 3             0.0   0.00                    0        J23505-095
# 4             0.0   0.50                    0        J23505-095
# ...           ...    ...                  ...               ...
# 37275         0.0   0.00                  232        J00051+457
# 37276         0.0   0.50                  232        J00051+457
# 37277         0.0   0.00                  232        J00051+457
# 37278         0.0   0.75                  232        J00051+457
# 37279         0.0   0.00                  232        J00051+457
#
#        errorRV_dist_loc  errorRV_dist_scale  errorRV_mean  errorRV_median  \
# 0              1.691561            0.290193      1.816338           1.740
# 1              1.691561            0.290193      1.762535           1.720
# 2              1.691561            0.290193      1.802535           1.690
# 3              1.691561            0.290193      1.631268           1.560
# 4              1.691561            0.290193      1.750704           1.730
# ...                 ...                 ...           ...             ...
# 37275          0.907302            0.727212      1.849423           1.680
# 37276          0.907302            0.727212      1.660769           1.530
# 37277          0.907302            0.727212      1.863077           1.645
# 37278          0.907302            0.727212      1.979615           1.660
# 37279          0.907302            0.727212      1.706731           1.655
#
#        errorRV_stdev         Tobs   Ps_mean  Ps_median   Ps_stdev  NumPoints  \
# 0           0.496892  1581.691279  22.59559   2.908164  69.264784       71.0
# 1           0.456927  1581.691279  22.59559   2.908164  69.264784       71.0
# 2           0.553292  1581.691279  22.59559   2.908164  69.264784       71.0
# 3           0.329254  1581.691279  22.59559   2.908164  69.264784       71.0
# 4           0.380797  1581.691279  22.59559   2.908164  69.264784       71.0
# ...              ...          ...       ...        ...        ...        ...
# 37275       0.593589   693.216479  13.59248   3.024201  35.635775       52.0
# 37276       0.478916   693.216479  13.59248   3.024201  35.635775       52.0
# 37277       0.752909   693.216479  13.59248   3.024201  35.635775       52.0
# 37278       0.880542   693.216479  13.59248   3.024201  35.635775       52.0
# 37279       0.455352   693.216479  13.59248   3.024201  35.635775       52.0
#
#                                              S4_ALT_file
# 0      ../data/SYNTH_RV_SAMPLES/S4B_ALTERNATIVE_ts_fi...
# 1      ../data/SYNTH_RV_SAMPLES/S4B_ALTERNATIVE_ts_fi...
# 2      ../data/SYNTH_RV_SAMPLES/S4B_ALTERNATIVE_ts_fi...
# 3      ../data/SYNTH_RV_SAMPLES/S4B_ALTERNATIVE_ts_fi...
# 4      ../data/SYNTH_RV_SAMPLES/S4B_ALTERNATIVE_ts_fi...
# ...                                                  ...
# 37275  ../data/SYNTH_RV_SAMPLES/S4B_ALTERNATIVE_ts_fi...
# 37276  ../data/SYNTH_RV_SAMPLES/S4B_ALTERNATIVE_ts_fi...
# 37277  ../data/SYNTH_RV_SAMPLES/S4B_ALTERNATIVE_ts_fi...
# 37278  ../data/SYNTH_RV_SAMPLES/S4B_ALTERNATIVE_ts_fi...
# 37279  ../data/SYNTH_RV_SAMPLES/S4B_ALTERNATIVE_ts_fi...
#
# [37280 rows x 20 columns]

# %%
print(list(syn_df.columns))
# Out:
# ['ID', 'Pulsating', 'frequency', 'amplitudeRV', 'offsetRV', 'refepochRV', 'phase', 'CARMENES_source_idx', 'CARMENES_Ref_star', 'errorRV_dist_loc', 'errorRV_dist_scale', 'errorRV_mean', 'errorRV_median', 'errorRV_stdev', 'Tobs', 'Ps_mean', 'Ps_median', 'Ps_stdev', 'NumPoints', 'S4_ALT_file']

# %% [markdown]
# ## Analyze the results

# %% [markdown]
# ### Rename columns

# %% [markdown]
# ### Sorted predictions with additional info

# %% [markdown]
# We now prepare a table with the predictions, sorted by prediction probability, with some additional info about the star (spectral type, $T_{eff}$ and $logg$).

# %%
carm_pred[['Karmn', 'InstBand_nominal']].groupby(by='InstBand_nominal').count()
# Out:
#                   Karmn
# InstBand_nominal
# He3-burning         180
# none                 53

# %%
carm_pred[['Karmn', 'InstBand_ranged']].groupby(by='InstBand_ranged').count()
# Out:
#                  Karmn
# InstBand_ranged
# He3-burning        202
# none                31

# %%
carm_pred_info = carm_pred[['Karmn', 'Pulsation probability', 'SpT', 'Teff_K', 'logg', 'V_mag', 'J_mag',
                            'InstBand_nominal', 'InstBand_ranged']].reset_index().copy()
carm_pred_info['InstBand_nominal'] = carm_pred_info['InstBand_nominal'] \
    .map(lambda x: "Yes" if x == "He3-burning" else "No")
carm_pred_info['InstBand_ranged'] = carm_pred_info['InstBand_ranged'] \
    .map(lambda x: "Yes" if x == "He3-burning" else "No")
carm_pred_info.index = carm_pred_info.index + 1
carm_pred_info.head()
# Out:
#    index       Karmn  Pulsation probability     SpT  Teff_K  logg   V_mag  \
# 1    161  J08126-215               0.533333  M4.0 V  3356.0  4.88  12.131
# 2     69  J16581+257               0.533333  M1.0 V  3782.0  4.87   9.837
# 3    214  J02070+496               0.483871  M3.5 V  3455.0  5.16  12.225
# 4    192  J04376-110               0.483871  M1.5 V  3666.0  5.08  10.346
# 5    191  J04429+189               0.483871  M2.0 V  3678.0  5.13  10.007
#
#    J_mag InstBand_nominal InstBand_ranged
# 1  7.601              Yes             Yes
# 2  6.448              Yes             Yes
# 3  8.366               No             Yes
# 4  6.943              Yes             Yes
# 5  6.462               No             Yes

# %%
carm_pred_info[['Karmn', 'Pulsation probability', 'SpT', 'Teff_K', 'logg', 'V_mag', 'J_mag']]
# Out:
#           Karmn  Pulsation probability     SpT  Teff_K  logg   V_mag  J_mag
# 1    J08126-215               0.533333  M4.0 V  3356.0  4.88  12.131  7.601
# 2    J16581+257               0.533333  M1.0 V  3782.0  4.87   9.837  6.448
# 3    J02070+496               0.483871  M3.5 V  3455.0  5.16  12.225  8.366
# 4    J04376-110               0.483871  M1.5 V  3666.0  5.08  10.346  6.943
# 5    J04429+189               0.483871  M2.0 V  3678.0  5.13  10.007  6.462
# ..          ...                    ...     ...     ...   ...     ...    ...
# 229  J22021+014               0.000000  M0.5 V  3882.0  4.97   9.420  6.196
# 230  J22503-070               0.000000  M0.5 V  3900.0  5.01   9.920  6.932
# 231  J23381-162               0.000000  M2.0 V  3570.0  5.07  11.288  7.813
# 232  J23419+441               0.000000  M5.0 V  3186.0  5.15     NaN  6.884
# 233  J23431+365               0.000000  M4.0 V  3301.0  5.18     NaN  8.110
#
# [233 rows x 7 columns]

# %% [raw]
# #### Rename columns

# %% [raw]
# rename_dict = {
#     'f_PG_RV': 'Detected frequency in RV [$\rm{d}^{-1}$]',
#     'A_PG_RV': 'Detected amplitude in RV [$\rm{m\;s}^{-1}$]',
#     'f_PG_TESS': 'Detected frequency in TESS [$\rm{d}^{-1}$]',
#     'A_PG_TESS': 'Detected amplitude in RV [$\rm{e\;s}^{-1}$]',
#     'SpT': 'Spectral type',
#     'Teff_K': 'Effective temperature [$K$]',
#     'logg': '$\log{g}$ value',
#     '[Fe/H]': 'Metallicity [Fe/H]',
#     'L_Lsol': 'Luminosity [$L_{\odot}$]',
#     'R_Rsol': 'Radius [$R_{\odot}$]',
#     'M_Msol': 'Mass [$M_{\odot}$]',
#     'InstBand_nominal': 'In He-Fb IS?',
#     'vsini_flag': 'Rotational velocity flag',
#     'vsini_kms-1': 'Rotational velocity [$\rm{km\;s}^{-1}$]',
#     'P_d': 'Rotational (or cycle) period [$\rm{d}$]',
#     'Planet': 'Exoplanet reported?',
#     'PlanetNum': 'Number of exoplanets',
#     'n_RV': 'Number of RV points',
#     'Ps_RV': 'Average sampling period',
#     'wrms_RV': 'Weigthed RMS [$\rm{m\;s}^{-1}$]',
#     'V_mag': 'V',
#     'J_mag': 'J',
# }

# %% [raw]
# carm_pred.rename(columns=rename_dict, inplace=True)
# carm_pred.head()

# %%
print(list(carm_pred.columns))
# Out:
# ['Karmn', 'Pulsation predicted', 'Pulsation probability', 'Name', 'Comp', 'GJ', 'RA_J2016_deg', 'DE_J2016_deg', 'RA_J2000', 'DE_J2000', 'l_J2016_deg', 'b_J2016_deg', 'Ref01', 'SpT', 'SpTnum', 'Ref02', 'Teff_K', 'eTeff_K', 'logg', 'elogg', '[Fe/H]', 'e[Fe/H]', 'Ref03', 'L_Lsol', 'eL_Lsol', 'Ref04', 'R_Rsol', 'eR_Rsol', 'Ref05', 'M_Msol', 'eM_Msol', 'Ref06', 'muRA_masa-1', 'emuRA_masa-1', 'muDE_masa-1', 'emuDE_masa-1', 'Ref07', 'pi_mas', 'epi_mas', 'Ref08', 'd_pc', 'ed_pc', 'Ref09', 'Vr_kms-1', 'eVr_kms-1', 'Ref10', 'ruwe', 'Ref11', 'U_kms-1', 'eU_kms-1', 'V_kms-1', 'eV_kms-1', 'W_kms-1', 'eW_kms-1', 'Ref12', 'sa_m/s/a', 'esa_m/s/a', 'Ref13', 'SKG', 'Ref14', 'SKG_lit', 'Ref14_lit', 'Pop', 'Ref15', 'vsini_flag', 'vsini_kms-1', 'evsini_kms-1', 'Ref16', 'P_d', 'eP_d', 'Ref17', 'pEWHalpha_A', 'epEWHalpha_A', 'Ref18', 'log(LHalpha/Lbol)', 'elog(LHalpha/Lbol)', 'Ref19', '1RXS', 'CRT_s-1', 'eCRT_s-1', 'HR1', 'eHR1', 'HR2', 'eHR2', 'Flux_X_E-13_ergcm-2s-1', 'eFlux_X_E-13_ergcm-2s-1', 'LX/LJ', 'eLX/LJ', 'Ref20', 'Activity', 'Ref21', 'FUV_mag', 'eFUV_mag', 'NUV_mag', 'eNUV_mag', 'Ref22', 'u_mag', 'eu_mag', 'Ref23', 'BT_mag', 'eBT_mag', 'Ref24', 'B_mag', 'eB_mag', 'Ref25', 'BP_mag', 'eBP_mag', 'Ref26', 'g_mag', 'eg_mag', 'Ref27', 'VT_mag', 'eVT_mag', 'Ref28', 'V_mag', 'eV_mag', 'Ref29', 'Ra_mag', 'Ref30', 'r_mag', 'er_mag', 'Ref31', 'GG_mag', 'eGG_mag', 'Ref32', 'i_mag', 'ei_mag', 'Ref33', 'RP_mag', 'eRP_mag', 'Ref34', 'IN_mag', 'Ref35', 'J_mag', 'eJ_mag', 'H_mag', 'eH_mag', 'Ks_mag', 'eKs_mag', 'QFlag_2M', 'Ref36', 'W1_mag', 'eW1_mag', 'W2_mag', 'eW2_mag', 'W3_mag', 'eW3_mag', 'W4_mag', 'eW4_mag', 'QFlag_WISE', 'Ref37', 'Multiplicity', 'WideWDS', 'Widerho_arcsec', 'eWiderho_arcsec', 'Ref38', 'WideCompanionName', 'WideCompanionSpT', 'CloseWDS', 'Closerho_arcsec', 'eCloserho_arcsec', 'Ref39', 'CloseCompanionSpT', 'RV', 'Planet', 'Ref40', 'PlanetNum', 'LoRes_spectrum', 'HiRes_spectrum', 'LoRes_imaging', 'HiRes_imaging', 'Class', 'Survey', 'Notes', 'Gaia_id_1', '2MASS_id', 'TIC_id', 'InstBand_nominal', 'InstBand_ranged', 'n_RV', 'Ps_RV', 'fs_RV', 'wmean_RV', 'wrms_RV', 'info_PG_RV', 'maxP_PG_RV', 'maxSNR_PG_RV', 'rms_PG_RV', 'f_PG_RV', 'e_f_PG_RV', 'Pd_PG_RV', 'e_Pd_PG_RV', 'Ph_PG_RV', 'e_Ph_PG_RV', 'Pm_PG_RV', 'e_Pm_PG_RV', 'A_PG_RV', 'e_A_PG_RV', 'ph_PG_RV', 'e_ph_PG_RV', 'T0_PG_RV', 'e_T0_PG_RV', 'offset_PG_RV', 'e_offset_PG_RV', 'FAP_PG_RV', 'valid_PG_RV', 'error_PG_RV', 'elapsed_time_PG_RV', 'fits_file_RV', 'fig_file_RV', 'WF_maxP_PG_RV', 'WF_maxSNR_PG_RV', 'WF_rms_PG_RV', 'WF_f_PG_RV', 'WF_e_f_PG_RV', 'WF_Pd_PG_RV', 'WF_e_Pd_PG_RV', 'WF_Ph_PG_RV', 'WF_e_Ph_PG_RV', 'WF_Pm_PG_RV', 'WF_e_Pm_PG_RV', 'WF_A_PG_RV', 'WF_e_A_PG_RV', 'WF_ph_PG_RV', 'WF_e_ph_PG_RV', 'WF_T0_PG_RV', 'WF_e_T0_PG_RV', 'WF_offset_PG_RV', 'WF_e_offset_PG_RV', 'WF_FAP_PG_RV', 'WF_valid_PG_RV', 'WF_error_PG_RV', 'WF_elapsed_time_PG_RV', 'WF_plain_file_RV', 'WF_fig_file_RV', 'PG_file_RV']

# %% [markdown]
# #### Print and store the LaTeX table

# %%
basic_cols = ['Karmn', 'Pulsation probability', 'SpT', 'Teff_K', 'logg', 'V_mag']

# %% [raw]
# sel_basic_cols = [rename_dict[elem] for elem in basic_cols if elem in rename_dict.keys()]
# sel_basic_cols

# %%
print(
    carm_pred_info[basic_cols].to_latex(
        index=True, longtable=True,
        caption=("ML model pulsation probabilities for CARMENES stars.",
                 "ML model pulsation probabilities for CARMENES stars.")
    )
)
# Out:
# \begin{longtable}{llrlrrr}
# \caption[ML model pulsation probabilities for CARMENES stars.]{ML model pulsation probabilities for CARMENES stars.}\\
# \toprule
# {} &        Karmn &  Pulsation probability &      SpT &  Teff\_K &  logg &   V\_mag \\
# \midrule
# \endfirsthead
# \caption[]{ML model pulsation probabilities for CARMENES stars.} \\
# \toprule
# {} &        Karmn &  Pulsation probability &      SpT &  Teff\_K &  logg &   V\_mag \\
# \midrule
# \endhead
# \midrule
# \multicolumn{7}{r}{{Continued on next page}} \\
# \midrule
# \endfoot
#
# \bottomrule
# \endlastfoot
# 1   &   J08126-215 &               0.533333 &   M4.0 V &  3356.0 &  4.88 &  12.131 \\
# 2   &   J16581+257 &               0.533333 &   M1.0 V &  3782.0 &  4.87 &   9.837 \\
# 3   &   J02070+496 &               0.483871 &   M3.5 V &  3455.0 &  5.16 &  12.225 \\
# 4   &   J04376-110 &               0.483871 &   M1.5 V &  3666.0 &  5.08 &  10.346 \\
# 5   &   J04429+189 &               0.483871 &   M2.0 V &  3678.0 &  5.13 &  10.007 \\
# 6   &   J04538-177 &               0.483871 &   M2.0 V &  3582.0 &  5.04 &  10.914 \\
# 7   &   J05019-069 &               0.483871 &   M4.0 V &  3284.0 &  5.13 &  12.166 \\
# 8   &   J05280+096 &               0.483871 &   M3.5 V &  3440.0 &  5.05 &  12.448 \\
# 9   &   J09447-182 &               0.483871 &   M4.0 V &  3417.0 &  4.84 &  12.455 \\
# 10  &   J15013+055 &               0.483871 &   M3.0 V &  3502.0 &  4.98 &  12.265 \\
# 11  &   J15095+031 &               0.483871 &   M3.0 V &  3545.0 &  4.86 &  11.464 \\
# 12  &   J17303+055 &               0.483871 &   M0.0 V &  3821.0 &  4.93 &   9.433 \\
# 13  &   J17355+616 &               0.483871 &   M0.5 V &  3847.0 &  5.02 &   9.976 \\
# 14  &   J18224+620 &               0.483871 &   M4.0 V &  3294.0 &  5.12 &  13.340 \\
# 15  &   J20336+617 &               0.483871 &   M4.0 V &  3406.0 &  4.76 &     NaN \\
# 16  &   J02362+068 &               0.466667 &   M4.0 V &  3335.0 &  4.91 &  11.664 \\
# 17  &   J06011+595 &               0.466667 &   M3.5 V &  3431.0 &  4.97 &  11.736 \\
# 18  &   J06103+821 &               0.466667 &   M2.0 V &  3554.0 &  4.95 &  10.432 \\
# 19  &   J09423+559 &               0.466667 &   M3.5 V &  3439.0 &  4.79 &  12.482 \\
# 20  &   J00389+306 &               0.428571 &   M2.5 V &  3551.0 &  4.90 &  11.000 \\
# 21  &   J01048-181 &               0.428571 &   M5.0 V &  3209.0 &  5.09 &  14.551 \\
# 22  &   J02358+202 &               0.428571 &   M2.0 V &  3703.0 &  4.86 &  10.636 \\
# 23  &   J03181+382 &               0.428571 &   M1.5 V &  3826.0 &  4.61 &  10.280 \\
# 24  &   J03531+625 &               0.428571 &   M3.0 V &  3501.0 &  5.04 &  11.496 \\
# 25  &   J05033-173 &               0.428571 &   M3.0 V &  3464.0 &  5.08 &  11.760 \\
# 26  &   J06371+175 &               0.428571 &   M0.0 V &  3803.0 &  5.20 &   9.767 \\
# 27  &   J07287-032 &               0.428571 &   M3.0 V &  3511.0 &  4.82 &  11.430 \\
# 28  &  J07319+362N &               0.428571 &   M3.5 V &  3289.0 &  5.10 &  11.738 \\
# 29  &   J09307+003 &               0.428571 &   M3.5 V &  3460.0 &  4.90 &  11.727 \\
# 30  &   J10289+008 &               0.428571 &   M2.0 V &  3588.0 &  5.15 &   9.705 \\
# 31  &   J11476+786 &               0.428571 &   M3.5 V &  3361.0 &  4.93 &  10.772 \\
# 32  &   J12479+097 &               0.428571 &   M3.5 V &  3408.0 &  4.82 &  11.393 \\
# 33  &  J14257+236W &               0.428571 &   M0.0 V &  3985.0 &  4.89 &   9.701 \\
# 34  &   J17052-050 &               0.428571 &   M1.5 V &  3587.0 &  4.89 &  10.193 \\
# 35  &   J17578+465 &               0.428571 &   M2.5 V &  3507.0 &  4.93 &  11.741 \\
# 36  &   J18051-030 &               0.428571 &   M1.0 V &  3706.0 &  5.14 &   9.379 \\
# 37  &   J20525-169 &               0.428571 &   M4.0 V &  3382.0 &  5.01 &  11.514 \\
# 38  &   J21466-001 &               0.428571 &   M4.0 V &  3408.0 &  4.82 &     NaN \\
# 39  &   J01550+379 &               0.363636 &   M5.0 V &  3100.0 &  4.50 &     NaN \\
# 40  &   J03090+100 &               0.363636 &   M5.0 V &  3000.0 &  4.00 &     NaN \\
# 41  &   J09597+472 &               0.363636 &   M4.0 V &  3200.0 &  5.50 &  14.083 \\
# 42  &   J09028+680 &               0.300000 &   M4.0 V &  3328.0 &  4.96 &  12.622 \\
# 43  &   J00184+440 &               0.285714 &   M3.5 V &  3318.0 &  5.20 &  11.092 \\
# 44  &   J00286-066 &               0.285714 &   M4.0 V &  3419.0 &  4.81 &  12.112 \\
# 45  &  J02565+554W &               0.285714 &   M1.0 V &  3832.0 &  4.65 &  10.524 \\
# 46  &   J08315+730 &               0.285714 &   M4.0 V &  3364.0 &  4.90 &  12.872 \\
# 47  &   J09360-216 &               0.285714 &   M2.5 V &  3496.0 &  4.95 &  10.920 \\
# 48  &   J10350-094 &               0.285714 &   M3.0 V &  3512.0 &  4.85 &  12.153 \\
# 49  &   J13102+477 &               0.285714 &   M5.0 V &  3221.0 &  5.25 &  14.590 \\
# 50  &   J18075-159 &               0.285714 &   M4.5 V &  3220.0 &  5.23 &  13.548 \\
# 51  &   J20405+154 &               0.285714 &   M4.5 V &  3263.0 &  5.02 &  13.335 \\
# 52  &   J04376+528 &               0.266667 &   M0.0 V &  4039.0 &  4.94 &   8.863 \\
# 53  &   J05348+138 &               0.266667 &   M3.5 V &  3464.0 &  4.85 &  11.816 \\
# 54  &   J07393+021 &               0.266667 &   M0.0 V &  3980.0 &  5.03 &   9.755 \\
# 55  &   J17033+514 &               0.266667 &   M4.5 V &  3273.0 &  4.92 &  13.627 \\
# 56  &   J18165+048 &               0.266667 &   M5.0 V &  3240.0 &  4.97 &  14.631 \\
# 57  &   J18319+406 &               0.266667 &   M3.5 V &  3492.0 &  4.92 &  12.046 \\
# 58  &  J20556-140S &               0.266667 &   M5.0 V &  3193.0 &  4.98 &  14.569 \\
# 59  &   J21019-063 &               0.266667 &   M2.5 V &  3568.0 &  4.95 &  11.276 \\
# 60  &   J22057+656 &               0.266667 &   M1.5 V &  3707.0 &  4.86 &  11.621 \\
# 61  &   J22559+178 &               0.266667 &   M1.0 V &  3814.0 &  4.90 &  10.558 \\
# 62  &   J23216+172 &               0.266667 &   M4.0 V &  3398.0 &  4.81 &  11.714 \\
# 63  &   J23340+001 &               0.266667 &   M2.5 V &  3530.0 &  4.91 &  11.037 \\
# 64  &   J23351-023 &               0.266667 &   M5.5 V &  3136.0 &  5.27 &     NaN \\
# 65  &   J03217-066 &               0.200000 &   M2.0 V &  3661.0 &  5.16 &  11.314 \\
# 66  &   J10088+692 &               0.200000 &   M0.5 V &  3952.0 &  4.94 &  11.493 \\
# 67  &   J11509+483 &               0.200000 &   M4.5 V &  3282.0 &  5.09 &  13.235 \\
# 68  &   J14310-122 &               0.200000 &   M3.5 V &  3450.0 &  4.79 &  11.934 \\
# 69  &   J06024+498 &               0.125000 &   M5.0 V &  3213.0 &  5.17 &  14.520 \\
# 70  &   J15583+354 &               0.125000 &   M3.5 V &  3478.0 &  4.91 &  12.675 \\
# 71  &   J18346+401 &               0.125000 &   M3.5 V &  3447.0 &  4.69 &  11.464 \\
# 72  &  J18427+596N &               0.125000 &   M3.0 V &  3473.0 &  4.90 &   9.056 \\
# 73  &   J20533+621 &               0.125000 &   M1.0 V &  3815.0 &  4.83 &   8.762 \\
# 74  &   J21164+025 &               0.125000 &   M3.0 V &  3550.0 &  4.88 &  11.967 \\
# 75  &   J06421+035 &               0.096774 &   M3.5 V &  3475.0 &  4.88 &  12.062 \\
# 76  &   J10167-119 &               0.096774 &   M3.0 V &  3552.0 &  4.84 &  11.022 \\
# 77  &  J13283-023W &               0.096774 &   M3.0 V &  3554.0 &  4.86 &  11.261 \\
# 78  &   J13293+114 &               0.096774 &   M3.5 V &  3455.0 &  4.83 &  12.238 \\
# 79  &   J18221+063 &               0.096774 &   M4.0 V &  3397.0 &  4.89 &  12.624 \\
# 80  &   J19216+208 &               0.096774 &   M4.5 V &  3278.0 &  5.05 &     NaN \\
# 81  &   J20260+585 &               0.096774 &   M5.0 V &  3223.0 &  4.97 &  13.993 \\
# 82  &   J21466+668 &               0.096774 &   M4.0 V &  3409.0 &  4.85 &  13.078 \\
# 83  &   J13457+148 &               0.076923 &   M1.5 V &  3620.0 &  4.93 &     NaN \\
# 84  &   J14307-086 &               0.076923 &   M0.5 V &  4037.0 &  4.82 &   9.736 \\
# 85  &   J17578+046 &               0.076923 &   M3.5 V &  3254.0 &  5.13 &   9.540 \\
# 86  &   J22565+165 &               0.076923 &   M1.5 V &  3798.0 &  4.80 &   9.142 \\
# 87  &   J23245+578 &               0.076923 &   M1.0 V &  3811.0 &  4.72 &  10.113 \\
# 88  &   J01025+716 &               0.009009 &   M3.0 V &  3524.0 &  4.86 &  10.044 \\
# 89  &   J01026+623 &               0.009009 &   M1.5 V &  3791.0 &  4.76 &   9.765 \\
# 90  &   J01433+043 &               0.009009 &   M2.0 V &  3547.0 &  5.10 &  10.755 \\
# 91  &   J03473+086 &               0.009009 &   M4.5 V &  3100.0 &  5.50 &  14.582 \\
# 92  &   J04290+219 &               0.009009 &   M0.5 V &  4123.0 &  4.48 &   8.496 \\
# 93  &   J06548+332 &               0.009009 &   M3.0 V &  3503.0 &  4.88 &  10.034 \\
# 94  &   J08402+314 &               0.009009 &   M3.5 V &  3426.0 &  4.88 &  12.273 \\
# 95  &   J10185-117 &               0.009009 &   M4.0 V &  3434.0 &  4.74 &  13.140 \\
# 96  &   J10238+438 &               0.009009 &   M5.0 V &  2900.0 &  5.00 &     NaN \\
# 97  &   J11033+359 &               0.009009 &   M1.5 V &  3557.0 &  4.95 &   7.490 \\
# 98  &  J11110+304W &               0.009009 &   M2.0 V &  3730.0 &  4.78 &   9.983 \\
# 99  &   J11306-080 &               0.009009 &   M3.5 V &  3486.0 &  4.90 &  12.016 \\
# 100 &   J11511+352 &               0.009009 &   M1.5 V &  3692.0 &  4.91 &   9.802 \\
# 101 &   J12100-150 &               0.009009 &   M3.5 V &  3415.0 &  4.74 &  12.083 \\
# 102 &   J12111-199 &               0.009009 &   M3.0 V &  3517.0 &  4.92 &  11.692 \\
# 103 &   J12350+098 &               0.009009 &   M2.5 V &  3556.0 &  4.82 &  11.407 \\
# 104 &   J12373-208 &               0.009009 &   M4.0 V &  3431.0 &  4.70 &  13.280 \\
# 105 &   J13119+658 &               0.009009 &   m1.5 V &  3686.0 &  4.83 &  12.951 \\
# 106 &   J14342-125 &               0.009009 &   M4.0 V &  3347.0 &  4.76 &  11.300 \\
# 107 &   J14544+355 &               0.009009 &   M3.5 V &  3433.0 &  4.82 &  12.321 \\
# 108 &   J16092+093 &               0.009009 &   M3.0 V &  3517.0 &  5.06 &  11.729 \\
# 109 &  J18427+596S &               0.009009 &   M3.5 V &  3393.0 &  4.98 &   9.877 \\
# 110 &   J18580+059 &               0.009009 &   M0.5 V &  3857.0 &  4.73 &   9.367 \\
# 111 &   J19072+208 &               0.009009 &   M2.0 V &  3558.0 &  5.06 &     NaN \\
# 112 &   J19242+755 &               0.009009 &   M5.5 V &  3044.0 &  5.06 &     NaN \\
# 113 &   J21474+627 &               0.009009 &     m0 V &  4029.0 &  4.98 &     NaN \\
# 114 &   J22020-194 &               0.009009 &   M3.5 V &  3474.0 &  4.85 &  12.025 \\
# 115 &   J22114+409 &               0.009009 &   M5.5 V &  3132.0 &  5.15 &  15.139 \\
# 116 &   J22330+093 &               0.009009 &   M1.0 V &  3722.0 &  4.98 &  10.365 \\
# 117 &   J23492+024 &               0.009009 &   M1.0 V &  3573.0 &  4.94 &   9.416 \\
# 118 &   J23505-095 &               0.009009 &   M4.0 V &  3377.0 &  4.83 &     NaN \\
# 119 &   J00051+457 &               0.000000 &   M1.0 V &  3773.0 &  5.07 &  10.102 \\
# 120 &   J00067-075 &               0.000000 &   M5.5 V &  3169.0 &  5.20 &  13.837 \\
# 121 &  J00162+198E &               0.000000 &   M4.0 V &  3329.0 &  4.93 &  13.240 \\
# 122 &   J00183+440 &               0.000000 &   M1.0 V &  3603.0 &  4.99 &   8.284 \\
# 123 &   J00570+450 &               0.000000 &   M3.0 V &  3488.0 &  5.04 &  11.972 \\
# 124 &   J01013+613 &               0.000000 &   M2.0 V &  3564.0 &  5.05 &  10.806 \\
# 125 &   J01066+192 &               0.000000 &     m3 V &  3496.0 &  5.00 &  13.124 \\
# 126 &   J01125-169 &               0.000000 &   M4.5 V &  3228.0 &  5.24 &  12.096 \\
# 127 &   J01518+644 &               0.000000 &   M2.5 V &  3625.0 &  5.04 &  11.415 \\
# 128 &   J02015+637 &               0.000000 &   M3.0 V &  3579.0 &  4.87 &  11.023 \\
# 129 &   J02123+035 &               0.000000 &   M1.5 V &  3575.0 &  4.86 &  10.139 \\
# 130 &   J02222+478 &               0.000000 &   M0.5 V &  3894.0 &  4.99 &   9.345 \\
# 131 &   J02442+255 &               0.000000 &   M3.0 V &  3510.0 &  4.97 &  10.586 \\
# 132 &  J02489-145E &               0.000000 &   m2.5 V &  3572.0 &  4.94 &  12.706 \\
# 133 &   J02530+168 &               0.000000 &   M7.0 V &  3034.0 &  5.19 &  15.075 \\
# 134 &   J02573+765 &               0.000000 &     m3 V &  3381.0 &  4.87 &  13.304 \\
# 135 &   J03213+799 &               0.000000 &   M2.0 V &  3599.0 &  5.12 &  11.110 \\
# 136 &   J03463+262 &               0.000000 &   M0.0 V &  3949.0 &  4.83 &   9.580 \\
# 137 &   J04219+213 &               0.000000 &     m0 V &  3940.0 &  4.76 &  12.806 \\
# 138 &   J04225+105 &               0.000000 &   M3.5 V &  3546.0 &  4.71 &  12.510 \\
# 139 &   J04311+589 &               0.000000 &  M4.0 V+ &  3382.0 &  4.89 &  10.977 \\
# 140 &   J04429+214 &               0.000000 &   M3.5 V &  3499.0 &  4.90 &  11.925 \\
# 141 &   J05127+196 &               0.000000 &   M2.0 V &  3599.0 &  4.91 &  10.789 \\
# 142 &   J05314-036 &               0.000000 &   M1.5 V &  3850.0 &  4.71 &   8.363 \\
# 143 &   J05360-076 &               0.000000 &   M4.0 V &  3422.0 &  4.81 &  12.874 \\
# 144 &   J05415+534 &               0.000000 &   M1.0 V &  3825.0 &  4.94 &   9.766 \\
# 145 &   J05421+124 &               0.000000 &   M4.0 V &  3324.0 &  4.93 &  11.483 \\
# 146 &   J06246+234 &               0.000000 &   M4.0 V &  3249.0 &  5.10 &  13.103 \\
# 147 &   J06594+193 &               0.000000 &   M5.0 V &  3146.0 &  5.09 &     NaN \\
# 148 &   J07044+682 &               0.000000 &   M3.0 V &  3527.0 &  4.82 &  11.895 \\
# 149 &   J07274+052 &               0.000000 &   M3.5 V &  3380.0 &  4.96 &   9.909 \\
# 150 &   J07353+548 &               0.000000 &   M2.0 V &  3564.0 &  5.03 &  11.325 \\
# 151 &   J07386-212 &               0.000000 &   M3.0 V &  3488.0 &  4.95 &  11.729 \\
# 152 &   J07582+413 &               0.000000 &   M3.5 V &  3431.0 &  4.87 &  12.015 \\
# 153 &   J08023+033 &               0.000000 &   M4.0 V &  3422.0 &  4.72 &  13.740 \\
# 154 &   J08119+087 &               0.000000 &   M4.5 V &  3245.0 &  5.24 &  12.834 \\
# 155 &   J08161+013 &               0.000000 &   M2.0 V &  3570.0 &  4.98 &  10.099 \\
# 156 &   J08293+039 &               0.000000 &   M2.5 V &  3651.0 &  4.97 &  11.437 \\
# 157 &   J08358+680 &               0.000000 &   M2.5 V &  3496.0 &  5.11 &  11.599 \\
# 158 &   J08526+283 &               0.000000 &   M4.5 V &  3321.0 &  4.87 &  13.148 \\
# 159 &   J08599+729 &               0.000000 &   M4.0 V &  3100.0 &  5.50 &  14.308 \\
# 160 &   J09005+465 &               0.000000 &   M4.5 V &  3293.0 &  5.16 &  13.314 \\
# 161 &   J09163-186 &               0.000000 &   M1.5 V &  3697.0 &  5.11 &  10.739 \\
# 162 &   J09286-121 &               0.000000 &   M2.5 V &  3500.0 &   NaN &  12.262 \\
# 163 &   J09411+132 &               0.000000 &   M1.5 V &  3699.0 &  5.01 &  10.393 \\
# 164 &   J09468+760 &               0.000000 &   M1.5 V &  3616.0 &  4.93 &  10.579 \\
# 165 &   J09511-123 &               0.000000 &   M0.5 V &  3769.0 &  4.84 &  10.069 \\
# 166 &   J10125+570 &               0.000000 &   M3.5 V &  3474.0 &  4.90 &  11.731 \\
# 167 &   J10251-102 &               0.000000 &   M1.0 V &  3759.0 &  4.91 &  10.219 \\
# 168 &   J10396-069 &               0.000000 &   M2.5 V &  3592.0 &  4.89 &  11.278 \\
# 169 &   J10416+376 &               0.000000 &   M4.5 V &  3298.0 &  4.87 &  13.038 \\
# 170 &   J10482-113 &               0.000000 &   M6.5 V &  3029.0 &  5.33 &  15.784 \\
# 171 &   J10508+068 &               0.000000 &   M4.0 V &  3410.0 &  4.92 &  11.696 \\
# 172 &   J11000+228 &               0.000000 &   M2.5 V &  3532.0 &  5.04 &  10.071 \\
# 173 &   J11054+435 &               0.000000 &   M1.0 V &  3628.0 &  5.01 &   8.820 \\
# 174 &  J11110+304E &               0.000000 &     K7 V &  4211.0 &  4.98 &   8.864 \\
# 175 &   J11126+189 &               0.000000 &   M1.5 V &  3752.0 &  4.88 &  10.765 \\
# 176 &   J11289+101 &               0.000000 &   M3.5 V &  3405.0 &  4.86 &  12.610 \\
# 177 &   J11302+076 &               0.000000 &   M2.5 V &  3563.0 &  4.93 &  13.496 \\
# 178 &   J11467-140 &               0.000000 &   M3.0 V &  3565.0 &  4.77 &  11.698 \\
# 179 &   J11477+008 &               0.000000 &   M4.0 V &  3325.0 &  5.09 &  11.114 \\
# 180 &   J12054+695 &               0.000000 &   M4.0 V &  3339.0 &  4.91 &  13.129 \\
# 181 &  J12123+544S &               0.000000 &   M0.0 V &  3902.0 &  4.99 &   9.699 \\
# 182 &   J12248-182 &               0.000000 &   M2.0 V &  3432.0 &  5.09 &  11.345 \\
# 183 &   J12312+086 &               0.000000 &   M0.5 V &  3896.0 &  5.07 &   9.749 \\
# 184 &   J12388+116 &               0.000000 &   M3.0 V &  3525.0 &  4.85 &  11.495 \\
# 185 &   J13196+333 &               0.000000 &   M1.5 V &  3799.0 &  4.67 &  10.598 \\
# 186 &   J13299+102 &               0.000000 &   M0.5 V &  3765.0 &  4.95 &   9.360 \\
# 187 &   J13427+332 &               0.000000 &   M3.5 V &  3430.0 &  4.88 &  11.999 \\
# 188 &   J13450+176 &               0.000000 &   M0.0 V &  3829.0 &  4.99 &   9.805 \\
# 189 &   J13458-179 &               0.000000 &   M3.5 V &  3443.0 &  4.78 &  11.877 \\
# 190 &   J13582+125 &               0.000000 &   M3.0 V &  3442.0 &  5.13 &  12.267 \\
# 191 &   J14010-026 &               0.000000 &   M1.0 V &  3719.0 &  4.89 &   9.716 \\
# 192 &   J14082+805 &               0.000000 &   M1.0 V &  3803.0 &  4.80 &  10.291 \\
# 193 &   J14152+450 &               0.000000 &   M3.0 V &  3516.0 &  4.85 &  11.848 \\
# 194 &   J14251+518 &               0.000000 &   M2.5 V &  3551.0 &  4.90 &  11.458 \\
# 195 &  J14257+236E &               0.000000 &   M0.5 V &  3933.0 &  4.71 &   9.921 \\
# 196 &   J14294+155 &               0.000000 &   M2.0 V &  3660.0 &  4.75 &  10.720 \\
# 197 &   J15100+193 &               0.000000 &   M4.0 V &  3200.0 &  5.50 &  13.419 \\
# 198 &   J15369-141 &               0.000000 &   M4.0 V &  3428.0 &  4.75 &  12.726 \\
# 199 &   J15598-082 &               0.000000 &   M1.0 V &  3707.0 &  5.05 &  10.537 \\
# 200 &   J16028+205 &               0.000000 &   M4.0 V &  3362.0 &  4.97 &  12.474 \\
# 201 &  J16167+672N &               0.000000 &   M3.0 V &  3569.0 &  4.97 &  10.615 \\
# 202 &   J16254+543 &               0.000000 &   M1.5 V &  3595.0 &  5.09 &  10.066 \\
# 203 &   J16303-126 &               0.000000 &   M3.5 V &  3426.0 &  4.89 &  10.101 \\
# 204 &   J16327+126 &               0.000000 &   M3.0 V &  3486.0 &  4.92 &  12.125 \\
# 205 &   J16462+164 &               0.000000 &   M2.5 V &  3560.0 &  4.90 &  11.678 \\
# 206 &  J16554-083N &               0.000000 &   M3.5 V &  3397.0 &  5.07 &  11.762 \\
# 207 &   J17071+215 &               0.000000 &   M3.0 V &  3534.0 &  4.94 &  11.683 \\
# 208 &   J17115+384 &               0.000000 &   M3.5 V &  3472.0 &  4.74 &  11.636 \\
# 209 &   J17166+080 &               0.000000 &   M2.0 V &  3567.0 &  4.89 &  11.490 \\
# 210 &   J17198+417 &               0.000000 &   M2.5 V &  3540.0 &  4.96 &  11.382 \\
# 211 &   J17378+185 &               0.000000 &   M1.0 V &  3663.0 &  5.03 &   9.637 \\
# 212 &   J17542+073 &               0.000000 &   M4.0 V &  3312.0 &  4.86 &  13.204 \\
# 213 &   J18027+375 &               0.000000 &   M5.0 V &  3210.0 &  5.02 &  14.983 \\
# 214 &  J18180+387E &               0.000000 &   M3.0 V &  3495.0 &  5.01 &     NaN \\
# 215 &   J18198-019 &               0.000000 &     K7 V &  4155.0 &  5.01 &   9.919 \\
# 216 &   J18353+457 &               0.000000 &   M0.5 V &  3876.0 &  4.82 &   9.830 \\
# 217 &   J18363+136 &               0.000000 &   M4.0 V &  3335.0 &  5.18 &  12.326 \\
# 218 &   J18419+318 &               0.000000 &   M3.0 V &  3519.0 &  4.93 &     NaN \\
# 219 &   J18480-145 &               0.000000 &   M2.5 V &  3540.0 &  4.92 &  12.043 \\
# 220 &   J19070+208 &               0.000000 &   M2.0 V &  3543.0 &  5.03 &     NaN \\
# 221 &   J19084+322 &               0.000000 &   M3.0 V &  3501.0 &  4.92 &     NaN \\
# 222 &   J19098+176 &               0.000000 &   M4.5 V &  3277.0 &  4.93 &     NaN \\
# 223 &  J19169+051N &               0.000000 &   M2.5 V &  3575.0 &  4.88 &   9.144 \\
# 224 &   J19251+283 &               0.000000 &   M3.0 V &  3472.0 &  4.90 &     NaN \\
# 225 &   J20305+654 &               0.000000 &   M2.5 V &  3514.0 &  5.06 &  10.510 \\
# 226 &   J20567-104 &               0.000000 &   M2.5 V &  3560.0 &  4.91 &     NaN \\
# 227 &   J21348+515 &               0.000000 &   M3.0 V &  3525.0 &  4.87 &  11.722 \\
# 228 &   J21463+382 &               0.000000 &   M4.0 V &  3247.0 &  4.84 &  12.210 \\
# 229 &   J22021+014 &               0.000000 &   M0.5 V &  3882.0 &  4.97 &   9.420 \\
# 230 &   J22503-070 &               0.000000 &   M0.5 V &  3900.0 &  5.01 &   9.920 \\
# 231 &   J23381-162 &               0.000000 &   M2.0 V &  3570.0 &  5.07 &  11.288 \\
# 232 &   J23419+441 &               0.000000 &   M5.0 V &  3186.0 &  5.15 &     NaN \\
# 233 &   J23431+365 &               0.000000 &   M4.0 V &  3301.0 &  5.18 &     NaN \\
# \end{longtable}
# C:\Users\ciroe\AppData\Local\Temp\ipykernel_4052\570567966.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   carm_pred_info[basic_cols].to_latex(

# %%
# Save to file:
# Write to file:
# Backup the standard output:
original_stdout = sys.stdout
with open(LTX_CARM_PRED_WITH_INFO, 'w') as f:
    sys.stdout = f # Change the standard output to the file we created.print(
    print(
        carm_pred_info[basic_cols].to_latex(
            index=True, longtable=True,
            caption=("ML model pulsation probabilities for CARMENES stars.",
                     "ML model pulsation probabilities for CARMENES stars.")
        )
    )
# Restore the standard output to its original value
sys.stdout = original_stdout
# Out:
# C:\Users\ciroe\AppData\Local\Temp\ipykernel_4052\3420603758.py:8: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   carm_pred_info[basic_cols].to_latex(

# %%
print(list(carm_pred_info.columns))
# Out:
# ['index', 'Karmn', 'Pulsation probability', 'SpT', 'Teff_K', 'logg', 'V_mag', 'J_mag', 'InstBand_nominal', 'InstBand_ranged']

# %%
carm_pred_info['SpT'].unique()
# Out:
# array(['M4.0 V', 'M1.0 V', 'M3.5 V', 'M1.5 V', 'M2.0 V', 'M3.0 V',
#        'M0.0 V', 'M0.5 V', 'M2.5 V', 'M5.0 V', 'M4.5 V', 'M5.5 V',
#        'm1.5 V', 'm0 V', 'm3 V', 'm2.5 V', 'M7.0 V', 'M4.0 V+', 'M6.5 V',
#        'K7 V'], dtype=object)

# %% [markdown]
# ### Store the table of the two pulsators

# %%
print(list(carm_pred.columns))
# Out:
# ['Karmn', 'Pulsation predicted', 'Pulsation probability', 'Name', 'Comp', 'GJ', 'RA_J2016_deg', 'DE_J2016_deg', 'RA_J2000', 'DE_J2000', 'l_J2016_deg', 'b_J2016_deg', 'Ref01', 'SpT', 'SpTnum', 'Ref02', 'Teff_K', 'eTeff_K', 'logg', 'elogg', '[Fe/H]', 'e[Fe/H]', 'Ref03', 'L_Lsol', 'eL_Lsol', 'Ref04', 'R_Rsol', 'eR_Rsol', 'Ref05', 'M_Msol', 'eM_Msol', 'Ref06', 'muRA_masa-1', 'emuRA_masa-1', 'muDE_masa-1', 'emuDE_masa-1', 'Ref07', 'pi_mas', 'epi_mas', 'Ref08', 'd_pc', 'ed_pc', 'Ref09', 'Vr_kms-1', 'eVr_kms-1', 'Ref10', 'ruwe', 'Ref11', 'U_kms-1', 'eU_kms-1', 'V_kms-1', 'eV_kms-1', 'W_kms-1', 'eW_kms-1', 'Ref12', 'sa_m/s/a', 'esa_m/s/a', 'Ref13', 'SKG', 'Ref14', 'SKG_lit', 'Ref14_lit', 'Pop', 'Ref15', 'vsini_flag', 'vsini_kms-1', 'evsini_kms-1', 'Ref16', 'P_d', 'eP_d', 'Ref17', 'pEWHalpha_A', 'epEWHalpha_A', 'Ref18', 'log(LHalpha/Lbol)', 'elog(LHalpha/Lbol)', 'Ref19', '1RXS', 'CRT_s-1', 'eCRT_s-1', 'HR1', 'eHR1', 'HR2', 'eHR2', 'Flux_X_E-13_ergcm-2s-1', 'eFlux_X_E-13_ergcm-2s-1', 'LX/LJ', 'eLX/LJ', 'Ref20', 'Activity', 'Ref21', 'FUV_mag', 'eFUV_mag', 'NUV_mag', 'eNUV_mag', 'Ref22', 'u_mag', 'eu_mag', 'Ref23', 'BT_mag', 'eBT_mag', 'Ref24', 'B_mag', 'eB_mag', 'Ref25', 'BP_mag', 'eBP_mag', 'Ref26', 'g_mag', 'eg_mag', 'Ref27', 'VT_mag', 'eVT_mag', 'Ref28', 'V_mag', 'eV_mag', 'Ref29', 'Ra_mag', 'Ref30', 'r_mag', 'er_mag', 'Ref31', 'GG_mag', 'eGG_mag', 'Ref32', 'i_mag', 'ei_mag', 'Ref33', 'RP_mag', 'eRP_mag', 'Ref34', 'IN_mag', 'Ref35', 'J_mag', 'eJ_mag', 'H_mag', 'eH_mag', 'Ks_mag', 'eKs_mag', 'QFlag_2M', 'Ref36', 'W1_mag', 'eW1_mag', 'W2_mag', 'eW2_mag', 'W3_mag', 'eW3_mag', 'W4_mag', 'eW4_mag', 'QFlag_WISE', 'Ref37', 'Multiplicity', 'WideWDS', 'Widerho_arcsec', 'eWiderho_arcsec', 'Ref38', 'WideCompanionName', 'WideCompanionSpT', 'CloseWDS', 'Closerho_arcsec', 'eCloserho_arcsec', 'Ref39', 'CloseCompanionSpT', 'RV', 'Planet', 'Ref40', 'PlanetNum', 'LoRes_spectrum', 'HiRes_spectrum', 'LoRes_imaging', 'HiRes_imaging', 'Class', 'Survey', 'Notes', 'Gaia_id_1', '2MASS_id', 'TIC_id', 'InstBand_nominal', 'InstBand_ranged', 'n_RV', 'Ps_RV', 'fs_RV', 'wmean_RV', 'wrms_RV', 'info_PG_RV', 'maxP_PG_RV', 'maxSNR_PG_RV', 'rms_PG_RV', 'f_PG_RV', 'e_f_PG_RV', 'Pd_PG_RV', 'e_Pd_PG_RV', 'Ph_PG_RV', 'e_Ph_PG_RV', 'Pm_PG_RV', 'e_Pm_PG_RV', 'A_PG_RV', 'e_A_PG_RV', 'ph_PG_RV', 'e_ph_PG_RV', 'T0_PG_RV', 'e_T0_PG_RV', 'offset_PG_RV', 'e_offset_PG_RV', 'FAP_PG_RV', 'valid_PG_RV', 'error_PG_RV', 'elapsed_time_PG_RV', 'fits_file_RV', 'fig_file_RV', 'WF_maxP_PG_RV', 'WF_maxSNR_PG_RV', 'WF_rms_PG_RV', 'WF_f_PG_RV', 'WF_e_f_PG_RV', 'WF_Pd_PG_RV', 'WF_e_Pd_PG_RV', 'WF_Ph_PG_RV', 'WF_e_Ph_PG_RV', 'WF_Pm_PG_RV', 'WF_e_Pm_PG_RV', 'WF_A_PG_RV', 'WF_e_A_PG_RV', 'WF_ph_PG_RV', 'WF_e_ph_PG_RV', 'WF_T0_PG_RV', 'WF_e_T0_PG_RV', 'WF_offset_PG_RV', 'WF_e_offset_PG_RV', 'WF_FAP_PG_RV', 'WF_valid_PG_RV', 'WF_error_PG_RV', 'WF_elapsed_time_PG_RV', 'WF_plain_file_RV', 'WF_fig_file_RV', 'PG_file_RV']

# %%
carm_pulse = carm_pred[carm_pred['Pulsation predicted'] == 1]
carm_pulse
# Out:
#           Karmn  Pulsation predicted  Pulsation probability        Name Comp  \
# 161  J08126-215                    1               0.533333      GJ 300    -
# 69   J16581+257                    1               0.533333  BD+25 3173    -
#
#       GJ  RA_J2016_deg  DE_J2016_deg     RA_J2000     DE_J2000  ...  \
# 161  300    123.170435    -21.555024  08:12:40.89  -21:33:07.0  ...
# 69   649    254.536304     25.741901  16:58:08.85  +25:44:39.0  ...
#
#      WF_e_T0_PG_RV  WF_offset_PG_RV WF_e_offset_PG_RV  WF_FAP_PG_RV  \
# 161            NaN              1.0               NaN           NaN
# 69        0.000123              1.0      8.245824e-18  3.881759e-09
#
#      WF_valid_PG_RV WF_error_PG_RV  WF_elapsed_time_PG_RV  \
# 161             1.0            NaN              30.181885
# 69              1.0            NaN              34.175749
#
#                                       WF_plain_file_RV  \
# 161  ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J08126-215...
# 69   ../data/CARM_VIS_RVs_WinFunc_PGs/WF_J16581+257...
#
#                                         WF_fig_file_RV  \
# 161  ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J0...
# 69   ../data/CARM_VIS_RVs_WinFunc_PGs/figures/WF_J1...
#
#                                         PG_file_RV
# 161  ../data/CARM_VIS_RVs_PGs/J08126-215_RV_PG.dat
# 69   ../data/CARM_VIS_RVs_PGs/J16581+257_RV_PG.dat
#
# [2 rows x 236 columns]

# %%
carm_pulse \
    .to_csv(CARM_2PULSATORS_DETAILS_OUT, sep=',', decimal='.', index=True)

# %%
selected_cols = ['Karmn', 'Pulsation predicted', 'Pulsation probability',
                 'SpT', 'Teff_K', 'logg', '[Fe/H]', 'L_Lsol', 'R_Rsol', 'M_Msol', 'InstBand_nominal',
                 'vsini_flag', 'vsini_kms-1', 'P_d',
                 'Planet', 'PlanetNum',
                 'n_RV', 'Ps_RV', 'wrms_RV', 'f_PG_RV', 'A_PG_RV', 'FAP_PG_RV',
                 'Name', 'GJ', 'Gaia_id_1', '2MASS_id', 'TIC_id',
                 'V_mag', 'J_mag',
                 'RA_J2000', 'DE_J2000']

# %%
carm_pulse[selected_cols]
# Out:
#           Karmn  Pulsation predicted  Pulsation probability     SpT  Teff_K  \
# 161  J08126-215                    1               0.533333  M4.0 V  3356.0
# 69   J16581+257                    1               0.533333  M1.0 V  3782.0
#
#      logg  [Fe/H]    L_Lsol   R_Rsol  M_Msol  ... FAP_PG_RV        Name   GJ  \
# 161  4.88   -0.18  0.008425  0.27152  0.2625  ...  0.934340      GJ 300  300
# 69   4.87   -0.05  0.045321  0.49586  0.4992  ...  0.064984  BD+25 3173  649
#
#                Gaia_id_1          2MASS_id     TIC_id   V_mag  J_mag  \
# 161  5700706729031126656  08124088-2133056  471012765  12.131  7.601
# 69   4572835535272627712  16580884+2544392  236743275   9.837  6.448
#
#         RA_J2000     DE_J2000
# 161  08:12:40.89  -21:33:07.0
# 69   16:58:08.85  +25:44:39.0
#
# [2 rows x 31 columns]

# %%
selected_cp = carm_pulse[selected_cols].T
selected_cp
# Out:
#                                        161                  69
# Karmn                           J08126-215           J16581+257
# Pulsation predicted                      1                    1
# Pulsation probability             0.533333             0.533333
# SpT                                 M4.0 V               M1.0 V
# Teff_K                              3356.0               3782.0
# logg                                  4.88                 4.87
# [Fe/H]                               -0.18                -0.05
# L_Lsol                            0.008425             0.045321
# R_Rsol                             0.27152              0.49586
# M_Msol                              0.2625               0.4992
# InstBand_nominal               He3-burning          He3-burning
# vsini_flag                               <                    <
# vsini_kms-1                            2.0                  2.0
# P_d                                    NaN                 23.8
# Planet                                  No                  Yes
# PlanetNum                              0.0                  1.0
# n_RV                                  18.0                 55.0
# Ps_RV                             3.997831             0.935792
# wrms_RV                           3.428837             4.457546
# f_PG_RV                          281.84128            151.02384
# A_PG_RV                            5.01331             4.282456
# FAP_PG_RV                          0.93434             0.064984
# Name                                GJ 300           BD+25 3173
# GJ                                     300                  649
# Gaia_id_1              5700706729031126656  4572835535272627712
# 2MASS_id                  08124088-2133056     16580884+2544392
# TIC_id                           471012765            236743275
# V_mag                               12.131                9.837
# J_mag                                7.601                6.448
# RA_J2000                       08:12:40.89          16:58:08.85
# DE_J2000                       -21:33:07.0          +25:44:39.0

# %% [markdown]
# Prepare the multiindex:

# %%
print(selected_cols)
# Out:
# ['Karmn', 'Pulsation predicted', 'Pulsation probability', 'SpT', 'Teff_K', 'logg', '[Fe/H]', 'L_Lsol', 'R_Rsol', 'M_Msol', 'InstBand_nominal', 'vsini_flag', 'vsini_kms-1', 'P_d', 'Planet', 'PlanetNum', 'n_RV', 'Ps_RV', 'wrms_RV', 'f_PG_RV', 'A_PG_RV', 'FAP_PG_RV', 'Name', 'GJ', 'Gaia_id_1', '2MASS_id', 'TIC_id', 'V_mag', 'J_mag', 'RA_J2000', 'DE_J2000']

# %%
tuples = []
for i in range(0, 3):
    tuples.append(('ML model predictions', selected_cols[i]))
for i in range(3, 11):
    tuples.append(('Physical characteristics', selected_cols[i]))
for i in range(11, 14):
    tuples.append(('Rotation', selected_cols[i]))    
for i in range(14, 16):
    tuples.append(('Exoplanets', selected_cols[i]))
for i in range(16, 19):
    tuples.append(('RV curve characteristics', selected_cols[i]))
for i in range(19, 22):
    tuples.append(('Periodogram results', selected_cols[i]))
for i in range(22, 27):
    tuples.append(('Star identifiers', selected_cols[i]))
for i in range(27, 29):
    tuples.append(('Magnitudes', selected_cols[i]))
for i in range(29, len(selected_cols)):
    tuples.append(('Coordinates', selected_cols[i]))
    
tuples
# Out:
# [('ML model predictions', 'Karmn'),
#  ('ML model predictions', 'Pulsation predicted'),
#  ('ML model predictions', 'Pulsation probability'),
#  ('Physical characteristics', 'SpT'),
#  ('Physical characteristics', 'Teff_K'),
#  ('Physical characteristics', 'logg'),
#  ('Physical characteristics', '[Fe/H]'),
#  ('Physical characteristics', 'L_Lsol'),
#  ('Physical characteristics', 'R_Rsol'),
#  ('Physical characteristics', 'M_Msol'),
#  ('Physical characteristics', 'InstBand_nominal'),
#  ('Rotation', 'vsini_flag'),
#  ('Rotation', 'vsini_kms-1'),
#  ('Rotation', 'P_d'),
#  ('Exoplanets', 'Planet'),
#  ('Exoplanets', 'PlanetNum'),
#  ('RV curve characteristics', 'n_RV'),
#  ('RV curve characteristics', 'Ps_RV'),
#  ('RV curve characteristics', 'wrms_RV'),
#  ('Periodogram results', 'f_PG_RV'),
#  ('Periodogram results', 'A_PG_RV'),
#  ('Periodogram results', 'FAP_PG_RV'),
#  ('Star identifiers', 'Name'),
#  ('Star identifiers', 'GJ'),
#  ('Star identifiers', 'Gaia_id_1'),
#  ('Star identifiers', '2MASS_id'),
#  ('Star identifiers', 'TIC_id'),
#  ('Magnitudes', 'V_mag'),
#  ('Magnitudes', 'J_mag'),
#  ('Coordinates', 'RA_J2000'),
#  ('Coordinates', 'DE_J2000')]

# %%
selected_cp.index =pd.MultiIndex.from_tuples(tuples)
selected_cp
# Out:
#                                                                 161  \
# ML model predictions     Karmn                           J08126-215
#                          Pulsation predicted                      1
#                          Pulsation probability             0.533333
# Physical characteristics SpT                                 M4.0 V
#                          Teff_K                              3356.0
#                          logg                                  4.88
#                          [Fe/H]                               -0.18
#                          L_Lsol                            0.008425
#                          R_Rsol                             0.27152
#                          M_Msol                              0.2625
#                          InstBand_nominal               He3-burning
# Rotation                 vsini_flag                               <
#                          vsini_kms-1                            2.0
#                          P_d                                    NaN
# Exoplanets               Planet                                  No
#                          PlanetNum                              0.0
# RV curve characteristics n_RV                                  18.0
#                          Ps_RV                             3.997831
#                          wrms_RV                           3.428837
# Periodogram results      f_PG_RV                          281.84128
#                          A_PG_RV                            5.01331
#                          FAP_PG_RV                          0.93434
# Star identifiers         Name                                GJ 300
#                          GJ                                     300
#                          Gaia_id_1              5700706729031126656
#                          2MASS_id                  08124088-2133056
#                          TIC_id                           471012765
# Magnitudes               V_mag                               12.131
#                          J_mag                                7.601
# Coordinates              RA_J2000                       08:12:40.89
#                          DE_J2000                       -21:33:07.0
#
#                                                                 69
# ML model predictions     Karmn                           J16581+257
#                          Pulsation predicted                      1
#                          Pulsation probability             0.533333
# Physical characteristics SpT                                 M1.0 V
#                          Teff_K                              3782.0
#                          logg                                  4.87
#                          [Fe/H]                               -0.05
#                          L_Lsol                            0.045321
#                          R_Rsol                             0.49586
#                          M_Msol                              0.4992
#                          InstBand_nominal               He3-burning
# Rotation                 vsini_flag                               <
#                          vsini_kms-1                            2.0
#                          P_d                                   23.8
# Exoplanets               Planet                                 Yes
#                          PlanetNum                              1.0
# RV curve characteristics n_RV                                  55.0
#                          Ps_RV                             0.935792
#                          wrms_RV                           4.457546
# Periodogram results      f_PG_RV                          151.02384
#                          A_PG_RV                           4.282456
#                          FAP_PG_RV                         0.064984
# Star identifiers         Name                            BD+25 3173
#                          GJ                                     649
#                          Gaia_id_1              4572835535272627712
#                          2MASS_id                  16580884+2544392
#                          TIC_id                           236743275
# Magnitudes               V_mag                                9.837
#                          J_mag                                6.448
# Coordinates              RA_J2000                       16:58:08.85
#                          DE_J2000                       +25:44:39.0

# %% [markdown]
# #### Print and store the LaTeX table

# %%
print(
    selected_cp.to_latex(
        index=True, longtable=False,
        caption=("Two CARMENES stars labelled as pulsators by ML model.",
                 "Two CARMENES stars labelled as pulsators by ML model.")
    )
)
# Out:
# \begin{table}
# \centering
# \caption[Two CARMENES stars labelled as pulsators by ML model.]{Two CARMENES stars labelled as pulsators by ML model.}
# \begin{tabular}{llll}
# \toprule
#             &          &                  161 &                  69  \\
# \midrule
# ML model predictions & Karmn &           J08126-215 &           J16581+257 \\
#             & Pulsation predicted &                    1 &                    1 \\
#             & Pulsation probability &             0.533333 &             0.533333 \\
# Physical characteristics & SpT &               M4.0 V &               M1.0 V \\
#             & Teff\_K &               3356.0 &               3782.0 \\
#             & logg &                 4.88 &                 4.87 \\
#             & [Fe/H] &                -0.18 &                -0.05 \\
#             & L\_Lsol &             0.008425 &             0.045321 \\
#             & R\_Rsol &              0.27152 &              0.49586 \\
#             & M\_Msol &               0.2625 &               0.4992 \\
#             & InstBand\_nominal &          He3-burning &          He3-burning \\
# Rotation & vsini\_flag &                    < &                    < \\
#             & vsini\_kms-1 &                  2.0 &                  2.0 \\
#             & P\_d &                  NaN &                 23.8 \\
# Exoplanets & Planet &                   No &                  Yes \\
#             & PlanetNum &                  0.0 &                  1.0 \\
# RV curve characteristics & n\_RV &                 18.0 &                 55.0 \\
#             & Ps\_RV &             3.997831 &             0.935792 \\
#             & wrms\_RV &             3.428837 &             4.457546 \\
# Periodogram results & f\_PG\_RV &            281.84128 &            151.02384 \\
#             & A\_PG\_RV &              5.01331 &             4.282456 \\
#             & FAP\_PG\_RV &              0.93434 &             0.064984 \\
# Star identifiers & Name &               GJ 300 &           BD+25 3173 \\
#             & GJ &                  300 &                  649 \\
#             & Gaia\_id\_1 &  5700706729031126656 &  4572835535272627712 \\
#             & 2MASS\_id &     08124088-2133056 &     16580884+2544392 \\
#             & TIC\_id &            471012765 &            236743275 \\
# Magnitudes & V\_mag &               12.131 &                9.837 \\
#             & J\_mag &                7.601 &                6.448 \\
# Coordinates & RA\_J2000 &          08:12:40.89 &          16:58:08.85 \\
#             & DE\_J2000 &          -21:33:07.0 &          +25:44:39.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
# C:\Users\ciroe\AppData\Local\Temp\ipykernel_4052\608555052.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   selected_cp.to_latex(

# %%
# Save to file:
# Write to file:
# Backup the standard output:
original_stdout = sys.stdout
with open(LTX_CARM_2PULSATORS_DETAILS_OUT, 'w') as f:
    sys.stdout = f # Change the standard output to the file we created.print(
    print(
        selected_cp.to_latex(
            index=True, longtable=False,
            caption=("Two CARMENES stars labelled as pulsators by ML model.",
                     "Two CARMENES stars labelled as pulsators by ML model.")
        )
    )
# Restore the standard output to its original value
sys.stdout = original_stdout
# Out:
# C:\Users\ciroe\AppData\Local\Temp\ipykernel_4052\3146622393.py:8: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   selected_cp.to_latex(

# %% [markdown]
# ### J08126-215: real and possible synthetic curves

# %%
STAR = "J08126-215"

# %% [markdown]
# #### Gather J08126-215 file info

# %%
carm_star = pg_info.loc[pg_info['Karmn'] == STAR, ['Karmn', 'rv_file']].reset_index(drop=True).copy()
carm_star

# %%
carm_data = pd.read_csv(carm_star.loc[0, 'rv_file'], sep=' ', decimal='.',
                        header=None, names=['BJD', 'RV', 'errorRV'])
carm_data['BJD'] = carm_data['BJD'] - carm_data['BJD'].min()
carm_data

# %%
carm_data['low_RV'] = carm_data['RV'] - carm_data['errorRV']
carm_data['high_RV'] = carm_data['RV'] + carm_data['errorRV']
carm_data

# %% [markdown]
# #### Gather related synthetic curves

# %% [markdown]
# We first get all the synthetic curves related with this CARMENES star:

# %%
print(list(syn_df.columns))

# %%
syn_curves = syn_df[syn_df['CARMENES_Ref_star'] == STAR].copy()
syn_curves

# %% [markdown]
# We just want to have a small number of synthetic stars, so we just take the stars with `phase`=0, and `frequency`=32 (centered in the range of intertest).

# %%
p_curves = syn_curves[(syn_curves['frequency'] == 32) & (syn_curves['phase'] == 0)]
p_curves

# %% [markdown]
# And we add just one non-pulsating synthetic star, with a media error near the median value for these stars:

# %%
syn_curves[syn_curves['frequency'] == 0]['errorRV_median'].describe()

# %%
np_curves = syn_curves[syn_curves['frequency'] == 0] \
    .sort_values(by='errorRV_median', ascending=True) \
    .reset_index(drop=True)
np_curves

# %%
sel_np_curve = pd.DataFrame(np_curves.loc[int(len(np_curves) / 2), :]).T
sel_np_curve

# %%
sel_synth_curves = pd.concat([sel_np_curve, p_curves]).reset_index(drop=True)
sel_synth_curves

# %% [markdown]
# ##### Draw the overlapped curves, with errors margins

# %%
print(list(sel_synth_curves.columns))

# %%
print(list(carm_star.columns))

# %%
carm_data

# %%
synth_data = pd.read_csv(sel_synth_curves.loc[5, 'S4_ALT_file'], sep=' ', decimal='.',
                         header=None, names=['BJD', 'RV', 'errorRV'])
synth_data['low_RV'] = synth_data['RV'] - synth_data['errorRV']
synth_data['high_RV'] = synth_data['RV'] + synth_data['errorRV']
synth_data

# %%
carm_data['BJD'] == synth_data['BJD']

# %%
np.abs(carm_data['BJD'] - synth_data['BJD']).max()

# %% [raw]
# fig, ax = plt.subplots(figsize=(9,5))
#
# # CARMENES:
# x_c = carm_data['BJD']
# y_mean_c = carm_data['RV']
# lower_c = carm_data['low_RV']
# upper_c = carm_data['high_RV']
#
# ax.plot(x_c, y_mean_c, label='signal mean')
# ax.plot(x_c, lower_c, color='tab:blue', alpha=0.1)
# ax.plot(x_c, upper_c, color='tab:blue', alpha=0.1)
# ax.fill_between(x_c, lower_c, upper_c, alpha=0.2)
# ax.set_xlabel('timepoint')
# ax.set_ylabel('signal')
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
#
#
# # THE MAXIMUM APLITUDE SYNTHETIC PULSATOR
# x_s = synth_data['BJD']
# y_mean_s = synth_data['RV']
# lower_s = synth_data['low_RV']
# upper_s = synth_data['high_RV']
#
# ax.plot(x_s, y_mean_s, label='signal mean_')
# ax.plot(x_s, lower_s, color='tab:red', alpha=0.1)
# ax.plot(x_s, upper_s, color='tab:red', alpha=0.1)
# ax.fill_between(x_s, lower_s, upper_s, alpha=0.2)
# ax.set_xlabel('timepoint')
# ax.set_ylabel('signal')
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
#
#
#
#
# plt.show()
#
#
# #for i in range(0, len(sel_synth_curves))[:2]:
# #    data = pd.read_csv(sel_synth_curves.loc[i, 'S4_ALT_file'], sep=)

# %%
fig, ax = plt.subplots(figsize=(15,9))

# CARMENES:
x_c = carm_data['BJD']
y_mean_c = carm_data['RV']
lower_c = carm_data['low_RV']
upper_c = carm_data['high_RV']
error_c = sns.utils.ci_to_errsize((lower_c, upper_c), y_mean_c)

ax.errorbar(x_c, y_mean_c, error_c, color='tab:blue', ecolor='tab:blue',
            marker='o', linestyle='', label='CARMENES RV curve for %s' %STAR)

# THE MAXIMUM APLITUDE SYNTHETIC PULSATOR:
synth_data = pd.read_csv(sel_synth_curves.loc[5, 'S4_ALT_file'], sep=' ', decimal='.',
                         header=None, names=['BJD', 'RV', 'errorRV'])
synth_data['low_RV'] = synth_data['RV'] - synth_data['errorRV']
synth_data['high_RV'] = synth_data['RV'] + synth_data['errorRV']
synth_data

x_s = synth_data['BJD']
y_mean_s = synth_data['RV']
lower_s = synth_data['low_RV']
upper_s = synth_data['high_RV']
error_s = sns.utils.ci_to_errsize((lower_s, upper_s), y_mean_s)

ax.errorbar(x_s, y_mean_s, error_s, color='tab:orange', ecolor='tab:gray',
            marker='o', linestyle='', label="Synthetic RV curve (Pulsating, A=1.6 $m\;s^{-1}$)")

# THE NON-PULSATING SYNTHETIC STAR:
synth_data = pd.read_csv(sel_synth_curves.loc[0, 'S4_ALT_file'], sep=' ', decimal='.',
                         header=None, names=['BJD', 'RV', 'errorRV'])
synth_data['low_RV'] = synth_data['RV'] - synth_data['errorRV']
synth_data['high_RV'] = synth_data['RV'] + synth_data['errorRV']
synth_data

x_s = synth_data['BJD']
y_mean_s = synth_data['RV']
lower_s = synth_data['low_RV']
upper_s = synth_data['high_RV']
error_s = sns.utils.ci_to_errsize((lower_s, upper_s), y_mean_s)

ax.errorbar(x_s, y_mean_s, error_s, color='tab:gray', ecolor='tab:gray',
            marker='o', linestyle='', label="Synthetic RV curve (Non-pulsating)")

ax.set_xlabel('Relative BJD', fontsize=12)
ax.set_ylabel('RV [$m\;s^{-1}$]', fontsize=12)
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)
ax.set_title("CARMENES star %s, and two synthetic stars: non-pulsator and maximum amplitude pulsator"
             # %STAR, fontsize=16)
ax.legend(fontsize=12)

plt.savefig(IMG_FOLDER + "ML_95_01_%s_RV_curves.jpg" %STAR, format='jpg')
plt.show()

# %% [markdown]
# ### J16581+257: real and possible synthetic curves

# %%
STAR = "J16581+257"

# %% [markdown]
# #### Gather J16581+257 file info

# %%
carm_star = pg_info.loc[pg_info['Karmn'] == STAR, ['Karmn', 'rv_file']].reset_index(drop=True).copy()
carm_star

# %%
carm_data = pd.read_csv(carm_star.loc[0, 'rv_file'], sep=' ', decimal='.',
                        header=None, names=['BJD', 'RV', 'errorRV'])
carm_data['BJD'] = carm_data['BJD'] - carm_data['BJD'].min()
carm_data

# %%
carm_data['low_RV'] = carm_data['RV'] - carm_data['errorRV']
carm_data['high_RV'] = carm_data['RV'] + carm_data['errorRV']
carm_data

# %% [markdown]
# #### Gather related synthetic curves

# %% [markdown]
# We first get all the synthetic curves related with this CARMENES star:

# %%
print(list(syn_df.columns))

# %%
syn_curves = syn_df[syn_df['CARMENES_Ref_star'] == STAR].copy()
syn_curves

# %% [markdown]
# We just want to have a small number of synthetic stars, so we just take the stars with `phase`=0, and `frequency`=32 (centered in the range of intertest).

# %%
p_curves = syn_curves[(syn_curves['frequency'] == 32) & (syn_curves['phase'] == 0)]
p_curves

# %% [markdown]
# And we add just one non-pulsating synthetic star, with a media error near the median value for these stars:

# %%
syn_curves[syn_curves['frequency'] == 0]['errorRV_median'].describe()

# %%
np_curves = syn_curves[syn_curves['frequency'] == 0] \
    .sort_values(by='errorRV_median', ascending=True) \
    .reset_index(drop=True)
np_curves

# %%
sel_np_curve = pd.DataFrame(np_curves.loc[int(len(np_curves) / 2), :]).T
sel_np_curve

# %%
sel_synth_curves = pd.concat([sel_np_curve, p_curves]).reset_index(drop=True)
sel_synth_curves

# %% [markdown]
# ##### Draw the overlapped curves, with errors margins

# %%
print(list(sel_synth_curves.columns))

# %%
print(list(carm_star.columns))

# %%
carm_data

# %%
synth_data = pd.read_csv(sel_synth_curves.loc[5, 'S4_ALT_file'], sep=' ', decimal='.',
                         header=None, names=['BJD', 'RV', 'errorRV'])
synth_data['low_RV'] = synth_data['RV'] - synth_data['errorRV']
synth_data['high_RV'] = synth_data['RV'] + synth_data['errorRV']
synth_data

# %%
carm_data['BJD'] == synth_data['BJD']

# %%
np.abs(carm_data['BJD'] - synth_data['BJD']).max()

# %% [raw]
# fig, ax = plt.subplots(figsize=(9,5))
#
# # CARMENES:
# x_c = carm_data['BJD']
# y_mean_c = carm_data['RV']
# lower_c = carm_data['low_RV']
# upper_c = carm_data['high_RV']
#
# ax.plot(x_c, y_mean_c, label='signal mean')
# ax.plot(x_c, lower_c, color='tab:blue', alpha=0.1)
# ax.plot(x_c, upper_c, color='tab:blue', alpha=0.1)
# ax.fill_between(x_c, lower_c, upper_c, alpha=0.2)
# ax.set_xlabel('timepoint')
# ax.set_ylabel('signal')
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
#
#
# # THE MAXIMUM APLITUDE SYNTHETIC PULSATOR
# x_s = synth_data['BJD']
# y_mean_s = synth_data['RV']
# lower_s = synth_data['low_RV']
# upper_s = synth_data['high_RV']
#
# ax.plot(x_s, y_mean_s, label='signal mean_')
# ax.plot(x_s, lower_s, color='tab:red', alpha=0.1)
# ax.plot(x_s, upper_s, color='tab:red', alpha=0.1)
# ax.fill_between(x_s, lower_s, upper_s, alpha=0.2)
# ax.set_xlabel('timepoint')
# ax.set_ylabel('signal')
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
#
#
#
#
# plt.show()
#
#
# #for i in range(0, len(sel_synth_curves))[:2]:
# #    data = pd.read_csv(sel_synth_curves.loc[i, 'S4_ALT_file'], sep=)

# %%
fig, ax = plt.subplots(figsize=(15,9))

# CARMENES:
x_c = carm_data['BJD']
y_mean_c = carm_data['RV']
lower_c = carm_data['low_RV']
upper_c = carm_data['high_RV']
error_c = sns.utils.ci_to_errsize((lower_c, upper_c), y_mean_c)

ax.errorbar(x_c, y_mean_c, error_c, color='tab:blue', ecolor='tab:blue',
            marker='o', linestyle='', label='CARMENES RV curve for %s' %STAR)

# THE MAXIMUM APLITUDE SYNTHETIC PULSATOR:
synth_data = pd.read_csv(sel_synth_curves.loc[5, 'S4_ALT_file'], sep=' ', decimal='.',
                         header=None, names=['BJD', 'RV', 'errorRV'])
synth_data['low_RV'] = synth_data['RV'] - synth_data['errorRV']
synth_data['high_RV'] = synth_data['RV'] + synth_data['errorRV']
synth_data

x_s = synth_data['BJD']
y_mean_s = synth_data['RV']
lower_s = synth_data['low_RV']
upper_s = synth_data['high_RV']
error_s = sns.utils.ci_to_errsize((lower_s, upper_s), y_mean_s)

ax.errorbar(x_s, y_mean_s, error_s, color='tab:orange', ecolor='tab:gray',
            marker='o', linestyle='', label="Synthetic RV curve (Pulsating, A=1.6 $m\;s^{-1}$)")

# THE NON-PULSATING SYNTHETIC STAR:
synth_data = pd.read_csv(sel_synth_curves.loc[0, 'S4_ALT_file'], sep=' ', decimal='.',
                         header=None, names=['BJD', 'RV', 'errorRV'])
synth_data['low_RV'] = synth_data['RV'] - synth_data['errorRV']
synth_data['high_RV'] = synth_data['RV'] + synth_data['errorRV']
synth_data

x_s = synth_data['BJD']
y_mean_s = synth_data['RV']
lower_s = synth_data['low_RV']
upper_s = synth_data['high_RV']
error_s = sns.utils.ci_to_errsize((lower_s, upper_s), y_mean_s)

ax.errorbar(x_s, y_mean_s, error_s, color='tab:gray', ecolor='tab:gray',
            marker='o', linestyle='', label="Synthetic RV curve (Non-pulsating)")

ax.set_xlabel('Relative BJD', fontsize=12)
ax.set_ylabel('RV [$m\;s^{-1}$]', fontsize=12)
#ax.spines['top'].set_visible(False)
#ax.spines['right'].set_visible(False)
ax.set_title("CARMENES star %s, and two synthetic stars: non-pulsator and maximum amplitude pulsator"
             # %STAR, fontsize=16)
ax.legend(fontsize=12)

plt.savefig(IMG_FOLDER + "ML_95_02_%s_RV_curves.jpg" %STAR, format='jpg')
plt.show()

# %% [markdown]
# ## Summary

# %% [markdown]
# **RESULTS:**
#
# - We have gathered some more information on the two CARMENES stars identified as pulsators by the ML model with the default threshold.
