# %% [markdown]
# #  FEATURE ENGINEERING - FEATURE SCALING - ALTERNATIVE S4B SAMPLE FOR 1-NN IMPLEMENTATION

# %% [markdown]
# In this Notebook we apply a standard feature scaling, by subtracting the mean and dividing by the standard deviation
#
# **(PROBAR TAMBIÉN CON MINMAXSCALER A 0-1)**
#
# **NOTE:** we will define the scaler based just in the ALT_S4B sample, and apply the sampling to ALT_S4 sample. We will save the scaler for later use with the ML subsample.

# %% [markdown]
# ## Modules and configuration

# %% [markdown]
# ### Modules

# %%
import pandas as pd

from sklearn.preprocessing import StandardScaler
import pickle

#import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set_style("white", {'figure.figsize':(15,10)})

# %% [markdown]
# ### Configuration

# %%
CARMENES_IN = "../data/DATASETS_ML/1NN_CARMENES_00_DS_Initial.csv"
TRAIN_S4B_IN = "../data/DATASETS_ML/1NN_TRAIN_S4B_00_DS_Initial.csv"
VAL_S4B_IN = "../data/DATASETS_ML/1NN_VAL_S4B_00_DS_Initial.csv"

CESIUM_FEATURES_FILE = "../data/cesium_Features_by_Category.csv"

B_SCALER_FILE = "../data/ML_MODELS/ML_pipeline_steps/1NN_scaler.pickle" # Will store the fitted scaler object

CARMENES_OUT = "../data/DATASETS_ML/1NN_CARMENES_01_DS_AfterScaling.csv" # The scaled features of the ML subsample.
TRAIN_S4B_OUT = "../data/DATASETS_ML/1NN_TRAIN_S4B_01_DS_AfterScaling.csv" # The scaled features of the TRAINING S4 sample
VAL_S4B_OUT = "../data/DATASETS_ML/1NN_VAL_S4B_01_DS_AfterScaling.csv" # The scaled features of the VALIDATION S4 sample

ML_ADD_COLUMNS = ['Karmn'] # Only cesium features and this column will be kept.
S4_ADD_COLUMNS = ['ID', 'Pulsating', 'frequency', 'amplitudeRV',
                  'offsetRV', 'refepochRV', 'phase',
                  'CARMENES_source_idx', 'CARMENES_Ref_star'] # Only cesium features and these columns will be kept.

# %% [markdown]
# ### Functions

# %% [markdown]
# ## Load data

# %% [markdown]
# We load the data, which are the time series as previously featurized by _cesium_.

# %% [markdown]
# ### Load the cesium features

# %%
cs_f = pd.read_csv(CESIUM_FEATURES_FILE, sep=';', decimal='.')
cs_f
# Out:
#                         Type                     Feature  \
# 0              Cadence/Error    all_times_nhist_numpeaks
# 1              Cadence/Error   all_times_nhist_peak1_bin
# 2              Cadence/Error   all_times_nhist_peak2_bin
# 3              Cadence/Error   all_times_nhist_peak3_bin
# 4              Cadence/Error   all_times_nhist_peak4_bin
# ..                       ...                         ...
# 107  Lomb-Scargle (periodic)           p2p_scatter_2praw
# 108  Lomb-Scargle (periodic)        p2p_scatter_over_mad
# 109  Lomb-Scargle (periodic)  p2p_scatter_pfold_over_mad
# 110  Lomb-Scargle (periodic)      p2p_ssqr_diff_over_var
# 111  Lomb-Scargle (periodic)             scatter_res_raw
#
#                                            Description
# 0    Number of peaks (local maxima) in histogram of...
# 1    Return the (bin) index of the ith largest peak...
# 2    Return the (bin) index of the ith largest peak...
# 3    Return the (bin) index of the ith largest peak...
# 4    Return the (bin) index of the ith largest peak...
# ..                                                 ...
# 107  Get ratio of variability (sum of squared diffe...
# 108  Get ratio of variability of folded and unfolde...
# 109  Get ratio of median of period-folded data over...
# 110  Get sum of squared differences of consecutive ...
# 111      From arXiv 1101_2406v1 Dubath 20110112 paper.
#
# [112 rows x 3 columns]

# %%
cs_f_list = cs_f['Feature'].to_list()
print(cs_f_list)
# Out:
# ['all_times_nhist_numpeaks', 'all_times_nhist_peak1_bin', 'all_times_nhist_peak2_bin', 'all_times_nhist_peak3_bin', 'all_times_nhist_peak4_bin', 'all_times_nhist_peak_1_to_2', 'all_times_nhist_peak_1_to_3', 'all_times_nhist_peak_1_to_4', 'all_times_nhist_peak_2_to_3', 'all_times_nhist_peak_2_to_4', 'all_times_nhist_peak_3_to_4', 'all_times_nhist_peak_val', 'avg_double_to_single_step', 'avg_err', 'avgt', 'cad_probs_1', 'cad_probs_10', 'cad_probs_20', 'cad_probs_30', 'cad_probs_40', 'cad_probs_50', 'cad_probs_100', 'cad_probs_500', 'cad_probs_1000', 'cad_probs_5000', 'cad_probs_10000', 'cad_probs_50000', 'cad_probs_100000', 'cad_probs_500000', 'cad_probs_1000000', 'cad_probs_5000000', 'cad_probs_10000000', 'cads_avg', 'cads_med', 'cads_std', 'mean', 'med_double_to_single_step', 'med_err', 'n_epochs', 'std_double_to_single_step', 'std_err', 'total_time', 'amplitude', 'flux_percentile_ratio_mid20', 'flux_percentile_ratio_mid35', 'flux_percentile_ratio_mid50', 'flux_percentile_ratio_mid65', 'flux_percentile_ratio_mid80', 'max_slope', 'maximum', 'median', 'median_absolute_deviation', 'minimum', 'percent_amplitude', 'percent_beyond_1_std', 'percent_close_to_median', 'percent_difference_flux_percentile', 'period_fast', 'qso_log_chi2_qsonu', 'qso_log_chi2nuNULL_chi2nu', 'skew', 'std', 'stetson_j', 'stetson_k', 'weighted_average', 'fold2P_slope_10percentile', 'fold2P_slope_90percentile', 'freq1_amplitude1', 'freq1_amplitude2', 'freq1_amplitude3', 'freq1_amplitude4', 'freq1_freq', 'freq1_lambda', 'freq1_rel_phase2', 'freq1_rel_phase3', 'freq1_rel_phase4', 'freq1_signif', 'freq2_amplitude1', 'freq2_amplitude2', 'freq2_amplitude3', 'freq2_amplitude4', 'freq2_freq', 'freq2_rel_phase2', 'freq2_rel_phase3', 'freq2_rel_phase4', 'freq3_amplitude1', 'freq3_amplitude2', 'freq3_amplitude3', 'freq3_amplitude4', 'freq3_freq', 'freq3_rel_phase2', 'freq3_rel_phase3', 'freq3_rel_phase4', 'freq_amplitude_ratio_21', 'freq_amplitude_ratio_31', 'freq_frequency_ratio_21', 'freq_frequency_ratio_31', 'freq_model_max_delta_mags', 'freq_model_min_delta_mags', 'freq_model_phi1_phi2', 'freq_n_alias', 'freq_signif_ratio_21', 'freq_signif_ratio_31', 'freq_varrat', 'freq_y_offset', 'linear_trend', 'medperc90_2p_p', 'p2p_scatter_2praw', 'p2p_scatter_over_mad', 'p2p_scatter_pfold_over_mad', 'p2p_ssqr_diff_over_var', 'scatter_res_raw']

# %% [markdown]
# ### Load the TRAINING S4 sample data

# %%
s4_tr = pd.read_csv(TRAIN_S4B_IN, sep=',', decimal='.')
s4_tr
# Out:
#                      ID  Pulsating  frequency  amplitudeRV  offsetRV  \
# 0      ALT-B_Star-00000       True        8.0          0.1       0.0
# 1      ALT-B_Star-00001      False        0.0          0.0       0.0
# 2      ALT-B_Star-00002       True        8.0          0.1       0.0
# 3      ALT-B_Star-00003      False        0.0          0.0       0.0
# 4      ALT-B_Star-00004       True        8.0          0.1       0.0
# ...                 ...        ...        ...          ...       ...
# 37275  ALT-B_Star-37275      False        0.0          0.0       0.0
# 37276  ALT-B_Star-37276       True       64.0          1.6       0.0
# 37277  ALT-B_Star-37277      False        0.0          0.0       0.0
# 37278  ALT-B_Star-37278       True       64.0          1.6       0.0
# 37279  ALT-B_Star-37279      False        0.0          0.0       0.0
#
#        refepochRV  phase  CARMENES_source_idx CARMENES_Ref_star  \
# 0             0.0   0.00                    0        J23505-095
# 1             0.0   0.00                    0        J23505-095
# 2             0.0   0.25                    0        J23505-095
# 3             0.0   0.00                    0        J23505-095
# 4             0.0   0.50                    0        J23505-095
# ...           ...    ...                  ...               ...
# 37275         0.0   0.00                  232        J00051+457
# 37276         0.0   0.50                  232        J00051+457
# 37277         0.0   0.00                  232        J00051+457
# 37278         0.0   0.75                  232        J00051+457
# 37279         0.0   0.00                  232        J00051+457
#
#        all_times_nhist_numpeaks  ...  freq_signif_ratio_31  freq_varrat  \
# 0                          10.0  ...              0.852444     0.595003
# 1                          10.0  ...              0.875066     0.666432
# 2                          10.0  ...              0.913891     0.672340
# 3                          10.0  ...              0.961831     0.714286
# 4                          10.0  ...              0.930988     0.698053
# ...                         ...  ...                   ...          ...
# 37275                      12.0  ...              0.916000     0.561798
# 37276                      12.0  ...              1.000267     0.575509
# 37277                      12.0  ...              0.856494     0.592491
# 37278                      12.0  ...              0.904447     0.546488
# 37279                      12.0  ...              0.852733     0.594664
#
#        freq_y_offset  linear_trend  medperc90_2p_p  p2p_scatter_2praw  \
# 0          -0.152339     -0.000978        1.074144           0.772892
# 1           0.140860     -0.000429        1.024657           0.962333
# 2           0.120452     -0.000041        0.767704           0.779927
# 3          -0.015359      0.000299        0.832362           0.868586
# 4          -0.051849     -0.000303        0.619250           0.574467
# ...              ...           ...             ...                ...
# 37275       0.263209     -0.002615        0.857144           0.652312
# 37276       0.042197     -0.001708        0.888439           0.863114
# 37277       0.047063     -0.002131        0.800533           0.931275
# 37278      -0.374507     -0.001698        1.423353           0.905443
# 37279      -0.053339      0.000472        0.704872           0.499136
#
#        p2p_scatter_over_mad  p2p_scatter_pfold_over_mad  \
# 0                  1.201439                    1.104317
# 1                  1.214286                    1.314286
# 2                  1.320423                    1.038732
# 3                  1.435185                    1.550926
# 4                  1.934343                    1.050505
# ...                     ...                         ...
# 37275              1.617647                    1.245098
# 37276              1.583333                    1.000000
# 37277              1.403636                    1.098182
# 37278              1.049451                    1.060440
# 37279              1.474510                    1.027451
#
#        p2p_ssqr_diff_over_var  scatter_res_raw
# 0                    2.008315         0.482745
# 1                    2.107205         0.585830
# 2                    2.067927         0.447995
# 3                    2.188623         0.487488
# 4                    2.382155         0.730568
# ...                       ...              ...
# 37275                2.364025         0.406583
# 37276                1.918760         0.492849
# 37277                2.033018         0.397017
# 37278                1.823070         0.385341
# 37279                1.932530         0.491239
#
# [37280 rows x 121 columns]

# %%
print(list(s4_tr.columns))
# Out:
# ['ID', 'Pulsating', 'frequency', 'amplitudeRV', 'offsetRV', 'refepochRV', 'phase', 'CARMENES_source_idx', 'CARMENES_Ref_star', 'all_times_nhist_numpeaks', 'all_times_nhist_peak1_bin', 'all_times_nhist_peak2_bin', 'all_times_nhist_peak3_bin', 'all_times_nhist_peak4_bin', 'all_times_nhist_peak_1_to_2', 'all_times_nhist_peak_1_to_3', 'all_times_nhist_peak_1_to_4', 'all_times_nhist_peak_2_to_3', 'all_times_nhist_peak_2_to_4', 'all_times_nhist_peak_3_to_4', 'all_times_nhist_peak_val', 'avg_double_to_single_step', 'avg_err', 'avgt', 'cad_probs_1', 'cad_probs_10', 'cad_probs_20', 'cad_probs_30', 'cad_probs_40', 'cad_probs_50', 'cad_probs_100', 'cad_probs_500', 'cad_probs_1000', 'cad_probs_5000', 'cad_probs_10000', 'cad_probs_50000', 'cad_probs_100000', 'cad_probs_500000', 'cad_probs_1000000', 'cad_probs_5000000', 'cad_probs_10000000', 'cads_avg', 'cads_med', 'cads_std', 'mean', 'med_double_to_single_step', 'med_err', 'n_epochs', 'std_double_to_single_step', 'std_err', 'total_time', 'amplitude', 'flux_percentile_ratio_mid20', 'flux_percentile_ratio_mid35', 'flux_percentile_ratio_mid50', 'flux_percentile_ratio_mid65', 'flux_percentile_ratio_mid80', 'max_slope', 'maximum', 'median', 'median_absolute_deviation', 'minimum', 'percent_amplitude', 'percent_beyond_1_std', 'percent_close_to_median', 'percent_difference_flux_percentile', 'period_fast', 'qso_log_chi2_qsonu', 'qso_log_chi2nuNULL_chi2nu', 'skew', 'std', 'stetson_j', 'stetson_k', 'weighted_average', 'fold2P_slope_10percentile', 'fold2P_slope_90percentile', 'freq1_amplitude1', 'freq1_amplitude2', 'freq1_amplitude3', 'freq1_amplitude4', 'freq1_freq', 'freq1_lambda', 'freq1_rel_phase2', 'freq1_rel_phase3', 'freq1_rel_phase4', 'freq1_signif', 'freq2_amplitude1', 'freq2_amplitude2', 'freq2_amplitude3', 'freq2_amplitude4', 'freq2_freq', 'freq2_rel_phase2', 'freq2_rel_phase3', 'freq2_rel_phase4', 'freq3_amplitude1', 'freq3_amplitude2', 'freq3_amplitude3', 'freq3_amplitude4', 'freq3_freq', 'freq3_rel_phase2', 'freq3_rel_phase3', 'freq3_rel_phase4', 'freq_amplitude_ratio_21', 'freq_amplitude_ratio_31', 'freq_frequency_ratio_21', 'freq_frequency_ratio_31', 'freq_model_max_delta_mags', 'freq_model_min_delta_mags', 'freq_model_phi1_phi2', 'freq_n_alias', 'freq_signif_ratio_21', 'freq_signif_ratio_31', 'freq_varrat', 'freq_y_offset', 'linear_trend', 'medperc90_2p_p', 'p2p_scatter_2praw', 'p2p_scatter_over_mad', 'p2p_scatter_pfold_over_mad', 'p2p_ssqr_diff_over_var', 'scatter_res_raw']

# %% [markdown]
# ### Read the VALIDATION S4 sample data

# %%
s4_val = pd.read_csv(VAL_S4B_IN, sep=',', decimal='.')
s4_val
# Out:
#                 ID  Pulsating  frequency  amplitudeRV  offsetRV    refepochRV  \
# 0     B_Star-00000      False       0.00         0.00       0.0  2.457432e+06
# 1     B_Star-00001      False       0.00         0.00       0.0  2.457487e+06
# 2     B_Star-00002      False       0.00         0.00       0.0  2.457417e+06
# 3     B_Star-00003      False       0.00         0.00       0.0  2.457431e+06
# 4     B_Star-00004      False       0.00         0.00       0.0  2.461026e+06
# ...            ...        ...        ...          ...       ...           ...
# 3988  B_Star-03995      False       0.00         0.00       0.0  2.459911e+06
# 3989  B_Star-03996      False       0.00         0.00       0.0  2.457428e+06
# 3990  B_Star-03997      False       0.00         0.00       0.0  2.458409e+06
# 3991  B_Star-03998      False       0.00         0.00       0.0  2.457468e+06
# 3992  B_Star-03999       True      19.13         1.41       0.0  2.457400e+06
#
#       phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0      0.00                  116        J11511+352                      11.0
# 1      0.00                   29        J20336+617                       8.0
# 2      0.00                  156        J08402+314                      11.0
# 3      0.00                  180        J05421+124                      12.0
# 4      0.00                   67        J17052-050                      12.0
# ...     ...                  ...               ...                       ...
# 3988   0.00                   53        J18165+048                       7.0
# 3989   0.00                    8        J23216+172                       4.0
# 3990   0.00                    3        J23419+441                      10.0
# 3991   0.00                  181        J05415+534                      10.0
# 3992   0.45                  179        J06011+595                      15.0
#
#       ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0     ...              0.948040     0.809789       0.008037     -0.000402
# 1     ...              0.980112     0.604269       0.250163      0.000595
# 2     ...              1.131387     0.234854      -0.012060      0.002152
# 3     ...              0.957384     0.539035       0.130598     -0.000051
# 4     ...              0.926403     0.625322      -0.001450     -0.000311
# ...   ...                   ...          ...            ...           ...
# 3988  ...              0.871491     0.508868       0.113752      0.002208
# 3989  ...              1.080301     0.727763      -0.132918     -0.000010
# 3990  ...              1.016076     0.752359      -0.028916      0.000088
# 3991  ...              0.998230     0.806347      -0.023802     -0.000209
# 3992  ...              0.869605     0.536597      -0.050504     -0.000626
#
#       medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0           0.952390           0.823571              1.387755
# 1           1.387666           0.716612              1.701031
# 2           2.565635           0.785639              3.083333
# 3           1.186332           0.588031              1.942197
# 4           1.389174           0.576179              2.175000
# ...              ...                ...                   ...
# 3988        0.670102           1.184699              1.859155
# 3989        1.251124           0.839217              1.426966
# 3990        0.993836           0.703634              1.431034
# 3991        0.898179           0.768453              1.546392
# 3992        0.881329           0.914166              1.234783
#
#       p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                       1.673469                2.091815         0.732392
# 1                       1.134021                2.363048         0.372797
# 2                       2.152778                2.362236         0.114480
# 3                       1.005780                2.343527         0.457471
# 4                       1.000000                2.457354         0.486447
# ...                          ...                     ...              ...
# 3988                    1.267606                1.190609         0.517696
# 3989                    1.202247                1.971105         0.446290
# 3990                    1.275862                2.133724         0.686681
# 3991                    1.206186                2.199315         0.621301
# 3992                    1.130435                1.800200         0.440239
#
# [3993 rows x 121 columns]

# %%
print(list(s4_val.columns))
# Out:
# ['ID', 'Pulsating', 'frequency', 'amplitudeRV', 'offsetRV', 'refepochRV', 'phase', 'CARMENES_source_idx', 'CARMENES_Ref_star', 'all_times_nhist_numpeaks', 'all_times_nhist_peak1_bin', 'all_times_nhist_peak2_bin', 'all_times_nhist_peak3_bin', 'all_times_nhist_peak4_bin', 'all_times_nhist_peak_1_to_2', 'all_times_nhist_peak_1_to_3', 'all_times_nhist_peak_1_to_4', 'all_times_nhist_peak_2_to_3', 'all_times_nhist_peak_2_to_4', 'all_times_nhist_peak_3_to_4', 'all_times_nhist_peak_val', 'avg_double_to_single_step', 'avg_err', 'avgt', 'cad_probs_1', 'cad_probs_10', 'cad_probs_20', 'cad_probs_30', 'cad_probs_40', 'cad_probs_50', 'cad_probs_100', 'cad_probs_500', 'cad_probs_1000', 'cad_probs_5000', 'cad_probs_10000', 'cad_probs_50000', 'cad_probs_100000', 'cad_probs_500000', 'cad_probs_1000000', 'cad_probs_5000000', 'cad_probs_10000000', 'cads_avg', 'cads_med', 'cads_std', 'mean', 'med_double_to_single_step', 'med_err', 'n_epochs', 'std_double_to_single_step', 'std_err', 'total_time', 'amplitude', 'flux_percentile_ratio_mid20', 'flux_percentile_ratio_mid35', 'flux_percentile_ratio_mid50', 'flux_percentile_ratio_mid65', 'flux_percentile_ratio_mid80', 'max_slope', 'maximum', 'median', 'median_absolute_deviation', 'minimum', 'percent_amplitude', 'percent_beyond_1_std', 'percent_close_to_median', 'percent_difference_flux_percentile', 'period_fast', 'qso_log_chi2_qsonu', 'qso_log_chi2nuNULL_chi2nu', 'skew', 'std', 'stetson_j', 'stetson_k', 'weighted_average', 'fold2P_slope_10percentile', 'fold2P_slope_90percentile', 'freq1_amplitude1', 'freq1_amplitude2', 'freq1_amplitude3', 'freq1_amplitude4', 'freq1_freq', 'freq1_lambda', 'freq1_rel_phase2', 'freq1_rel_phase3', 'freq1_rel_phase4', 'freq1_signif', 'freq2_amplitude1', 'freq2_amplitude2', 'freq2_amplitude3', 'freq2_amplitude4', 'freq2_freq', 'freq2_rel_phase2', 'freq2_rel_phase3', 'freq2_rel_phase4', 'freq3_amplitude1', 'freq3_amplitude2', 'freq3_amplitude3', 'freq3_amplitude4', 'freq3_freq', 'freq3_rel_phase2', 'freq3_rel_phase3', 'freq3_rel_phase4', 'freq_amplitude_ratio_21', 'freq_amplitude_ratio_31', 'freq_frequency_ratio_21', 'freq_frequency_ratio_31', 'freq_model_max_delta_mags', 'freq_model_min_delta_mags', 'freq_model_phi1_phi2', 'freq_n_alias', 'freq_signif_ratio_21', 'freq_signif_ratio_31', 'freq_varrat', 'freq_y_offset', 'linear_trend', 'medperc90_2p_p', 'p2p_scatter_2praw', 'p2p_scatter_over_mad', 'p2p_scatter_pfold_over_mad', 'p2p_ssqr_diff_over_var', 'scatter_res_raw']

# %% [markdown]
# ###  Read the CARMENES ML subsample data

# %%
carm = pd.read_csv(CARMENES_IN, sep=',', decimal='.')
carm
# Out:
#            Karmn  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0     J23505-095                      10.0                       10.0
# 1     J23492+024                       7.0                        8.0
# 2     J23431+365                      11.0                       17.0
# 3     J23419+441                      10.0                       38.0
# 4     J23381-162                       9.0                       13.0
# ..           ...                       ...                        ...
# 228   J00184+440                      13.0                        7.0
# 229   J00183+440                      10.0                       10.0
# 230  J00162+198E                      14.0                       15.0
# 231   J00067-075                       6.0                       29.0
# 232   J00051+457                      12.0                        2.0
#
#      all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                         22.0                       12.0
# 1                         16.0                       24.0
# 2                         29.0                       48.0
# 3                         25.0                       40.0
# 4                         10.0                       16.0
# ..                         ...                        ...
# 228                       11.0                        9.0
# 229                       19.0                       24.0
# 230                       23.0                       34.0
# 231                       27.0                       16.0
# 232                       25.0                       22.0
#
#      all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                         31.0                     1.071111
# 1                         32.0                     1.222588
# 2                         13.0                     1.076923
# 3                         13.0                     1.265000
# 4                         45.0                     1.448718
# ..                         ...                          ...
# 228                        3.0                     1.000000
# 229                       26.0                     5.729958
# 230                       13.0                     1.000000
# 231                       45.0                     1.262032
# 232                        6.0                     1.443038
#
#      all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                       1.095455                     4.381818
# 1                       1.557039                     5.172370
# 2                       1.076923                     1.400000
# 3                       1.445714                     1.552147
# 4                       3.054054                     3.054054
# ..                           ...                          ...
# 228                     1.159763                     1.185006
# 229                     6.722772                     7.760000
# 230                     1.142857                     1.333333
# 231                     1.627586                     1.918699
# 232                     1.701493                     2.590909
#
#      all_times_nhist_peak_2_to_3  ...  freq_signif_ratio_31  freq_varrat  \
# 0                       1.022727  ...              0.813481     0.554379
# 1                       1.273560  ...              0.707163     0.879691
# 2                       1.000000  ...              0.991922     0.222404
# 3                       1.142857  ...              0.733129     0.550059
# 4                       2.108108  ...              0.872267     0.684783
# ..                           ...  ...                   ...          ...
# 228                     1.159763  ...              0.666641     0.558432
# 229                     1.173267  ...              0.633442     0.543139
# 230                     1.142857  ...              0.918027     0.215861
# 231                     1.289655  ...              1.030706     0.693464
# 232                     1.179104  ...              0.948621     0.591730
#
#      freq_y_offset  linear_trend  medperc90_2p_p  p2p_scatter_2praw  \
# 0         0.489066      0.004200        1.295720           1.436865
# 1        -0.910369      0.000814        1.044964           1.000000
# 2         0.082574      0.000863        1.033456           0.496443
# 3         0.182636     -0.001152        1.053811           0.971801
# 4        -0.039567      0.001306        1.099656           1.011043
# ..             ...           ...             ...                ...
# 228      -0.085931      0.002910        1.049630           2.126325
# 229      -0.020521     -0.000210        1.005997           1.155374
# 230      -0.329471      0.003725        2.401874           0.826581
# 231      -0.023253     -0.001416        0.920014           1.296351
# 232      -0.019719      0.001683        1.103366           0.643362
#
#      p2p_scatter_over_mad  p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  \
# 0                0.920684                    1.092416                0.978539
# 1                0.935512                    0.935512                1.242137
# 2                1.216607                    0.641686                1.907862
# 3                0.921956                    0.994958                1.188842
# 4                1.268031                    1.157254                2.078314
# ..                    ...                         ...                     ...
# 228              0.857117                    1.381938                0.643994
# 229              0.609987                    0.673215                0.591909
# 230              2.169255                    1.637703                1.688356
# 231              1.311097                    1.494734                1.489506
# 232              1.960808                    1.515754                2.107341
#
#      scatter_res_raw
# 0           0.445028
# 1           0.829985
# 2           0.091860
# 3           0.546181
# 4           0.457373
# ..               ...
# 228         0.752413
# 229         0.472642
# 230         0.169315
# 231         0.609811
# 232         0.573041
#
# [233 rows x 113 columns]

# %%
print(list(carm.columns))
# Out:
# ['Karmn', 'all_times_nhist_numpeaks', 'all_times_nhist_peak1_bin', 'all_times_nhist_peak2_bin', 'all_times_nhist_peak3_bin', 'all_times_nhist_peak4_bin', 'all_times_nhist_peak_1_to_2', 'all_times_nhist_peak_1_to_3', 'all_times_nhist_peak_1_to_4', 'all_times_nhist_peak_2_to_3', 'all_times_nhist_peak_2_to_4', 'all_times_nhist_peak_3_to_4', 'all_times_nhist_peak_val', 'avg_double_to_single_step', 'avg_err', 'avgt', 'cad_probs_1', 'cad_probs_10', 'cad_probs_20', 'cad_probs_30', 'cad_probs_40', 'cad_probs_50', 'cad_probs_100', 'cad_probs_500', 'cad_probs_1000', 'cad_probs_5000', 'cad_probs_10000', 'cad_probs_50000', 'cad_probs_100000', 'cad_probs_500000', 'cad_probs_1000000', 'cad_probs_5000000', 'cad_probs_10000000', 'cads_avg', 'cads_med', 'cads_std', 'mean', 'med_double_to_single_step', 'med_err', 'n_epochs', 'std_double_to_single_step', 'std_err', 'total_time', 'amplitude', 'flux_percentile_ratio_mid20', 'flux_percentile_ratio_mid35', 'flux_percentile_ratio_mid50', 'flux_percentile_ratio_mid65', 'flux_percentile_ratio_mid80', 'max_slope', 'maximum', 'median', 'median_absolute_deviation', 'minimum', 'percent_amplitude', 'percent_beyond_1_std', 'percent_close_to_median', 'percent_difference_flux_percentile', 'period_fast', 'qso_log_chi2_qsonu', 'qso_log_chi2nuNULL_chi2nu', 'skew', 'std', 'stetson_j', 'stetson_k', 'weighted_average', 'fold2P_slope_10percentile', 'fold2P_slope_90percentile', 'freq1_amplitude1', 'freq1_amplitude2', 'freq1_amplitude3', 'freq1_amplitude4', 'freq1_freq', 'freq1_lambda', 'freq1_rel_phase2', 'freq1_rel_phase3', 'freq1_rel_phase4', 'freq1_signif', 'freq2_amplitude1', 'freq2_amplitude2', 'freq2_amplitude3', 'freq2_amplitude4', 'freq2_freq', 'freq2_rel_phase2', 'freq2_rel_phase3', 'freq2_rel_phase4', 'freq3_amplitude1', 'freq3_amplitude2', 'freq3_amplitude3', 'freq3_amplitude4', 'freq3_freq', 'freq3_rel_phase2', 'freq3_rel_phase3', 'freq3_rel_phase4', 'freq_amplitude_ratio_21', 'freq_amplitude_ratio_31', 'freq_frequency_ratio_21', 'freq_frequency_ratio_31', 'freq_model_max_delta_mags', 'freq_model_min_delta_mags', 'freq_model_phi1_phi2', 'freq_n_alias', 'freq_signif_ratio_21', 'freq_signif_ratio_31', 'freq_varrat', 'freq_y_offset', 'linear_trend', 'medperc90_2p_p', 'p2p_scatter_2praw', 'p2p_scatter_over_mad', 'p2p_scatter_pfold_over_mad', 'p2p_ssqr_diff_over_var', 'scatter_res_raw']

# %% [markdown]
# ## Define and train the scaler

# %%
fit_data = s4_tr[cs_f_list].copy()
fit_data
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0                          10.0                       10.0
# 1                          10.0                       10.0
# 2                          10.0                       10.0
# 3                          10.0                       10.0
# 4                          10.0                       10.0
# ...                         ...                        ...
# 37275                      12.0                        2.0
# 37276                      12.0                        2.0
# 37277                      12.0                        2.0
# 37278                      12.0                        2.0
# 37279                      12.0                        2.0
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                           22.0                       12.0
# 1                           22.0                       12.0
# 2                           22.0                       12.0
# 3                           22.0                       12.0
# 4                           22.0                       12.0
# ...                          ...                        ...
# 37275                       25.0                       22.0
# 37276                       25.0                       22.0
# 37277                       25.0                       22.0
# 37278                       25.0                       22.0
# 37279                       25.0                       22.0
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                           31.0                     1.071111
# 1                           31.0                     1.071111
# 2                           31.0                     1.071111
# 3                           31.0                     1.071111
# 4                           31.0                     1.071111
# ...                          ...                          ...
# 37275                        6.0                     1.443038
# 37276                        6.0                     1.443038
# 37277                        6.0                     1.443038
# 37278                        6.0                     1.443038
# 37279                        6.0                     1.443038
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                         1.095455                     4.381818
# 1                         1.095455                     4.381818
# 2                         1.095455                     4.381818
# 3                         1.095455                     4.381818
# 4                         1.095455                     4.381818
# ...                            ...                          ...
# 37275                     1.701493                     2.590909
# 37276                     1.701493                     2.590909
# 37277                     1.701493                     2.590909
# 37278                     1.701493                     2.590909
# 37279                     1.701493                     2.590909
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# 0                         1.022727                     4.090909  ...
# 1                         1.022727                     4.090909  ...
# 2                         1.022727                     4.090909  ...
# 3                         1.022727                     4.090909  ...
# 4                         1.022727                     4.090909  ...
# ...                            ...                          ...  ...
# 37275                     1.179104                     1.795455  ...
# 37276                     1.179104                     1.795455  ...
# 37277                     1.179104                     1.795455  ...
# 37278                     1.179104                     1.795455  ...
# 37279                     1.179104                     1.795455  ...
#
#        freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0                  0.852444     0.595003      -0.152339     -0.000978
# 1                  0.875066     0.666432       0.140860     -0.000429
# 2                  0.913891     0.672340       0.120452     -0.000041
# 3                  0.961831     0.714286      -0.015359      0.000299
# 4                  0.930988     0.698053      -0.051849     -0.000303
# ...                     ...          ...            ...           ...
# 37275              0.916000     0.561798       0.263209     -0.002615
# 37276              1.000267     0.575509       0.042197     -0.001708
# 37277              0.856494     0.592491       0.047063     -0.002131
# 37278              0.904447     0.546488      -0.374507     -0.001698
# 37279              0.852733     0.594664      -0.053339      0.000472
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0            1.074144           0.772892              1.201439
# 1            1.024657           0.962333              1.214286
# 2            0.767704           0.779927              1.320423
# 3            0.832362           0.868586              1.435185
# 4            0.619250           0.574467              1.934343
# ...               ...                ...                   ...
# 37275        0.857144           0.652312              1.617647
# 37276        0.888439           0.863114              1.583333
# 37277        0.800533           0.931275              1.403636
# 37278        1.423353           0.905443              1.049451
# 37279        0.704872           0.499136              1.474510
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                        1.104317                2.008315         0.482745
# 1                        1.314286                2.107205         0.585830
# 2                        1.038732                2.067927         0.447995
# 3                        1.550926                2.188623         0.487488
# 4                        1.050505                2.382155         0.730568
# ...                           ...                     ...              ...
# 37275                    1.245098                2.364025         0.406583
# 37276                    1.000000                1.918760         0.492849
# 37277                    1.098182                2.033018         0.397017
# 37278                    1.060440                1.823070         0.385341
# 37279                    1.027451                1.932530         0.491239
#
# [37280 rows x 112 columns]

# %%
scaler = StandardScaler()
scaler.fit(fit_data)
# Out:
# StandardScaler()

# %% [markdown]
# ### Save the trained scaler

# %%
pickle.dump(scaler, open(SCALER_FILE, 'wb'))

# %% [markdown]
# ## Reload and apply the scaler to S4 sample and to ML subsample

# %% [markdown]
# ### Reload scaler

# %%
ld_scaler = pickle.load(open(SCALER_FILE, 'rb'))
ld_scaler
# Out:
# StandardScaler()

# %% [markdown]
# ### Scale the features in TRAINING S4 sample

# %%
scaled_s4_tr = s4_tr.copy()
scaled_s4_tr.head()
# Out:
#                  ID  Pulsating  frequency  amplitudeRV  offsetRV  refepochRV  \
# 0  ALT-B_Star-00000       True        8.0          0.1       0.0         0.0
# 1  ALT-B_Star-00001      False        0.0          0.0       0.0         0.0
# 2  ALT-B_Star-00002       True        8.0          0.1       0.0         0.0
# 3  ALT-B_Star-00003      False        0.0          0.0       0.0         0.0
# 4  ALT-B_Star-00004       True        8.0          0.1       0.0         0.0
#
#    phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0   0.00                    0        J23505-095                      10.0
# 1   0.00                    0        J23505-095                      10.0
# 2   0.25                    0        J23505-095                      10.0
# 3   0.00                    0        J23505-095                      10.0
# 4   0.50                    0        J23505-095                      10.0
#
#    ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0  ...              0.852444     0.595003      -0.152339     -0.000978
# 1  ...              0.875066     0.666432       0.140860     -0.000429
# 2  ...              0.913891     0.672340       0.120452     -0.000041
# 3  ...              0.961831     0.714286      -0.015359      0.000299
# 4  ...              0.930988     0.698053      -0.051849     -0.000303
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0        1.074144           0.772892              1.201439
# 1        1.024657           0.962333              1.214286
# 2        0.767704           0.779927              1.320423
# 3        0.832362           0.868586              1.435185
# 4        0.619250           0.574467              1.934343
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                    1.104317                2.008315         0.482745
# 1                    1.314286                2.107205         0.585830
# 2                    1.038732                2.067927         0.447995
# 3                    1.550926                2.188623         0.487488
# 4                    1.050505                2.382155         0.730568
#
# [5 rows x 121 columns]

# %%
scaled_s4_tr.loc[:, cs_f_list] = ld_scaler.transform(scaled_s4_tr.loc[:, cs_f_list])
scaled_s4_tr.head()
# Out:
#                  ID  Pulsating  frequency  amplitudeRV  offsetRV  refepochRV  \
# 0  ALT-B_Star-00000       True        8.0          0.1       0.0         0.0
# 1  ALT-B_Star-00001      False        0.0          0.0       0.0         0.0
# 2  ALT-B_Star-00002       True        8.0          0.1       0.0         0.0
# 3  ALT-B_Star-00003      False        0.0          0.0       0.0         0.0
# 4  ALT-B_Star-00004       True        8.0          0.1       0.0         0.0
#
#    phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0   0.00                    0        J23505-095                  0.205178
# 1   0.00                    0        J23505-095                  0.205178
# 2   0.25                    0        J23505-095                  0.205178
# 3   0.00                    0        J23505-095                  0.205178
# 4   0.50                    0        J23505-095                  0.205178
#
#    ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0  ...             -0.908970     0.541171      -0.669931     -0.015526
# 1  ...             -0.725712     0.832929       0.631644     -0.009818
# 2  ...             -0.411204     0.857062       0.541050     -0.005791
# 3  ...             -0.022857     1.028396      -0.061844     -0.002265
# 4  ...             -0.272705     0.962090      -0.223832     -0.008516
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0       -0.019047          -0.007352             -0.442166
# 1       -0.021695           0.552345             -0.429826
# 2       -0.035445           0.013431             -0.327874
# 3       -0.031985           0.275371             -0.217636
# 4       -0.043389          -0.593592              0.261842
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                   -0.134743               -0.219987         0.356795
# 1                    0.007825               -0.005592         0.720584
# 2                   -0.179274               -0.090747         0.234164
# 3                    0.168502                0.170924         0.373533
# 4                   -0.171281                0.590502         1.231367
#
# [5 rows x 121 columns]

# %%
s4_tr.head()
# Out:
#                  ID  Pulsating  frequency  amplitudeRV  offsetRV  refepochRV  \
# 0  ALT-B_Star-00000       True        8.0          0.1       0.0         0.0
# 1  ALT-B_Star-00001      False        0.0          0.0       0.0         0.0
# 2  ALT-B_Star-00002       True        8.0          0.1       0.0         0.0
# 3  ALT-B_Star-00003      False        0.0          0.0       0.0         0.0
# 4  ALT-B_Star-00004       True        8.0          0.1       0.0         0.0
#
#    phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0   0.00                    0        J23505-095                      10.0
# 1   0.00                    0        J23505-095                      10.0
# 2   0.25                    0        J23505-095                      10.0
# 3   0.00                    0        J23505-095                      10.0
# 4   0.50                    0        J23505-095                      10.0
#
#    ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0  ...              0.852444     0.595003      -0.152339     -0.000978
# 1  ...              0.875066     0.666432       0.140860     -0.000429
# 2  ...              0.913891     0.672340       0.120452     -0.000041
# 3  ...              0.961831     0.714286      -0.015359      0.000299
# 4  ...              0.930988     0.698053      -0.051849     -0.000303
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0        1.074144           0.772892              1.201439
# 1        1.024657           0.962333              1.214286
# 2        0.767704           0.779927              1.320423
# 3        0.832362           0.868586              1.435185
# 4        0.619250           0.574467              1.934343
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                    1.104317                2.008315         0.482745
# 1                    1.314286                2.107205         0.585830
# 2                    1.038732                2.067927         0.447995
# 3                    1.550926                2.188623         0.487488
# 4                    1.050505                2.382155         0.730568
#
# [5 rows x 121 columns]

# %%
s4_tr[cs_f_list].describe()
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count              37280.000000               37280.000000
# mean                   9.343348                  18.042918
# std                    3.200453                  14.103665
# min                    2.000000                   0.000000
# 25%                    7.000000                   8.000000
# 50%                    9.000000                  13.000000
# 75%                   11.000000                  26.000000
# max                   18.000000                  49.000000
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count               36800.000000               36000.000000
# mean                   20.647826                  24.391111
# std                    13.185888                  13.212565
# min                     0.000000                   0.000000
# 25%                     9.000000                  14.000000
# 50%                    18.000000                  24.000000
# 75%                    31.000000                  35.000000
# max                    49.000000                  49.000000
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count               34720.000000                 36800.000000
# mean                   26.124424                     1.456544
# std                    12.997465                     0.715273
# min                     0.000000                     1.000000
# 25%                    14.000000                     1.071111
# 50%                    26.000000                     1.250000
# 75%                    37.000000                     1.535714
# max                    49.000000                     7.288276
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                 36000.000000                 34720.000000
# mean                      1.944625                     2.562140
# std                       1.241585                     1.888397
# min                       1.000000                     1.000000
# 25%                       1.330827                     1.500000
# 50%                       1.600000                     2.000000
# 75%                       2.027778                     3.000000
# max                      13.351852                    15.000000
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                 36000.000000                 34720.000000  ...
# mean                      1.367510                     1.816531  ...
# std                       0.695504                     1.085073  ...
# min                       1.000000                     1.000000  ...
# 25%                       1.023810                     1.235294  ...
# 50%                       1.181818                     1.500000  ...
# 75%                       1.446154                     2.000000  ...
# max                       9.370370                     9.370370  ...
#
#        freq_signif_ratio_31   freq_varrat  freq_y_offset  linear_trend  \
# count          37264.000000  3.726400e+04   3.726400e+04  37264.000000
# mean               0.964652  4.625134e-01  -1.427365e-03      0.000517
# std                0.123448  2.448243e-01   2.252681e-01      0.096315
# min                0.186169  3.398250e-08  -1.463254e+00     -5.271012
# 25%                0.895362  2.426018e-01  -9.878183e-02     -0.000482
# 50%                0.959796  4.544353e-01  -8.930678e-11      0.000001
# 75%                1.028426  6.703860e-01   9.537411e-02      0.000489
# max                1.375438  9.966831e-01   1.936008e+00      4.129752
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count    3.677800e+04       37280.000000          37280.000000
# mean     1.430096e+00           0.775381              1.661754
# std      1.868824e+01           0.338476              1.041060
# min      2.541953e-11           0.112570              0.090293
# 25%      9.285395e-01           0.575155              1.335683
# 50%      1.110795e+00           0.736751              1.529304
# 75%      1.508761e+00           0.905465              1.787105
# max      3.564057e+03           7.054280             85.626667
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                37280.000000            37280.000000     37264.000000
# mean                     1.302762                2.109784         0.381641
# std                      1.472788                0.461259         0.283369
# min                      0.090293                0.172812         0.000359
# 25%                      0.980263                1.852855         0.145400
# 50%                      1.212766                2.063600         0.339266
# 75%                      1.440000                2.317864         0.576435
# max                    213.437500                4.519623        11.745672
#
# [8 rows x 112 columns]

# %%
scaled_s4_tr[cs_f_list].describe()
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count              3.728000e+04               3.728000e+04
# mean              -4.269355e-17              -9.148619e-17
# std                1.000013e+00               1.000013e+00
# min               -2.294502e+00              -1.279324e+00
# 25%               -7.322022e-01              -7.120882e-01
# 50%               -1.072824e-01              -3.575656e-01
# 75%                5.176375e-01               5.641929e-01
# max                2.704857e+00               2.194997e+00
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count               3.680000e+04               3.600000e+04
# mean                8.959017e-17              -5.052748e-17
# std                 1.000014e+00               1.000014e+00
# min                -1.565925e+00              -1.846080e+00
# 25%                -8.833674e-01              -7.864677e-01
# 50%                -2.008103e-01              -2.960186e-02
# 75%                 7.851056e-01               8.029505e-01
# max                 2.150220e+00               1.862563e+00
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count               3.472000e+04                 3.680000e+04
# mean               -1.309756e-17                 9.576880e-17
# std                 1.000014e+00                 1.000014e+00
# min                -2.009992e+00                -6.382879e-01
# 25%                -9.328434e-01                -5.388684e-01
# 50%                -9.573079e-03                -2.887663e-01
# 75%                 8.367580e-01                 1.106870e-01
# max                 1.760028e+00                 8.153267e+00
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                 3.600000e+04                 3.472000e+04
# mean                 -5.842240e-17                 8.185976e-17
# std                   1.000014e+00                 1.000014e+00
# min                  -7.608323e-01                -8.272426e-01
# 25%                  -4.943731e-01                -5.624640e-01
# 50%                  -2.775723e-01                -2.976853e-01
# 75%                   6.697425e-02                 2.318719e-01
# max                   9.187762e+00                 6.586559e+00
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                 3.600000e+04                 3.472000e+04  ...
# mean                  1.831621e-16                 4.584147e-17  ...
# std                   1.000014e+00                 1.000014e+00  ...
# min                  -5.284149e-01                -7.525235e-01  ...
# 25%                  -4.941809e-01                -5.356740e-01  ...
# 50%                  -2.669921e-01                -2.917182e-01  ...
# 75%                   1.130764e-01                 1.690871e-01  ...
# max                   1.150672e+01                 6.961699e+00  ...
#
#        freq_signif_ratio_31   freq_varrat  freq_y_offset  linear_trend  \
# count          3.726400e+04  3.726400e+04   3.726400e+04  3.726400e+04
# mean           3.355934e-17 -2.745764e-16   7.627123e-18 -2.288137e-18
# std            1.000013e+00  1.000013e+00   1.000013e+00  1.000013e+00
# min           -6.306264e+00 -1.889190e+00  -6.489361e+00 -5.473265e+01
# 25%           -5.613034e-01 -8.982544e-01  -4.321774e-01 -1.037192e-02
# 50%           -3.934120e-02 -3.299619e-02   6.336377e-03 -5.353901e-03
# 75%            5.166123e-01  8.490798e-01   4.297225e-01 -2.887420e-04
# max            3.327655e+00  2.181878e+00   8.600693e+00  4.287256e+01
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count    3.677800e+04       3.728000e+04          3.728000e+04
# mean    -3.670758e-18      -9.529811e-17         -9.758527e-17
# std      1.000014e+00       1.000013e+00          1.000013e+00
# min     -7.652490e-02      -1.958247e+00         -1.509502e+00
# 25%     -2.683846e-02      -5.915596e-01         -3.132149e-01
# 50%     -1.708591e-02      -1.141285e-01         -1.272274e-01
# 75%      4.209387e-03       3.843297e-01          1.204085e-01
# max      1.906373e+02       1.855076e+01          8.065438e+01
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                3.728000e+04            3.728000e+04     3.726400e+04
# mean                 7.242657e-17           -5.611153e-16    -1.830509e-16
# std                  1.000013e+00            1.000013e+00     1.000013e+00
# min                 -8.232581e-01           -4.199372e+00    -1.345553e+00
# 25%                 -2.189744e-01           -5.570242e-01    -8.336991e-01
# 50%                 -6.110645e-02           -1.001276e-01    -1.495433e-01
# 75%                  9.318402e-02            4.511185e-01     6.874313e-01
# max                  1.440381e+02            5.224551e+00     4.010389e+01
#
# [8 rows x 112 columns]

# %% [markdown]
# #### Save the scaled TRAINING S4 sample dataset

# %%
scaled_s4_tr.to_csv(TRAIN_S4B_OUT, sep=',', decimal='.', index=False)

# %% [markdown]
# ### Scale the features in VALIDATION S4 sample

# %%
scaled_s4_val = s4_val.copy()
scaled_s4_val.head()
# Out:
#              ID  Pulsating  frequency  amplitudeRV  offsetRV    refepochRV  \
# 0  B_Star-00000      False        0.0          0.0       0.0  2.457432e+06
# 1  B_Star-00001      False        0.0          0.0       0.0  2.457487e+06
# 2  B_Star-00002      False        0.0          0.0       0.0  2.457417e+06
# 3  B_Star-00003      False        0.0          0.0       0.0  2.457431e+06
# 4  B_Star-00004      False        0.0          0.0       0.0  2.461026e+06
#
#    phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0    0.0                  116        J11511+352                      11.0
# 1    0.0                   29        J20336+617                       8.0
# 2    0.0                  156        J08402+314                      11.0
# 3    0.0                  180        J05421+124                      12.0
# 4    0.0                   67        J17052-050                      12.0
#
#    ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0  ...              0.948040     0.809789       0.008037     -0.000402
# 1  ...              0.980112     0.604269       0.250163      0.000595
# 2  ...              1.131387     0.234854      -0.012060      0.002152
# 3  ...              0.957384     0.539035       0.130598     -0.000051
# 4  ...              0.926403     0.625322      -0.001450     -0.000311
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0        0.952390           0.823571              1.387755
# 1        1.387666           0.716612              1.701031
# 2        2.565635           0.785639              3.083333
# 3        1.186332           0.588031              1.942197
# 4        1.389174           0.576179              2.175000
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                    1.673469                2.091815         0.732392
# 1                    1.134021                2.363048         0.372797
# 2                    2.152778                2.362236         0.114480
# 3                    1.005780                2.343527         0.457471
# 4                    1.000000                2.457354         0.486447
#
# [5 rows x 121 columns]

# %%
scaled_s4_val.loc[:, cs_f_list] = ld_scaler.transform(scaled_s4_val.loc[:, cs_f_list])
scaled_s4_val.head()
# Out:
#              ID  Pulsating  frequency  amplitudeRV  offsetRV    refepochRV  \
# 0  B_Star-00000      False        0.0          0.0       0.0  2.457432e+06
# 1  B_Star-00001      False        0.0          0.0       0.0  2.457487e+06
# 2  B_Star-00002      False        0.0          0.0       0.0  2.457417e+06
# 3  B_Star-00003      False        0.0          0.0       0.0  2.457431e+06
# 4  B_Star-00004      False        0.0          0.0       0.0  2.461026e+06
#
#    phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0    0.0                  116        J11511+352                  0.517637
# 1    0.0                   29        J20336+617                 -0.419742
# 2    0.0                  156        J08402+314                  0.517637
# 3    0.0                  180        J05421+124                  0.830097
# 4    0.0                   67        J17052-050                  0.830097
#
#    ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0  ...             -0.134573     1.418486       0.042013     -0.009545
# 1  ...              0.125231     0.579019       1.116863      0.000807
# 2  ...              1.350668    -0.929902      -0.047202      0.016980
# 3  ...             -0.058875     0.312563       0.586087     -0.005898
# 4  ...             -0.309842     0.665012      -0.000102     -0.008592
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0       -0.025562           0.142376             -0.263196
# 1       -0.002270          -0.173628              0.037728
# 2        0.060763           0.030306              1.365530
# 3       -0.013044          -0.553518              0.269385
# 4       -0.002190          -0.588534              0.493010
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                    0.251708               -0.038958         1.237807
# 1                   -0.114574                0.549077        -0.031212
# 2                    0.577156                0.547318        -0.942817
# 3                   -0.201648                0.506757         0.267605
# 4                   -0.205573                0.753534         0.369862
#
# [5 rows x 121 columns]

# %%
s4_val.head()
# Out:
#              ID  Pulsating  frequency  amplitudeRV  offsetRV    refepochRV  \
# 0  B_Star-00000      False        0.0          0.0       0.0  2.457432e+06
# 1  B_Star-00001      False        0.0          0.0       0.0  2.457487e+06
# 2  B_Star-00002      False        0.0          0.0       0.0  2.457417e+06
# 3  B_Star-00003      False        0.0          0.0       0.0  2.457431e+06
# 4  B_Star-00004      False        0.0          0.0       0.0  2.461026e+06
#
#    phase  CARMENES_source_idx CARMENES_Ref_star  all_times_nhist_numpeaks  \
# 0    0.0                  116        J11511+352                      11.0
# 1    0.0                   29        J20336+617                       8.0
# 2    0.0                  156        J08402+314                      11.0
# 3    0.0                  180        J05421+124                      12.0
# 4    0.0                   67        J17052-050                      12.0
#
#    ...  freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# 0  ...              0.948040     0.809789       0.008037     -0.000402
# 1  ...              0.980112     0.604269       0.250163      0.000595
# 2  ...              1.131387     0.234854      -0.012060      0.002152
# 3  ...              0.957384     0.539035       0.130598     -0.000051
# 4  ...              0.926403     0.625322      -0.001450     -0.000311
#
#    medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# 0        0.952390           0.823571              1.387755
# 1        1.387666           0.716612              1.701031
# 2        2.565635           0.785639              3.083333
# 3        1.186332           0.588031              1.942197
# 4        1.389174           0.576179              2.175000
#
#    p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# 0                    1.673469                2.091815         0.732392
# 1                    1.134021                2.363048         0.372797
# 2                    2.152778                2.362236         0.114480
# 3                    1.005780                2.343527         0.457471
# 4                    1.000000                2.457354         0.486447
#
# [5 rows x 121 columns]

# %%
s4_val[cs_f_list].describe()
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count               3993.000000                3993.000000
# mean                   9.356875                  18.049086
# std                    3.232803                  14.019475
# min                    2.000000                   0.000000
# 25%                    7.000000                   8.000000
# 50%                    9.000000                  13.000000
# 75%                   12.000000                  26.000000
# max                   18.000000                  49.000000
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count                3939.000000                3867.000000
# mean                   20.869002                  24.577709
# std                    13.283738                  13.272984
# min                     0.000000                   0.000000
# 25%                     9.000000                  14.000000
# 50%                    18.000000                  24.000000
# 75%                    31.000000                  36.000000
# max                    49.000000                  49.000000
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count                3728.000000                  3939.000000
# mean                   26.037822                     1.441207
# std                    13.054052                     0.693493
# min                     0.000000                     1.000000
# 25%                    14.000000                     1.066667
# 50%                    25.000000                     1.234831
# 75%                    37.000000                     1.522774
# max                    49.000000                     7.288276
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                  3867.000000                  3728.000000
# mean                      1.951830                     2.565117
# std                       1.274144                     1.901285
# min                       1.000000                     1.000000
# 25%                       1.300971                     1.500000
# 50%                       1.600000                     2.000000
# 75%                       2.116279                     3.000000
# max                      13.351852                    15.000000
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                  3867.000000                  3728.000000  ...
# mean                      1.384547                     1.835793  ...
# std                       0.731997                     1.134257  ...
# min                       1.000000                     1.000000  ...
# 25%                       1.022727                     1.235294  ...
# 50%                       1.180851                     1.500000  ...
# 75%                       1.454545                     2.000000  ...
# max                       9.370370                     9.370370  ...
#
#        freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# count           3987.000000  3987.000000    3987.000000   3987.000000
# mean               0.974717     0.469068       0.002993     -0.000556
# std                0.109177     0.246879       0.224028      0.074621
# min                0.412037     0.012189      -1.300869     -1.998146
# 25%                0.903999     0.247992      -0.089468     -0.000480
# 50%                0.964275     0.460597       0.000006     -0.000002
# 75%                1.029773     0.676191       0.097040      0.000485
# max                1.375438     0.992947       1.455934      3.289913
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count    3.938000e+03        3993.000000           3993.000000
# mean     1.337140e+00           0.766770              1.653001
# std      9.721879e-01           0.320665              0.726211
# min      8.961103e-10           0.143365              0.178138
# 25%      9.223354e-01           0.572295              1.337705
# 50%      1.101106e+00           0.731889              1.530612
# 75%      1.486661e+00           0.895140              1.780822
# max      2.500916e+01           4.360050             17.538462
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                 3993.000000             3993.000000      3987.000000
# mean                     1.278361                2.110168         0.382817
# std                      0.687530                0.449390         0.269142
# min                      0.216418                0.494870         0.008886
# 25%                      0.968421                1.860780         0.151018
# 50%                      1.202247                2.063319         0.333944
# 75%                      1.433071                2.326295         0.573129
# max                     18.153846                4.545622         3.029625
#
# [8 rows x 112 columns]

# %%
scaled_s4_val[cs_f_list].describe()
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count               3993.000000                3993.000000
# mean                   0.004227                   0.000437
# std                    1.010121                   0.994044
# min                   -2.294502                  -1.279324
# 25%                   -0.732202                  -0.712088
# 50%                   -0.107282                  -0.357566
# 75%                    0.830097                   0.564193
# max                    2.704857                   2.194997
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count                3939.000000                3867.000000
# mean                    0.016774                   0.014123
# std                     1.007434                   1.004587
# min                    -1.565925                  -1.846080
# 25%                    -0.883367                  -0.786468
# 50%                    -0.200810                  -0.029602
# 75%                     0.785106                   0.878637
# max                     2.150220                   1.862563
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count                3728.000000                  3939.000000
# mean                   -0.006663                    -0.021442
# std                     1.004368                     0.969563
# min                    -2.009992                    -0.638288
# 25%                    -0.932843                    -0.545082
# 50%                    -0.086512                    -0.309973
# 75%                     0.836758                     0.092596
# max                     1.760028                     8.153267
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                  3867.000000                  3728.000000
# mean                      0.005803                     0.001576
# std                       1.026238                     1.006839
# min                      -0.760832                    -0.827243
# 25%                      -0.518420                    -0.562464
# 50%                      -0.277572                    -0.297685
# 75%                       0.138256                     0.231872
# max                       9.187762                     6.586559
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                  3867.000000                  3728.000000  ...
# mean                      0.024496                     0.017752  ...
# std                       1.052484                     1.045343  ...
# min                      -0.528415                    -0.752524  ...
# 25%                      -0.495737                    -0.535674  ...
# 50%                      -0.268383                    -0.291718  ...
# 75%                       0.125142                     0.169087  ...
# max                      11.506715                     6.961699  ...
#
#        freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# count           3987.000000  3987.000000    3987.000000   3987.000000
# mean               0.081534     0.026774       0.019621     -0.011142
# std                0.884413     1.008406       0.994507      0.774763
# min               -4.476570    -1.839401      -5.768502    -20.751503
# 25%               -0.491335    -0.876238      -0.390831     -0.010355
# 50%               -0.003054    -0.007826       0.006365     -0.005383
# 75%                0.527522     0.872792       0.437119     -0.000329
# max                3.327655     2.166616       6.469539     34.152774
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count     3938.000000        3993.000000           3993.000000
# mean        -0.004974          -0.025440             -0.008408
# std          0.052022           0.947391              0.697579
# min         -0.076525          -1.867264             -1.425121
# 25%         -0.027170          -0.600010             -0.311273
# 50%         -0.017604          -0.128495             -0.125971
# 75%          0.003027           0.353823              0.114373
# max          1.261723          10.590762             15.250728
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                 3993.000000             3993.000000      3987.000000
# mean                    -0.016568                0.000833         0.004148
# std                      0.466829                0.974282         0.949807
# min                     -0.737620               -3.501148        -1.315462
# 25%                     -0.227015               -0.539844        -0.813875
# 50%                     -0.068249               -0.100736        -0.168325
# 75%                      0.088479                0.469398         0.675763
# max                     11.441779                5.280916         9.344787
#
# [8 rows x 112 columns]

# %% [markdown]
# #### Save the scaled VALIDATION S4 sample dataset

# %%
scaled_s4_val.to_csv(VAL_S4B_OUT, sep=',', decimal='.', index=False)

# %% [markdown]
# ### Scale the features in CARMENES subsample

# %%
scaled_carm = carm.copy()
scaled_carm.head()
# Out:
#         Karmn  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0  J23505-095                      10.0                       10.0
# 1  J23492+024                       7.0                        8.0
# 2  J23431+365                      11.0                       17.0
# 3  J23419+441                      10.0                       38.0
# 4  J23381-162                       9.0                       13.0
#
#    all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                       22.0                       12.0
# 1                       16.0                       24.0
# 2                       29.0                       48.0
# 3                       25.0                       40.0
# 4                       10.0                       16.0
#
#    all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                       31.0                     1.071111
# 1                       32.0                     1.222588
# 2                       13.0                     1.076923
# 3                       13.0                     1.265000
# 4                       45.0                     1.448718
#
#    all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                     1.095455                     4.381818
# 1                     1.557039                     5.172370
# 2                     1.076923                     1.400000
# 3                     1.445714                     1.552147
# 4                     3.054054                     3.054054
#
#    all_times_nhist_peak_2_to_3  ...  freq_signif_ratio_31  freq_varrat  \
# 0                     1.022727  ...              0.813481     0.554379
# 1                     1.273560  ...              0.707163     0.879691
# 2                     1.000000  ...              0.991922     0.222404
# 3                     1.142857  ...              0.733129     0.550059
# 4                     2.108108  ...              0.872267     0.684783
#
#    freq_y_offset  linear_trend  medperc90_2p_p  p2p_scatter_2praw  \
# 0       0.489066      0.004200        1.295720           1.436865
# 1      -0.910369      0.000814        1.044964           1.000000
# 2       0.082574      0.000863        1.033456           0.496443
# 3       0.182636     -0.001152        1.053811           0.971801
# 4      -0.039567      0.001306        1.099656           1.011043
#
#    p2p_scatter_over_mad  p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  \
# 0              0.920684                    1.092416                0.978539
# 1              0.935512                    0.935512                1.242137
# 2              1.216607                    0.641686                1.907862
# 3              0.921956                    0.994958                1.188842
# 4              1.268031                    1.157254                2.078314
#
#    scatter_res_raw
# 0         0.445028
# 1         0.829985
# 2         0.091860
# 3         0.546181
# 4         0.457373
#
# [5 rows x 113 columns]

# %%
scaled_carm.loc[:, cs_f_list] = ld_scaler.transform(scaled_carm.loc[:, cs_f_list])
scaled_carm.head()
# Out:
#         Karmn  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0  J23505-095                  0.205178                  -0.570279
# 1  J23492+024                 -0.732202                  -0.712088
# 2  J23431+365                  0.517637                  -0.073948
# 3  J23419+441                  0.205178                   1.415047
# 4  J23381-162                 -0.107282                  -0.357566
#
#    all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                   0.102548                  -0.937841
# 1                  -0.352490                  -0.029602
# 2                   0.633426                   1.786876
# 3                   0.330067                   1.181383
# 4                  -0.807528                  -0.635095
#
#    all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                   0.375123                    -0.538868
# 1                   0.452062                    -0.327090
# 2                  -1.009783                    -0.530743
# 3                  -1.009783                    -0.267795
# 4                   1.452272                    -0.010941
#
#    all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                    -0.683950                     0.963624
# 1                    -0.312174                     1.382266
# 2                    -0.698876                    -0.615420
# 3                    -0.401839                    -0.534849
# 4                     0.893571                     0.260497
#
#    all_times_nhist_peak_2_to_3  ...  freq_signif_ratio_31  freq_varrat  \
# 0                    -0.495737  ...             -1.224593     0.375234
# 1                    -0.135084  ...             -2.085847     1.704012
# 2                    -0.528415  ...              0.220901    -0.980754
# 3                    -0.323011  ...             -1.875500     0.357589
# 4                     1.064851  ...             -0.748389     0.907884
#
#    freq_y_offset  linear_trend  medperc90_2p_p  p2p_scatter_2praw  \
# 0       2.177405      0.038241       -0.007191           1.954330
# 1      -4.034985      0.003083       -0.020609           0.663629
# 2       0.372899      0.003590       -0.021224          -0.824111
# 3       0.817097     -0.017334       -0.020135           0.580317
# 4      -0.169309      0.008196       -0.017682           0.696254
#
#    p2p_scatter_over_mad  p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  \
# 0             -0.711851                   -0.142823               -2.452548
# 1             -0.697608                   -0.249360               -1.881067
# 2             -0.427596                   -0.448866               -0.437768
# 3             -0.710630                   -0.208997               -1.996610
# 4             -0.378200                   -0.098799               -0.068227
#
#    scatter_res_raw
# 0         0.223693
# 1         1.582213
# 2        -1.022645
# 3         0.580664
# 4         0.267257
#
# [5 rows x 113 columns]

# %%
carm.head()
# Out:
#         Karmn  all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# 0  J23505-095                      10.0                       10.0
# 1  J23492+024                       7.0                        8.0
# 2  J23431+365                      11.0                       17.0
# 3  J23419+441                      10.0                       38.0
# 4  J23381-162                       9.0                       13.0
#
#    all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# 0                       22.0                       12.0
# 1                       16.0                       24.0
# 2                       29.0                       48.0
# 3                       25.0                       40.0
# 4                       10.0                       16.0
#
#    all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# 0                       31.0                     1.071111
# 1                       32.0                     1.222588
# 2                       13.0                     1.076923
# 3                       13.0                     1.265000
# 4                       45.0                     1.448718
#
#    all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# 0                     1.095455                     4.381818
# 1                     1.557039                     5.172370
# 2                     1.076923                     1.400000
# 3                     1.445714                     1.552147
# 4                     3.054054                     3.054054
#
#    all_times_nhist_peak_2_to_3  ...  freq_signif_ratio_31  freq_varrat  \
# 0                     1.022727  ...              0.813481     0.554379
# 1                     1.273560  ...              0.707163     0.879691
# 2                     1.000000  ...              0.991922     0.222404
# 3                     1.142857  ...              0.733129     0.550059
# 4                     2.108108  ...              0.872267     0.684783
#
#    freq_y_offset  linear_trend  medperc90_2p_p  p2p_scatter_2praw  \
# 0       0.489066      0.004200        1.295720           1.436865
# 1      -0.910369      0.000814        1.044964           1.000000
# 2       0.082574      0.000863        1.033456           0.496443
# 3       0.182636     -0.001152        1.053811           0.971801
# 4      -0.039567      0.001306        1.099656           1.011043
#
#    p2p_scatter_over_mad  p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  \
# 0              0.920684                    1.092416                0.978539
# 1              0.935512                    0.935512                1.242137
# 2              1.216607                    0.641686                1.907862
# 3              0.921956                    0.994958                1.188842
# 4              1.268031                    1.157254                2.078314
#
#    scatter_res_raw
# 0         0.445028
# 1         0.829985
# 2         0.091860
# 3         0.546181
# 4         0.457373
#
# [5 rows x 113 columns]

# %%
carm[cs_f_list].describe()
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count                233.000000                 233.000000
# mean                   9.343348                  18.042918
# std                    3.207301                  14.133839
# min                    2.000000                   0.000000
# 25%                    7.000000                   8.000000
# 50%                    9.000000                  13.000000
# 75%                   11.000000                  26.000000
# max                   18.000000                  49.000000
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count                 230.000000                 225.000000
# mean                   20.647826                  24.391111
# std                    13.214468                  13.241841
# min                     0.000000                   0.000000
# 25%                     9.000000                  14.000000
# 50%                    18.000000                  24.000000
# 75%                    31.000000                  35.000000
# max                    49.000000                  49.000000
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count                 217.000000                   230.000000
# mean                   26.124424                     1.456544
# std                    13.027329                     0.716823
# min                     0.000000                     1.000000
# 25%                    14.000000                     1.071190
# 50%                    26.000000                     1.250000
# 75%                    37.000000                     1.532738
# max                    49.000000                     7.288276
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                   225.000000                   217.000000
# mean                      1.944625                     2.562140
# std                       1.244336                     1.892736
# min                       1.000000                     1.000000
# 25%                       1.330827                     1.500000
# 50%                       1.600000                     2.000000
# 75%                       2.027778                     3.000000
# max                      13.351852                    15.000000
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                   225.000000                   217.000000  ...
# mean                      1.367510                     1.816531  ...
# std                       0.697046                     1.087566  ...
# min                       1.000000                     1.000000  ...
# 25%                       1.023810                     1.235294  ...
# 50%                       1.181818                     1.500000  ...
# 75%                       1.446154                     2.000000  ...
# max                       9.370370                     9.370370  ...
#
#        freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# count            233.000000   233.000000     233.000000    233.000000
# mean               0.931129     0.406203       0.044568     -0.005530
# std                0.139280     0.209434       0.479494      0.063154
# min                0.581979     0.050107      -1.378112     -0.946019
# 25%                0.846946     0.222533      -0.157819     -0.001681
# 50%                0.934611     0.380692       0.011492      0.000343
# 75%                1.006945     0.559939       0.267217      0.001723
# max                1.375437     0.998119       1.855925      0.054773
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count      228.000000         233.000000            233.000000
# mean         1.354686           0.970528              1.461775
# std          0.713218           0.434143              1.222450
# min          0.000299           0.300940              0.387727
# 25%          0.964158           0.657207              0.982467
# 50%          1.169603           0.916748              1.251863
# 75%          1.534653           1.179091              1.556039
# max          5.925674           3.069775             15.930603
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                  233.000000              233.000000       233.000000
# mean                     1.338192                1.673497         0.344544
# std                      1.203844                0.570022         0.231031
# min                      0.352122                0.391725         0.020064
# 25%                      0.948118                1.298997         0.133800
# 50%                      1.177379                1.614112         0.325024
# 75%                      1.381938                2.029083         0.492239
# max                     16.869044                3.703782         1.313978
#
# [8 rows x 112 columns]

# %%
scaled_carm[cs_f_list].describe()
# Out:
#        all_times_nhist_numpeaks  all_times_nhist_peak1_bin  \
# count              2.330000e+02               2.330000e+02
# mean               8.386234e-17              -9.148619e-17
# std                1.002153e+00               1.002153e+00
# min               -2.294502e+00              -1.279324e+00
# 25%               -7.322022e-01              -7.120882e-01
# 50%               -1.072824e-01              -3.575656e-01
# 75%                5.176375e-01               5.641929e-01
# max                2.704857e+00               2.194997e+00
#
#        all_times_nhist_peak2_bin  all_times_nhist_peak3_bin  \
# count               2.300000e+02               2.250000e+02
# mean                8.881784e-17              -7.105427e-17
# std                 1.002181e+00               1.002230e+00
# min                -1.565925e+00              -1.846080e+00
# 25%                -8.833674e-01              -7.864677e-01
# 50%                -2.008103e-01              -2.960186e-02
# 75%                 7.851056e-01               8.029505e-01
# max                 2.150220e+00               1.862563e+00
#
#        all_times_nhist_peak4_bin  all_times_nhist_peak_1_to_2  \
# count               2.170000e+02                 2.300000e+02
# mean               -1.227896e-17                 8.495620e-17
# std                 1.002312e+00                 1.002181e+00
# min                -2.009992e+00                -6.382879e-01
# 25%                -9.328434e-01                -5.387575e-01
# 50%                -9.573079e-03                -2.887663e-01
# 75%                 8.367580e-01                 1.065261e-01
# max                 1.760028e+00                 8.153267e+00
#
#        all_times_nhist_peak_1_to_3  all_times_nhist_peak_1_to_4  \
# count                 2.250000e+02                 2.170000e+02
# mean                 -4.934325e-17                 9.823171e-17
# std                   1.002230e+00                 1.002312e+00
# min                  -7.608323e-01                -8.272426e-01
# 25%                  -4.943731e-01                -5.624640e-01
# 50%                  -2.775723e-01                -2.976853e-01
# 75%                   6.697425e-02                 2.318719e-01
# max                   9.187762e+00                 6.586559e+00
#
#        all_times_nhist_peak_2_to_3  all_times_nhist_peak_2_to_4  ...  \
# count                 2.250000e+02                 2.170000e+02  ...
# mean                  2.289527e-16                 4.911586e-17  ...
# std                   1.002230e+00                 1.002312e+00  ...
# min                  -5.284149e-01                -7.525235e-01  ...
# 25%                  -4.941809e-01                -5.356740e-01  ...
# 50%                  -2.669921e-01                -2.917182e-01  ...
# 75%                   1.130764e-01                 1.690871e-01  ...
# max                   1.150672e+01                 6.961699e+00  ...
#
#        freq_signif_ratio_31  freq_varrat  freq_y_offset  linear_trend  \
# count            233.000000   233.000000     233.000000    233.000000
# mean              -0.271566    -0.230007       0.204185     -0.062786
# std                1.128264     0.855456       2.128576      0.655705
# min               -3.099925    -1.684524      -6.111399     -9.827589
# 25%               -0.953505    -0.980227      -0.694258     -0.022823
# 50%               -0.243356    -0.334207       0.057353     -0.001805
# 75%                0.342597     0.397944       1.192571      0.012517
# max                3.327644     2.187744       8.245187      0.563320
#
#        medperc90_2p_p  p2p_scatter_2praw  p2p_scatter_over_mad  \
# count      228.000000         233.000000            233.000000
# mean        -0.004035           0.576555             -0.192094
# std          0.038165           1.282657              1.174251
# min         -0.076509          -1.401715             -1.223795
# 25%         -0.024932          -0.349139             -0.652505
# 50%         -0.013939           0.417663             -0.393730
# 75%          0.005595           1.192746             -0.101547
# max          0.240560           6.778697             13.706263
#
#        p2p_scatter_pfold_over_mad  p2p_ssqr_diff_over_var  scatter_res_raw
# count                  233.000000              233.000000       233.000000
# mean                     0.024057               -0.945874        -0.130916
# std                      0.817402                1.235812         0.815313
# min                     -0.645478               -3.724766        -1.276013
# 25%                     -0.240800               -1.757794        -0.874639
# 50%                     -0.085134               -1.074622        -0.199803
# 75%                      0.053760               -0.174962         0.390301
# max                     10.569407                3.455800         3.290234
#
# [8 rows x 112 columns]

# %% [markdown]
# <font color='blue'>**SIMILAR TO S4 SAMPLE**</font>
#
# **OBSERVATION:** as we can see, mean and standard deviation for scaled ML sample are not exactly equal to 0 and 1, respectively, and even for some features the mean and standard deviation values differ a lot from those values. This is somehow expected, as we saw previously that for many features the distribution of values were very different between ML subsample and S4 sample.

# %% [markdown]
# #### Save the scaled ML subsample dataset

# %%
scaled_carm.to_csv(CARMENES_OUT, sep=',', decimal='.', index=False)

# %% [markdown]
# ## Summary

# %% [markdown]
# **RESULTS:**
#
# - We have created and saved a `StandardScaler`, fitted with the data in S4 sample (notice that `NaN` values are ignored during the fit and maintained during the transform)
# - We have reloaded that scaler and applied to the _cesium_ features of the S4 sample and the ML subsample.
# - **NOTE:** as expected (as the values distributions of many _cesium_ features were different for ML subsample and S4 sample), the mean and standard deviation for the scaled ML subsample are not 0 and 1 for many of the features.
